# %% [markdown]
# # - changes
#     model : resnext101_32x8d_wsl
#     transforms
#     optimizer -- SGD
#     scheduler -- cosineannealing
# ---

# %%
import gc
import os
import time
import numpy as np
import pandas as pd
from glob import glob
import tqdm
import argparse
import tqdm
from collections import defaultdict, Counter
from PIL import Image
import cv2

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch import nn, cuda
from torch.autograd import Variable 
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import CenterCrop

from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR
from utils import count_parameters, seed_everything, AdamW, CosineAnnealingWithRestartsLR

from efficientnet_pytorch import EfficientNet
import torchvision.models as models

from model import Baseline, Resnet18, Resnet50, Resnext50, Resnext101
from customs import mixup_data, mixup_criterion
from transforms import get_transform
from dataloader import make_loader, TestDataset

from torchvision.models.resnet import ResNet, Bottleneck

def clahe(img, clip_limit=1.0, tile_grid_size=(16, 16)):
    if img.dtype != np.uint8:
        raise TypeError("clahe supports only uint8 inputs")

    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)

    if len(img.shape) == 2:
        img = clahe.apply(img)
    else:
        img = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
        img[:, :, 0] = clahe.apply(img[:, :, 0])
        img = cv2.cvtColor(img, cv2.COLOR_LAB2RGB)

    return img

def _resnext(arch, block, layers, pretrained, progress, **kwargs):
    model = ResNet(block, layers, **kwargs)
#     state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
#     model.load_state_dict(state_dict)
    return model

def resnext101_32x8d_wsl(progress=True, **kwargs):
    """Constructs a ResNeXt-101 32x8 model pre-trained on weakly-supervised data
    and finetuned on ImageNet from Figure 5 in
    `"Exploring the Limits of Weakly Supervised Pretraining" <https://arxiv.org/abs/1805.00932>`_
    Args:
        progress (bool): If True, displays a progress bar of the download to stderr.
    """
    kwargs['groups'] = 32
    kwargs['width_per_group'] = 8
    return _resnext('resnext101_32x8d', Bottleneck, [3, 4, 23, 3], False, progress, **kwargs)

def to_numpy(t):
        return t.cpu().detach().numpy()

def make_folds(df, n_folds: int) -> pd.DataFrame:

    cls_counts = Counter([classes for classes in df['label']])
    fold_cls_counts = defaultdict()
    for class_index in cls_counts.keys():
        fold_cls_counts[class_index] = np.zeros(n_folds, dtype=np.int)

    df['fold'] = -1
    pbar = tqdm.tqdm(total=len(df))

    def get_fold(row):
        class_index = row['label']
        counts = fold_cls_counts[class_index]
        fold = np.argmin(counts)
        counts[fold] += 1
        fold_cls_counts[class_index] = counts
        row['fold']=fold
        pbar.update()
        return row

    df = df.apply(get_fold, axis=1)
    return df

def make_label(label):
    if label == 'MA':
        return 1
    elif label == 'GMA':
        return 2
    elif label == 'BOY':
        return 3
    elif label == 'FA':
        return 4
    elif label == 'GFA':
        return 5
    #elif label == 'GIRL':
    else:
        return 6


class TrainDataset(Dataset):
    def __init__(self, df, mode='train', transforms=None):
        self.df = df
        self.mode = mode
        self.transform = transforms[self.mode]

    def __len__(self):            
        return len(self.df)

    def __getitem__(self, idx):

        image = Image.open(IMAGES_PATH + '/' + self.df['filename'][idx]).convert("RGB")
        image = np.array(image)
        image = clahe((cv2.cvtColor(image, cv2.COLOR_BGR2RGB)))
        image = Image.fromarray(image)

        if self.transform:
            image = self.transform(image)
        label = self.df['label'][idx]

        return image, label

def make_loader(df, transforms, batch_size=256, num_workers=0):

    dataset = TrainDataset(df, transforms2)
    # dataset = image, label from Glass_Dataset

    loader = DataLoader(dataset, # image, label
                        batch_size=batch_size,
                        shuffle=True, 
                        num_workers=num_workers, 
                        pin_memory=True)

    return loader

class TestDataset(Dataset):
        def __init__(self, df, transform=None):
            self.df = df
            self.transform = transform

        def __len__(self):
            return len(self.df)

        def __getitem__(self, idx):

            image = Image.open(IMAGES_PATH+'/'+self.df['filename'][idx]).convert('RGB')
            image = np.array(image)
            image = clahe((cv2.cvtColor(image, cv2.COLOR_BGR2RGB)))
            image = Image.fromarray(image)

            if self.transform:
                image = self.transform(image)

            return image

IMAGES_PATH = 'C:/SEOYILGUK/JOB_VISION/faces_images'
csv_path = 'C:/SEOYILGUK/JOB_VISION/train.csv'
train_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/train.csv')
test_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/test.csv')

def make_df(image_path, csv_path):
    csv_df = pd.read_csv(csv_path)
    path_df = pd.DataFrame()
    file_list = os.listdir(image_path)
    path_df['filename'] = file_list
    path_df = path_df.iloc[1:,:] # remove .DS_Store filename
    df = csv_df.merge(path_df, on='filename', how='left')
    df['label'] = df['label']-1
    print(df.label.value_counts())
    return df

#num_fold = 0 #select fold number for training
for num_fold in range(5):
    
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 STARTS {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
    train_csv = pd.read_csv("../JOB_VISION/train.csv")

    SEED = 42
    seed_everything(SEED)

    device = 'cuda'
    use_gpu = cuda.is_available()

    if use_gpu:
        print("enable gpu use")
    else:
        print("enable cpu for debugging")

    target_size = (128, 128)

    num_classes = 6
    model = resnext101_32x8d_wsl(num_classes=num_classes)
    model.cuda()

    #model = models.resnet50() 
    #model.fc = nn.Linear(2048, args.num_classes)

    # elif args.model == 'resnet18': 
    #     model = Resnet18(args.num_classes, dropout=False)
    # elif args.model == 'resnet50':
    #     model = Resnet50(args.num_classes, dropout=False)
    # elif args.model == 'efficient':
    #     model = EfficientNet.from_pretrained('efficientnet-b0')
    #     in_features = model._fc.in_features
    #     model._fc = nn.Linear(in_features, args.num_classes)
    # elif args.model == 'densenet201':
    #     model = models.densenet201(pretrained=True)
    #     model.classifier = nn.Linear(1920, args.num_classes)
    # elif args.model == 'resnext50':
    #     model = Resnext50(args.num_classes, dropout=False)
    # elif args.model == 'resnext101':
    #     model = Resnext101(args.num_classes, dropout=False)
    # elif args.model == 'mobilenet':
    #     assert args.input_size == 158
    #     model = torch.hub.load('pytorch/vision', 'mobilenet_v2', pretrained=True)
    #     model.classifier = nn.Sequential(nn.Dropout(0.2),
    #                         nn.Linear(1280, args.num_classes))
    # else:
    #     raise NotImplementedError

    if use_gpu:
        model = model.to(device)

    # optimizer = optim.Adam(model.parameters(), args.lr, weight_decay=0.00025)
    #optimizer = AdamW(model.parameters(), 2.5e-4, weight_decay=0.000025)
    optimizer = optim.SGD(model.parameters(), 0.01, momentum=0.9, weight_decay=0.0025)

    ###### SCHEDULER #######
    #scheduler = ReduceLROnPlateau(optimizer, 'max', patience=5, factor=0.5)

    eta_min = 0.000001
    T_max = 10
    T_mult = 1
    restart_decay = 0.97
    scheduler = CosineAnnealingWithRestartsLR(optimizer, T_max=T_max, eta_min=eta_min, T_mult=T_mult, restart_decay=restart_decay)

    #scheduler = StepLR(optimizer, step_size=5, gamma=0.5)

    criterion = nn.CrossEntropyLoss() 

    num_parameters = count_parameters(model)
    print("==== number of parameters that can be trained: {}".format(num_parameters))

    df = make_df(IMAGES_PATH, csv_path)

    # 5 stratifiedKFold
    folds = make_folds(df, 5)
    print("==== fold_df created")
    print(folds.head())

    train_df = folds[folds['fold'] != num_fold]
    valid_df = folds[folds['fold'] == num_fold]

    train_df = train_df[['filename', 'label']].reset_index(drop=True)
    valid_df = valid_df[['filename', 'label']].reset_index(drop=True)
    print("number of train images: {}".format(len(train_df)))
    print("number of valid images: {}".format(len(valid_df)))

    start_time = time.time()
    
    print("shape of the df: {}".format(df.shape))    
    
    data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(target_size, scale=(0.7, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(
                brightness=0.4,
                contrast=0.4,
                saturation=0.4,
            ),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5161, 0.4225, 0.3763], 
            [0.2442, 0.2184, 0.2164]
        )]),
    'valid': transforms.Compose([
        transforms.RandomResizedCrop(target_size, scale=(0.8, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5161, 0.4225, 0.3763], 
            [0.2442, 0.2184, 0.2164]
        )])
    }
    
    batch_size = 32
    train_dataset = TrainDataset(train_df, mode='train', transforms=data_transforms)
    valid_dataset = TrainDataset(valid_df, mode='valid', transforms=data_transforms)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    print("number train batches: {}".format(len(train_loader)))
    print("number valid batches: {}".format(len(valid_loader)))
    elapsed = time.time() - start_time
    print("elapsed: {:.0f}".format(elapsed))

    best_val_acc = 0
    grad_clip_step = 100
    grad_clip = 100
    step = 0
    # accumulation_step = 2

    print("start training")

    for epoch_idx in range(1, 100 + 1):

        start_time = time.time()

        train_loss = 0
        train_total_correct = 0
        model.train()
        optimizer.zero_grad()

        for batch_idx, (image, labels) in enumerate(train_loader):
            if use_gpu:
                image = image.to(device)
                labels = labels.to(device)

            # print("shape of the image: {}".format(image.shape))
            # print("shape of the labels: {}".format(labels.shape))
            # print(image)
            # print(labels)

            #if args.mixup_loss:
            #    inputs, targets_a, targets_b, lam = mixup_data(image, labels, alpha=0.4, device=device)
            #    inputs, targets_a, targets_b = map(Variable, (inputs, targets_a, targets_b))
            #    output = model(inputs)
            #    loss = mixup_criterion(criterion, output.to(device), targets_a.to(device), targets_b.to(device), lam)
            #else:
            output = model(image)
            loss = criterion(output, labels)

            # gradient explosion prevention
            if step > grad_clip_step:
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

            step += 1

            loss.backward()

            optimizer.step()
            optimizer.zero_grad()

            # output_prob = F.softmax(output, dim=1)

            train_loss += loss.item() / len(train_loader)

        # Validation Starts
        model.eval()
        valid_loss = 0
        valid_total_correct = 0

        with torch.no_grad():
            for batch_idx, (image, labels) in enumerate(valid_loader):
                if use_gpu:
                    image = image.to(device)
                    labels = labels.to(device)


                output = model(image)
                loss = criterion(output, labels)

                output_prob = F.softmax(output, dim=1)

                predict_vector = np.argmax(to_numpy(output_prob), axis=1)
                label_vector = to_numpy(labels)
                bool_vector = predict_vector == label_vector
                #print('val_pred', predict_vector[:5])
                #print('val_label', label_vector[:5])
                #print("shape of prediction vector: {}".format(predict_vector.shape))
                #print(predict_vector.head())
                #print("shape of label vector: {}".format(label_vector.shape))

                valid_loss += loss.item() / len(valid_loader)
                valid_total_correct += bool_vector.sum()


        elapsed = time.time() - start_time

        val_acc = valid_total_correct / len(valid_loader.dataset)

        # best val_acc checkpoint
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            print("val_acc has improved !! ")
            torch.save(model.state_dict(), 'resnext101_32x8d_wsl_clahe_fold_{}_best_model.pt'.format(num_fold))
            print("================ ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ".format(epoch_idx, best_val_acc))
            #file_save_name = 'best_acc' + '_' + str(num_fold)
            #print(file_save_name)
        else:
            print("val acc has not improved")

        lr = [_['lr'] for _ in optimizer.param_groups]

        #if args.scheduler == 'plateau':
        scheduler.step(val_acc)
        #else:
        #    scheduler.step()

        # nsml.save(epoch_idx)

        print("Epoch {}/{}  train_loss: {:.5f}  valid_loss {:.5f}  valid_acc: {:.5f}  lr: {:.6f}  elapsed: {:.0f}".format(
               epoch_idx, 100, train_loss, valid_loss, val_acc, lr[0], elapsed))
                #epoch_idx, args.epochs, train_loss, valid_loss, val_acc, lr[0], elapsed

#    IMAGES_PATH = 'C:/SEOYILGUK/JOB_VISION/faces_images'
#    test_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/test.csv')

    batch_size = 32
    num_workers = 0

    # model = models.resnet18(pretrained=False) 
    # model.fc = nn.Linear(512, args.num_classes)

    # checkpoint = 'team012/KHD2019_FUNDUS/93'
    # nsml.load(checkpoint, load_fn=load)

    test_transforms = transforms.Compose([
                        transforms.RandomResizedCrop(target_size, scale=(0.8, 1.0)),
                        transforms.RandomHorizontalFlip(),
                        transforms.ToTensor(),
                        transforms.Normalize(
                            [0.5161, 0.4225, 0.3763], 
                            [0.2442, 0.2184, 0.2164])
                    ])

    test_dataset = TestDataset(test_df, test_transforms)
    test_loader = DataLoader(test_dataset,
                             batch_size=batch_size,
                             shuffle=False, 
                             num_workers=num_workers, 
                             pin_memory=True)
    
    print("============== ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ====================================".format(epoch_idx, best_val_acc))
    print("========================== ༼ つ ◕_◕ ༽つ Model Load {}_th FOLD =================================".format(num_fold))
    model.load_state_dict(torch.load('resnext101_32x8d_wsl_clahe_fold_{}_best_model.pt'.format(num_fold)))

    model.eval()
    # for _ in range(tta):
        # print("tta {} predict".format(_+1))
    predictions = np.zeros((len(test_loader.dataset), 6))

    with torch.no_grad():
        for i, image in enumerate(test_loader):
            image = image.to(device)
            output = model(image) # output shape (batch_num, num_classes)

            predictions[i*batch_size: (i+1)*batch_size] = output.detach().cpu().numpy()
    print("predict values check : ",predictions[0])
    np.savetxt("../JOB_VISION/resnext101_32x8d_wsl_submission/resnext101_32x8d_wsl_clahe_{}_fold.csv".format(num_fold), predictions, delimiter=",")
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 SAVED {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
# Out:
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7606.85it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.430401366353544
# Epoch 1/100  train_loss: 2.57137  valid_loss 1.46804  valid_acc: 0.43040  lr: 0.010000  elapsed: 83
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.4543125533731853
# Epoch 2/100  train_loss: 1.53559  valid_loss 1.41016  valid_acc: 0.45431  lr: 0.009954  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.4927412467976089
# Epoch 3/100  train_loss: 1.51124  valid_loss 1.34955  valid_acc: 0.49274  lr: 0.009949  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.5072587532023911
# Epoch 4/100  train_loss: 1.40694  valid_loss 1.36218  valid_acc: 0.50726  lr: 0.009940  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5175064047822374
# Epoch 5/100  train_loss: 1.35765  valid_loss 1.30959  valid_acc: 0.51751  lr: 0.009937  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.5866780529461998
# Epoch 6/100  train_loss: 1.27640  valid_loss 1.12530  valid_acc: 0.58668  lr: 0.009934  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.6797608881298036
# Epoch 7/100  train_loss: 1.09893  valid_loss 0.90382  valid_acc: 0.67976  lr: 0.009915  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.7139197267292912
# Epoch 8/100  train_loss: 0.94142  valid_loss 0.76308  valid_acc: 0.71392  lr: 0.009886  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.7438087105038429
# Epoch 9/100  train_loss: 0.83817  valid_loss 0.67363  valid_acc: 0.74381  lr: 0.009875  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7702818104184458
# Epoch 10/100  train_loss: 0.72554  valid_loss 0.61197  valid_acc: 0.77028  lr: 0.009864  elapsed: 87
# val acc has not improved
# Epoch 11/100  train_loss: 0.65959  valid_loss 0.70598  valid_acc: 0.74552  lr: 0.009854  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.8249359521776259
# Epoch 12/100  train_loss: 0.60045  valid_loss 0.53671  valid_acc: 0.82494  lr: 0.009864  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.8317677198975235
# Epoch 13/100  train_loss: 0.55573  valid_loss 0.44610  valid_acc: 0.83177  lr: 0.009833  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 14, Accuracy : 0.8420153714773698
# Epoch 14/100  train_loss: 0.55074  valid_loss 0.49163  valid_acc: 0.84202  lr: 0.009830  elapsed: 88
# val acc has not improved
# Epoch 15/100  train_loss: 0.49347  valid_loss 0.43899  valid_acc: 0.82579  lr: 0.009826  elapsed: 87
# val acc has not improved
# Epoch 16/100  train_loss: 0.46960  valid_loss 0.40208  valid_acc: 0.84202  lr: 0.009833  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.842869342442357
# Epoch 17/100  train_loss: 0.45627  valid_loss 0.47724  valid_acc: 0.84287  lr: 0.009826  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 18, Accuracy : 0.8539709649871904
# Epoch 18/100  train_loss: 0.44242  valid_loss 0.39259  valid_acc: 0.85397  lr: 0.009826  elapsed: 87
# val acc has not improved
# Epoch 19/100  train_loss: 0.41107  valid_loss 0.53607  valid_acc: 0.80188  lr: 0.009821  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 20, Accuracy : 0.860802732707088
# Epoch 20/100  train_loss: 0.39408  valid_loss 0.38933  valid_acc: 0.86080  lr: 0.009842  elapsed: 87
# val acc has not improved
# Epoch 21/100  train_loss: 0.38206  valid_loss 0.43998  valid_acc: 0.84799  lr: 0.009818  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 22, Accuracy : 0.8659265584970111
# Epoch 22/100  train_loss: 0.37912  valid_loss 0.38318  valid_acc: 0.86593  lr: 0.009824  elapsed: 87
# val acc has not improved
# Epoch 23/100  train_loss: 0.33572  valid_loss 0.43374  valid_acc: 0.85568  lr: 0.009816  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 24, Accuracy : 0.8778821520068317
# Epoch 24/100  train_loss: 0.34652  valid_loss 0.34210  valid_acc: 0.87788  lr: 0.009820  elapsed: 87
# val acc has not improved
# Epoch 25/100  train_loss: 0.33934  valid_loss 0.38360  valid_acc: 0.86166  lr: 0.009811  elapsed: 87
# val acc has not improved
# Epoch 26/100  train_loss: 0.34339  valid_loss 0.69532  valid_acc: 0.83006  lr: 0.009818  elapsed: 88
# val acc has not improved
# Epoch 27/100  train_loss: 0.33528  valid_loss 0.38369  valid_acc: 0.86934  lr: 0.009831  elapsed: 87
# val acc has not improved
# Epoch 28/100  train_loss: 0.32648  valid_loss 0.36572  valid_acc: 0.87617  lr: 0.009815  elapsed: 87
# val acc has not improved
# Epoch 29/100  train_loss: 0.33520  valid_loss 0.35540  valid_acc: 0.87276  lr: 0.009812  elapsed: 87
# val acc has not improved
# Epoch 30/100  train_loss: 0.31748  valid_loss 0.61896  valid_acc: 0.85056  lr: 0.009813  elapsed: 87
# val acc has not improved
# Epoch 31/100  train_loss: 0.30314  valid_loss 0.37548  valid_acc: 0.87276  lr: 0.009823  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 32, Accuracy : 0.8787361229718189
# Epoch 32/100  train_loss: 0.32857  valid_loss 0.33233  valid_acc: 0.87874  lr: 0.009813  elapsed: 87
# val acc has not improved
# Epoch 33/100  train_loss: 0.29769  valid_loss 0.36095  valid_acc: 0.87532  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 34/100  train_loss: 0.31120  valid_loss 0.41100  valid_acc: 0.86166  lr: 0.009812  elapsed: 87
# val acc has not improved
# Epoch 35/100  train_loss: 0.29241  valid_loss 0.38337  valid_acc: 0.86507  lr: 0.009818  elapsed: 87
# val acc has not improved
# Epoch 36/100  train_loss: 0.30861  valid_loss 0.32991  valid_acc: 0.87447  lr: 0.009817  elapsed: 87
# val acc has not improved
# Epoch 37/100  train_loss: 0.28643  valid_loss 0.34185  valid_acc: 0.86934  lr: 0.009813  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 38, Accuracy : 0.8855678906917165
# Epoch 38/100  train_loss: 0.28505  valid_loss 0.33901  valid_acc: 0.88557  lr: 0.009815  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 39, Accuracy : 0.8906917164816396
# Epoch 39/100  train_loss: 0.27781  valid_loss 0.32661  valid_acc: 0.89069  lr: 0.009808  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 40, Accuracy : 0.8932536293766012
# Epoch 40/100  train_loss: 0.27473  valid_loss 0.32445  valid_acc: 0.89325  lr: 0.009806  elapsed: 87
# val acc has not improved
# Epoch 41/100  train_loss: 0.32485  valid_loss 0.56435  valid_acc: 0.79419  lr: 0.009804  elapsed: 87
# val acc has not improved
# Epoch 42/100  train_loss: 0.28825  valid_loss 0.37920  valid_acc: 0.87276  lr: 0.009845  elapsed: 87
# val acc has not improved
# Epoch 43/100  train_loss: 0.30599  valid_loss 0.39852  valid_acc: 0.85312  lr: 0.009813  elapsed: 87
# val acc has not improved
# Epoch 44/100  train_loss: 0.27414  valid_loss 0.35294  valid_acc: 0.87361  lr: 0.009822  elapsed: 87
# val acc has not improved
# Epoch 45/100  train_loss: 0.27329  valid_loss 0.36625  valid_acc: 0.87105  lr: 0.009813  elapsed: 87
# val acc has not improved
# Epoch 46/100  train_loss: 0.29944  valid_loss 0.36250  valid_acc: 0.87447  lr: 0.009814  elapsed: 88
# val acc has not improved
# Epoch 47/100  train_loss: 0.27924  valid_loss 0.33297  valid_acc: 0.89325  lr: 0.009813  elapsed: 88
# val acc has not improved
# Epoch 48/100  train_loss: 0.28396  valid_loss 0.42694  valid_acc: 0.86678  lr: 0.009804  elapsed: 87
# val acc has not improved
# Epoch 49/100  train_loss: 0.27168  valid_loss 0.33913  valid_acc: 0.88728  lr: 0.009816  elapsed: 87
# val acc has not improved
# Epoch 50/100  train_loss: 0.27143  valid_loss 0.38447  valid_acc: 0.87020  lr: 0.009807  elapsed: 87
# val acc has not improved
# Epoch 51/100  train_loss: 0.29675  valid_loss 0.35811  valid_acc: 0.86763  lr: 0.009814  elapsed: 87
# val acc has not improved
# Epoch 52/100  train_loss: 0.27197  valid_loss 0.38515  valid_acc: 0.86763  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 53/100  train_loss: 0.26889  valid_loss 0.40108  valid_acc: 0.86849  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 54/100  train_loss: 0.28056  valid_loss 0.39059  valid_acc: 0.86678  lr: 0.009815  elapsed: 87
# val acc has not improved
# Epoch 55/100  train_loss: 0.27248  valid_loss 0.34519  valid_acc: 0.88386  lr: 0.009816  elapsed: 87
# val acc has not improved
# Epoch 56/100  train_loss: 0.27019  valid_loss 0.38383  valid_acc: 0.86336  lr: 0.009808  elapsed: 87
# val acc has not improved
# Epoch 57/100  train_loss: 0.23977  valid_loss 0.36471  valid_acc: 0.87190  lr: 0.009817  elapsed: 87
# val acc has not improved
# Epoch 58/100  train_loss: 0.28079  valid_loss 0.33039  valid_acc: 0.88557  lr: 0.009814  elapsed: 87
# val acc has not improved
# Epoch 59/100  train_loss: 0.29454  valid_loss 0.36958  valid_acc: 0.86080  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 60/100  train_loss: 0.27410  valid_loss 0.37691  valid_acc: 0.87959  lr: 0.009818  elapsed: 87
# val acc has not improved
# Epoch 61/100  train_loss: 0.27414  valid_loss 0.35307  valid_acc: 0.88386  lr: 0.009810  elapsed: 87
# val acc has not improved
# Epoch 62/100  train_loss: 0.26536  valid_loss 0.35854  valid_acc: 0.87703  lr: 0.009808  elapsed: 87
# val acc has not improved
# Epoch 63/100  train_loss: 0.26156  valid_loss 0.32436  valid_acc: 0.88984  lr: 0.009811  elapsed: 87
# val acc has not improved
# Epoch 64/100  train_loss: 0.26366  valid_loss 0.35677  valid_acc: 0.87788  lr: 0.009806  elapsed: 88
# val acc has not improved
# Epoch 65/100  train_loss: 0.26200  valid_loss 0.35689  valid_acc: 0.87874  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 66/100  train_loss: 0.27473  valid_loss 0.31303  valid_acc: 0.88728  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 67/100  train_loss: 0.26273  valid_loss 0.32478  valid_acc: 0.88386  lr: 0.009807  elapsed: 88
# val acc has not improved
# Epoch 68/100  train_loss: 0.26572  valid_loss 0.44341  valid_acc: 0.85482  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 69/100  train_loss: 0.26819  valid_loss 0.32258  valid_acc: 0.87874  lr: 0.009821  elapsed: 88
# val acc has not improved
# Epoch 70/100  train_loss: 0.25114  valid_loss 0.56375  valid_acc: 0.79590  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 71/100  train_loss: 0.26240  valid_loss 0.35969  valid_acc: 0.87788  lr: 0.009845  elapsed: 87
# val acc has not improved
# Epoch 72/100  train_loss: 0.26277  valid_loss 0.36295  valid_acc: 0.87532  lr: 0.009811  elapsed: 87
# val acc has not improved
# Epoch 73/100  train_loss: 0.26642  valid_loss 0.34453  valid_acc: 0.87874  lr: 0.009812  elapsed: 88
# val acc has not improved
# Epoch 74/100  train_loss: 0.27880  valid_loss 0.30795  valid_acc: 0.88728  lr: 0.009811  elapsed: 87
# val acc has not improved
# Epoch 75/100  train_loss: 0.25548  valid_loss 0.34943  valid_acc: 0.87874  lr: 0.009807  elapsed: 87
# val acc has not improved
# Epoch 76/100  train_loss: 0.27180  valid_loss 0.34613  valid_acc: 0.88557  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 77/100  train_loss: 0.24667  valid_loss 0.35239  valid_acc: 0.87874  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 78/100  train_loss: 0.26815  valid_loss 0.36965  valid_acc: 0.87874  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 79/100  train_loss: 0.25205  valid_loss 0.37017  valid_acc: 0.87020  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 80/100  train_loss: 0.26115  valid_loss 0.41068  valid_acc: 0.85909  lr: 0.009814  elapsed: 87
# val acc has not improved
# Epoch 81/100  train_loss: 0.26423  valid_loss 0.39215  valid_acc: 0.85995  lr: 0.009819  elapsed: 87
# val acc has not improved
# Epoch 82/100  train_loss: 0.24652  valid_loss 0.35062  valid_acc: 0.87788  lr: 0.009819  elapsed: 87
# val acc has not improved
# Epoch 83/100  train_loss: 0.27594  valid_loss 0.31588  valid_acc: 0.89155  lr: 0.009811  elapsed: 87
# val acc has not improved
# Epoch 84/100  train_loss: 0.26443  valid_loss 0.29104  valid_acc: 0.89155  lr: 0.009805  elapsed: 87
# val acc has not improved
# Epoch 85/100  train_loss: 0.24625  valid_loss 0.34507  valid_acc: 0.88130  lr: 0.009805  elapsed: 87
# val acc has not improved
# Epoch 86/100  train_loss: 0.25288  valid_loss 0.35246  valid_acc: 0.88386  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 87/100  train_loss: 0.24974  valid_loss 0.32825  valid_acc: 0.88215  lr: 0.009808  elapsed: 89
# val acc has not improved
# Epoch 88/100  train_loss: 0.25005  valid_loss 0.32275  valid_acc: 0.88642  lr: 0.009809  elapsed: 87
# val acc has not improved
# Epoch 89/100  train_loss: 0.24637  valid_loss 0.32004  valid_acc: 0.89155  lr: 0.009807  elapsed: 87
# val acc has not improved
# Epoch 90/100  train_loss: 0.23484  valid_loss 0.30971  valid_acc: 0.89240  lr: 0.009805  elapsed: 87
# val acc has not improved
# Epoch 91/100  train_loss: 0.25109  valid_loss 0.37999  valid_acc: 0.86849  lr: 0.009805  elapsed: 88
# val acc has not improved
# Epoch 92/100  train_loss: 0.24275  valid_loss 0.36970  valid_acc: 0.87532  lr: 0.009815  elapsed: 87
# val acc has not improved
# Epoch 93/100  train_loss: 0.24934  valid_loss 0.31978  valid_acc: 0.88215  lr: 0.009812  elapsed: 87
# val acc has not improved
# Epoch 94/100  train_loss: 0.23633  valid_loss 0.35694  valid_acc: 0.87959  lr: 0.009809  elapsed: 88
# val acc has not improved
# Epoch 95/100  train_loss: 0.27662  valid_loss 0.33204  valid_acc: 0.88215  lr: 0.009810  elapsed: 87
# val acc has not improved
# Epoch 96/100  train_loss: 0.24656  valid_loss 0.39621  valid_acc: 0.87532  lr: 0.009809  elapsed: 87
# val acc has not improved
# Epoch 97/100  train_loss: 0.25936  valid_loss 0.40843  valid_acc: 0.86763  lr: 0.009812  elapsed: 87
# val acc has not improved
# Epoch 98/100  train_loss: 0.24990  valid_loss 0.30915  valid_acc: 0.88984  lr: 0.009815  elapsed: 87
# val acc has not improved
# Epoch 99/100  train_loss: 0.26981  valid_loss 0.33137  valid_acc: 0.87959  lr: 0.009806  elapsed: 87
# val acc has not improved
# Epoch 100/100  train_loss: 0.24709  valid_loss 0.33188  valid_acc: 0.88642  lr: 0.009810  elapsed: 87
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8932536293766012 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 0_th FOLD =================================
# predict values check :  [ 5.31870937  4.17411947 -0.99648154 -1.82862425 -2.51034212 -4.23580647]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7168.72it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.4560204953031597
# Epoch 1/100  train_loss: 2.43347  valid_loss 1.54765  valid_acc: 0.45602  lr: 0.010000  elapsed: 82
# val acc has not improved
# Epoch 2/100  train_loss: 1.56966  valid_loss 1.42263  valid_acc: 0.44150  lr: 0.009949  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.5072587532023911
# Epoch 3/100  train_loss: 1.46083  valid_loss 1.42207  valid_acc: 0.50726  lr: 0.009952  elapsed: 87
# val acc has not improved
# Epoch 4/100  train_loss: 1.39103  valid_loss 1.70119  valid_acc: 0.50299  lr: 0.009937  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5362937660119556
# Epoch 5/100  train_loss: 1.32162  valid_loss 1.31308  valid_acc: 0.53629  lr: 0.009938  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.6507258753202391
# Epoch 6/100  train_loss: 1.21025  valid_loss 0.99412  valid_acc: 0.65073  lr: 0.009929  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.6797608881298036
# Epoch 7/100  train_loss: 0.98220  valid_loss 0.87254  valid_acc: 0.67976  lr: 0.009896  elapsed: 89
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.7147736976942783
# Epoch 8/100  train_loss: 0.85765  valid_loss 0.76004  valid_acc: 0.71477  lr: 0.009886  elapsed: 90
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.7608881298035867
# Epoch 9/100  train_loss: 0.76300  valid_loss 0.88273  valid_acc: 0.76089  lr: 0.009874  elapsed: 89
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7873612297181896
# Epoch 10/100  train_loss: 0.67678  valid_loss 0.55803  valid_acc: 0.78736  lr: 0.009858  elapsed: 92
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 11, Accuracy : 0.802732707087959
# Epoch 11/100  train_loss: 0.60386  valid_loss 0.52994  valid_acc: 0.80273  lr: 0.009848  elapsed: 91
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.8104184457728437
# Epoch 12/100  train_loss: 0.52710  valid_loss 0.54598  valid_acc: 0.81042  lr: 0.009842  elapsed: 89
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.8146883005977796
# Epoch 13/100  train_loss: 0.51802  valid_loss 0.53581  valid_acc: 0.81469  lr: 0.009839  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 14, Accuracy : 0.82066609735269
# Epoch 14/100  train_loss: 0.49723  valid_loss 0.51124  valid_acc: 0.82067  lr: 0.009837  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 15, Accuracy : 0.8240819812126388
# Epoch 15/100  train_loss: 0.45561  valid_loss 0.51361  valid_acc: 0.82408  lr: 0.009835  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 16, Accuracy : 0.852263023057216
# Epoch 16/100  train_loss: 0.42652  valid_loss 0.47282  valid_acc: 0.85226  lr: 0.009833  elapsed: 88
# val acc has not improved
# Epoch 17/100  train_loss: 0.39217  valid_loss 0.53078  valid_acc: 0.85226  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 18/100  train_loss: 0.40243  valid_loss 0.42450  valid_acc: 0.85056  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 19/100  train_loss: 0.39311  valid_loss 0.45757  valid_acc: 0.84116  lr: 0.009823  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 20, Accuracy : 0.8642186165670367
# Epoch 20/100  train_loss: 0.37583  valid_loss 0.39133  valid_acc: 0.86422  lr: 0.009826  elapsed: 88
# val acc has not improved
# Epoch 21/100  train_loss: 0.36081  valid_loss 0.45533  valid_acc: 0.84116  lr: 0.009817  elapsed: 88
# val acc has not improved
# Epoch 22/100  train_loss: 0.36130  valid_loss 0.44712  valid_acc: 0.85568  lr: 0.009826  elapsed: 88
# val acc has not improved
# Epoch 23/100  train_loss: 0.34408  valid_loss 0.66701  valid_acc: 0.86080  lr: 0.009820  elapsed: 87
# val acc has not improved
# Epoch 24/100  train_loss: 0.33987  valid_loss 0.39180  valid_acc: 0.86166  lr: 0.009818  elapsed: 88
# val acc has not improved
# Epoch 25/100  train_loss: 0.33592  valid_loss 0.58029  valid_acc: 0.81981  lr: 0.009818  elapsed: 89
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 26, Accuracy : 0.8693424423569599
# Epoch 26/100  train_loss: 0.33753  valid_loss 0.38118  valid_acc: 0.86934  lr: 0.009835  elapsed: 90
# val acc has not improved
# Epoch 27/100  train_loss: 0.32202  valid_loss 0.43489  valid_acc: 0.86934  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 28/100  train_loss: 0.31950  valid_loss 0.45435  valid_acc: 0.85056  lr: 0.009815  elapsed: 89
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 29, Accuracy : 0.8770281810418445
# Epoch 29/100  train_loss: 0.32048  valid_loss 0.40665  valid_acc: 0.87703  lr: 0.009823  elapsed: 91
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 30, Accuracy : 0.8847139197267293
# Epoch 30/100  train_loss: 0.30407  valid_loss 0.35834  valid_acc: 0.88471  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 31/100  train_loss: 0.31543  valid_loss 0.41849  valid_acc: 0.85568  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 32/100  train_loss: 0.30139  valid_loss 0.37360  valid_acc: 0.88471  lr: 0.009820  elapsed: 88
# val acc has not improved
# Epoch 33/100  train_loss: 0.29596  valid_loss 0.41783  valid_acc: 0.88215  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 34/100  train_loss: 0.32162  valid_loss 0.41469  valid_acc: 0.85141  lr: 0.009809  elapsed: 88
# val acc has not improved
# Epoch 35/100  train_loss: 0.29026  valid_loss 0.36918  valid_acc: 0.86678  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 36/100  train_loss: 0.29392  valid_loss 0.38137  valid_acc: 0.85824  lr: 0.009816  elapsed: 88
# val acc has not improved
# Epoch 37/100  train_loss: 0.29621  valid_loss 0.40735  valid_acc: 0.85739  lr: 0.009819  elapsed: 88
# val acc has not improved
# Epoch 38/100  train_loss: 0.29207  valid_loss 0.42494  valid_acc: 0.85653  lr: 0.009820  elapsed: 88
# val acc has not improved
# Epoch 39/100  train_loss: 0.29200  valid_loss 0.38215  valid_acc: 0.87020  lr: 0.009820  elapsed: 88
# val acc has not improved
# Epoch 40/100  train_loss: 0.29556  valid_loss 0.46328  valid_acc: 0.84202  lr: 0.009814  elapsed: 88
# val acc has not improved
# Epoch 41/100  train_loss: 0.29382  valid_loss 0.68446  valid_acc: 0.83177  lr: 0.009826  elapsed: 89
# val acc has not improved
# Epoch 42/100  train_loss: 0.27943  valid_loss 0.41237  valid_acc: 0.85312  lr: 0.009830  elapsed: 89
# val acc has not improved
# Epoch 43/100  train_loss: 0.27041  valid_loss 0.36181  valid_acc: 0.88044  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 44/100  train_loss: 0.28633  valid_loss 0.40561  valid_acc: 0.86678  lr: 0.009810  elapsed: 89
# val acc has not improved
# Epoch 45/100  train_loss: 0.29218  valid_loss 0.31904  valid_acc: 0.87959  lr: 0.009816  elapsed: 92
# val acc has not improved
# Epoch 46/100  train_loss: 0.27852  valid_loss 0.38981  valid_acc: 0.87020  lr: 0.009810  elapsed: 91
# val acc has not improved
# Epoch 47/100  train_loss: 0.26353  valid_loss 0.37833  valid_acc: 0.88130  lr: 0.009814  elapsed: 89
# val acc has not improved
# Epoch 48/100  train_loss: 0.26473  valid_loss 0.36955  valid_acc: 0.87105  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 49/100  train_loss: 0.27792  valid_loss 0.50073  valid_acc: 0.84885  lr: 0.009814  elapsed: 88
# val acc has not improved
# Epoch 50/100  train_loss: 0.27227  valid_loss 0.42912  valid_acc: 0.85397  lr: 0.009823  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 51, Accuracy : 0.892399658411614
# Epoch 51/100  train_loss: 0.27898  valid_loss 0.31569  valid_acc: 0.89240  lr: 0.009821  elapsed: 88
# val acc has not improved
# Epoch 52/100  train_loss: 0.26256  valid_loss 0.40611  valid_acc: 0.86251  lr: 0.009805  elapsed: 88
# val acc has not improved
# Epoch 53/100  train_loss: 0.27854  valid_loss 0.52350  valid_acc: 0.84031  lr: 0.009818  elapsed: 88
# val acc has not improved
# Epoch 54/100  train_loss: 0.29810  valid_loss 0.40747  valid_acc: 0.86422  lr: 0.009827  elapsed: 87
# val acc has not improved
# Epoch 55/100  train_loss: 0.27134  valid_loss 0.40071  valid_acc: 0.86763  lr: 0.009817  elapsed: 87
# val acc has not improved
# Epoch 56/100  train_loss: 0.26741  valid_loss 0.47970  valid_acc: 0.84287  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 57/100  train_loss: 0.28599  valid_loss 0.35800  valid_acc: 0.87276  lr: 0.009826  elapsed: 88
# val acc has not improved
# Epoch 58/100  train_loss: 0.27068  valid_loss 0.35276  valid_acc: 0.86849  lr: 0.009813  elapsed: 88
# val acc has not improved
# Epoch 59/100  train_loss: 0.26062  valid_loss 0.41787  valid_acc: 0.85226  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 60/100  train_loss: 0.28498  valid_loss 0.43961  valid_acc: 0.85141  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 61/100  train_loss: 0.27772  valid_loss 0.36849  valid_acc: 0.87874  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 62/100  train_loss: 0.27071  valid_loss 0.42948  valid_acc: 0.85482  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 63/100  train_loss: 0.28464  valid_loss 0.40770  valid_acc: 0.86251  lr: 0.009821  elapsed: 88
# val acc has not improved
# Epoch 64/100  train_loss: 0.27761  valid_loss 0.41398  valid_acc: 0.85824  lr: 0.009818  elapsed: 87
# val acc has not improved
# Epoch 65/100  train_loss: 0.27667  valid_loss 0.50889  valid_acc: 0.82664  lr: 0.009819  elapsed: 88
# val acc has not improved
# Epoch 66/100  train_loss: 0.26987  valid_loss 0.38559  valid_acc: 0.85824  lr: 0.009832  elapsed: 88
# val acc has not improved
# Epoch 67/100  train_loss: 0.27108  valid_loss 0.42581  valid_acc: 0.84629  lr: 0.009819  elapsed: 87
# val acc has not improved
# Epoch 68/100  train_loss: 0.27445  valid_loss 0.37619  valid_acc: 0.86678  lr: 0.009824  elapsed: 88
# val acc has not improved
# Epoch 69/100  train_loss: 0.26601  valid_loss 0.48710  valid_acc: 0.83945  lr: 0.009816  elapsed: 88
# val acc has not improved
# Epoch 70/100  train_loss: 0.27180  valid_loss 0.35099  valid_acc: 0.88044  lr: 0.009827  elapsed: 87
# val acc has not improved
# Epoch 71/100  train_loss: 0.24011  valid_loss 0.34404  valid_acc: 0.87874  lr: 0.009810  elapsed: 87
# val acc has not improved
# Epoch 72/100  train_loss: 0.26973  valid_loss 0.45767  valid_acc: 0.84372  lr: 0.009811  elapsed: 87
# val acc has not improved
# Epoch 73/100  train_loss: 0.24659  valid_loss 0.39666  valid_acc: 0.87020  lr: 0.009825  elapsed: 87
# val acc has not improved
# Epoch 74/100  train_loss: 0.26706  valid_loss 0.37166  valid_acc: 0.86849  lr: 0.009814  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 75, Accuracy : 0.8949615713065756
# Epoch 75/100  train_loss: 0.25096  valid_loss 0.33036  valid_acc: 0.89496  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 76/100  train_loss: 0.27165  valid_loss 0.39101  valid_acc: 0.86934  lr: 0.009804  elapsed: 88
# val acc has not improved
# Epoch 77/100  train_loss: 0.24259  valid_loss 0.34091  valid_acc: 0.88471  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 78/100  train_loss: 0.25408  valid_loss 0.33861  valid_acc: 0.88898  lr: 0.009808  elapsed: 87
# val acc has not improved
# Epoch 79/100  train_loss: 0.26284  valid_loss 0.34328  valid_acc: 0.88642  lr: 0.009806  elapsed: 88
# val acc has not improved
# Epoch 80/100  train_loss: 0.24990  valid_loss 0.45551  valid_acc: 0.85056  lr: 0.009807  elapsed: 87
# val acc has not improved
# Epoch 81/100  train_loss: 0.24934  valid_loss 0.55502  valid_acc: 0.78907  lr: 0.009823  elapsed: 88
# val acc has not improved
# Epoch 82/100  train_loss: 0.25830  valid_loss 0.34213  valid_acc: 0.87874  lr: 0.009847  elapsed: 88
# val acc has not improved
# Epoch 83/100  train_loss: 0.24981  valid_loss 0.35991  valid_acc: 0.87874  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 84/100  train_loss: 0.25931  valid_loss 0.35839  valid_acc: 0.87447  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 85/100  train_loss: 0.26033  valid_loss 0.35091  valid_acc: 0.87020  lr: 0.009813  elapsed: 88
# val acc has not improved
# Epoch 86/100  train_loss: 0.25241  valid_loss 0.39233  valid_acc: 0.87276  lr: 0.009814  elapsed: 88
# val acc has not improved
# Epoch 87/100  train_loss: 0.24765  valid_loss 0.34189  valid_acc: 0.87874  lr: 0.009813  elapsed: 88
# val acc has not improved
# Epoch 88/100  train_loss: 0.26504  valid_loss 0.37740  valid_acc: 0.86507  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 89/100  train_loss: 0.24017  valid_loss 0.34817  valid_acc: 0.88044  lr: 0.009817  elapsed: 88
# val acc has not improved
# Epoch 90/100  train_loss: 0.24918  valid_loss 0.37860  valid_acc: 0.86678  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 91/100  train_loss: 0.26140  valid_loss 0.42107  valid_acc: 0.86678  lr: 0.009816  elapsed: 88
# val acc has not improved
# Epoch 92/100  train_loss: 0.24433  valid_loss 0.74072  valid_acc: 0.76260  lr: 0.009816  elapsed: 88
# val acc has not improved
# Epoch 93/100  train_loss: 0.26046  valid_loss 0.42447  valid_acc: 0.86678  lr: 0.009857  elapsed: 88
# val acc has not improved
# Epoch 94/100  train_loss: 0.25054  valid_loss 0.34024  valid_acc: 0.88130  lr: 0.009816  elapsed: 87
# val acc has not improved
# Epoch 95/100  train_loss: 0.25854  valid_loss 0.39347  valid_acc: 0.86080  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 96/100  train_loss: 0.25991  valid_loss 0.53539  valid_acc: 0.81725  lr: 0.009818  elapsed: 88
# val acc has not improved
# Epoch 97/100  train_loss: 0.24867  valid_loss 0.47413  valid_acc: 0.82750  lr: 0.009836  elapsed: 90
# val acc has not improved
# Epoch 98/100  train_loss: 0.23395  valid_loss 0.50219  valid_acc: 0.82494  lr: 0.009832  elapsed: 88
# val acc has not improved
# Epoch 99/100  train_loss: 0.25104  valid_loss 0.38139  valid_acc: 0.87020  lr: 0.009833  elapsed: 88
# val acc has not improved
# Epoch 100/100  train_loss: 0.27851  valid_loss 0.58695  valid_acc: 0.79932  lr: 0.009814  elapsed: 88
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8949615713065756 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 1_th FOLD =================================
# predict values check :  [ 5.43333578 -0.09870232  0.04868899  0.13333794 -3.13516903 -2.38632536]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 2_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7064.82it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.2946199829205807
# Epoch 1/100  train_loss: 2.48104  valid_loss 1.53611  valid_acc: 0.29462  lr: 0.010000  elapsed: 83
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.43979504696840305
# Epoch 2/100  train_loss: 1.53146  valid_loss 1.39620  valid_acc: 0.43980  lr: 0.009979  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.5388556789069172
# Epoch 3/100  train_loss: 1.44315  valid_loss 1.29000  valid_acc: 0.53886  lr: 0.009952  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.5755764304013663
# Epoch 4/100  train_loss: 1.34934  valid_loss 1.16201  valid_acc: 0.57558  lr: 0.009929  elapsed: 89
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.6823228010247652
# Epoch 5/100  train_loss: 1.18016  valid_loss 0.88157  valid_acc: 0.68232  lr: 0.009918  elapsed: 89
# val acc has not improved
# Epoch 6/100  train_loss: 1.05131  valid_loss 0.96112  valid_acc: 0.67720  lr: 0.009886  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.7788215200683177
# Epoch 7/100  train_loss: 0.95807  valid_loss 0.63856  valid_acc: 0.77882  lr: 0.009887  elapsed: 88
# val acc has not improved
# Epoch 8/100  train_loss: 0.83905  valid_loss 0.74981  valid_acc: 0.73954  lr: 0.009851  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.8274978650725875
# Epoch 9/100  train_loss: 0.75459  valid_loss 0.52388  valid_acc: 0.82750  lr: 0.009866  elapsed: 88
# val acc has not improved
# Epoch 10/100  train_loss: 0.69224  valid_loss 0.66364  valid_acc: 0.76857  lr: 0.009832  elapsed: 89
# val acc has not improved
# Epoch 11/100  train_loss: 0.63446  valid_loss 0.49417  valid_acc: 0.82664  lr: 0.009855  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.8377455166524338
# Epoch 12/100  train_loss: 0.58497  valid_loss 0.47660  valid_acc: 0.83775  lr: 0.009832  elapsed: 88
# val acc has not improved
# Epoch 13/100  train_loss: 0.54832  valid_loss 0.45428  valid_acc: 0.83604  lr: 0.009828  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 14, Accuracy : 0.8394534585824082
# Epoch 14/100  train_loss: 0.51412  valid_loss 0.44202  valid_acc: 0.83945  lr: 0.009829  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 15, Accuracy : 0.8761742100768574
# Epoch 15/100  train_loss: 0.50072  valid_loss 0.37092  valid_acc: 0.87617  lr: 0.009827  elapsed: 88
# val acc has not improved
# Epoch 16/100  train_loss: 0.48504  valid_loss 0.43934  valid_acc: 0.84287  lr: 0.009812  elapsed: 88
# val acc has not improved
# Epoch 17/100  train_loss: 0.46431  valid_loss 0.42617  valid_acc: 0.84372  lr: 0.009826  elapsed: 88
# val acc has not improved
# Epoch 18/100  train_loss: 0.42937  valid_loss 0.42904  valid_acc: 0.85056  lr: 0.009825  elapsed: 88
# val acc has not improved
# Epoch 19/100  train_loss: 0.42521  valid_loss 0.68307  valid_acc: 0.83177  lr: 0.009823  elapsed: 88
# val acc has not improved
# Epoch 20/100  train_loss: 0.41216  valid_loss 0.42731  valid_acc: 0.85568  lr: 0.009830  elapsed: 88
# val acc has not improved
# Epoch 21/100  train_loss: 0.39154  valid_loss 0.39483  valid_acc: 0.85824  lr: 0.009820  elapsed: 88
# val acc has not improved
# Epoch 22/100  train_loss: 0.36584  valid_loss 0.40742  valid_acc: 0.86251  lr: 0.009819  elapsed: 88
# val acc has not improved
# Epoch 23/100  train_loss: 0.35416  valid_loss 0.36590  valid_acc: 0.87020  lr: 0.009818  elapsed: 88
# val acc has not improved
# Epoch 24/100  train_loss: 0.34595  valid_loss 0.37368  valid_acc: 0.86593  lr: 0.009814  elapsed: 88
# val acc has not improved
# Epoch 25/100  train_loss: 0.34666  valid_loss 0.39322  valid_acc: 0.85824  lr: 0.009816  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 26, Accuracy : 0.8804440649017934
# Epoch 26/100  train_loss: 0.33202  valid_loss 0.34244  valid_acc: 0.88044  lr: 0.009819  elapsed: 88
# val acc has not improved
# Epoch 27/100  train_loss: 0.33925  valid_loss 0.45042  valid_acc: 0.85141  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 28/100  train_loss: 0.34190  valid_loss 0.40360  valid_acc: 0.85141  lr: 0.009822  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 29, Accuracy : 0.8864218616567037
# Epoch 29/100  train_loss: 0.33047  valid_loss 0.34101  valid_acc: 0.88642  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 30/100  train_loss: 0.31259  valid_loss 0.44937  valid_acc: 0.87105  lr: 0.009807  elapsed: 88
# val acc has not improved
# Epoch 31/100  train_loss: 0.31459  valid_loss 0.40688  valid_acc: 0.87361  lr: 0.009814  elapsed: 88
# val acc has not improved
# Epoch 32/100  train_loss: 0.31763  valid_loss 0.32842  valid_acc: 0.87532  lr: 0.009813  elapsed: 88
# val acc has not improved
# Epoch 33/100  train_loss: 0.33398  valid_loss 0.46314  valid_acc: 0.86166  lr: 0.009812  elapsed: 88
# val acc has not improved
# Epoch 34/100  train_loss: 0.30051  valid_loss 0.35874  valid_acc: 0.87276  lr: 0.009818  elapsed: 88
# val acc has not improved
# Epoch 35/100  train_loss: 0.28024  valid_loss 0.42201  valid_acc: 0.86251  lr: 0.009813  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 36, Accuracy : 0.8906917164816396
# Epoch 36/100  train_loss: 0.29530  valid_loss 0.27604  valid_acc: 0.89069  lr: 0.009818  elapsed: 88
# val acc has not improved
# Epoch 37/100  train_loss: 0.30320  valid_loss 0.33455  valid_acc: 0.88044  lr: 0.009806  elapsed: 88
# val acc has not improved
# Epoch 38/100  train_loss: 0.29451  valid_loss 0.42554  valid_acc: 0.83604  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 39/100  train_loss: 0.31585  valid_loss 0.41631  valid_acc: 0.86336  lr: 0.009829  elapsed: 88
# val acc has not improved
# Epoch 40/100  train_loss: 0.28552  valid_loss 0.51307  valid_acc: 0.84629  lr: 0.009817  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 41, Accuracy : 0.8915456874466268
# Epoch 41/100  train_loss: 0.31310  valid_loss 0.30113  valid_acc: 0.89155  lr: 0.009824  elapsed: 88
# val acc has not improved
# Epoch 42/100  train_loss: 0.28394  valid_loss 0.35224  valid_acc: 0.88557  lr: 0.009805  elapsed: 88
# val acc has not improved
# Epoch 43/100  train_loss: 0.25734  valid_loss 0.38794  valid_acc: 0.86336  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 44/100  train_loss: 0.27444  valid_loss 0.34109  valid_acc: 0.87276  lr: 0.009817  elapsed: 88
# val acc has not improved
# Epoch 45/100  train_loss: 0.27506  valid_loss 0.50083  valid_acc: 0.86849  lr: 0.009813  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 46, Accuracy : 0.8949615713065756
# Epoch 46/100  train_loss: 0.29755  valid_loss 0.29908  valid_acc: 0.89496  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 47/100  train_loss: 0.26895  valid_loss 0.31019  valid_acc: 0.89069  lr: 0.009804  elapsed: 90
# val acc has not improved
# Epoch 48/100  train_loss: 0.27587  valid_loss 0.37524  valid_acc: 0.87532  lr: 0.009806  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 49, Accuracy : 0.9000853970964987
# Epoch 49/100  train_loss: 0.28426  valid_loss 0.30853  valid_acc: 0.90009  lr: 0.009812  elapsed: 88
# val acc has not improved
# Epoch 50/100  train_loss: 0.27397  valid_loss 0.33231  valid_acc: 0.87361  lr: 0.009801  elapsed: 88
# val acc has not improved
# Epoch 51/100  train_loss: 0.29143  valid_loss 0.29133  valid_acc: 0.90009  lr: 0.009813  elapsed: 88
# val acc has not improved
# Epoch 52/100  train_loss: 0.27169  valid_loss 0.35585  valid_acc: 0.87959  lr: 0.009801  elapsed: 88
# val acc has not improved
# Epoch 53/100  train_loss: 0.27369  valid_loss 0.39820  valid_acc: 0.84799  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 54/100  train_loss: 0.27453  valid_loss 0.33053  valid_acc: 0.88471  lr: 0.009824  elapsed: 88
# val acc has not improved
# Epoch 55/100  train_loss: 0.30633  valid_loss 0.41261  valid_acc: 0.85568  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 56/100  train_loss: 0.27405  valid_loss 0.44242  valid_acc: 0.87361  lr: 0.009820  elapsed: 88
# val acc has not improved
# Epoch 57/100  train_loss: 0.30479  valid_loss 0.32661  valid_acc: 0.89582  lr: 0.009813  elapsed: 88
# val acc has not improved
# Epoch 58/100  train_loss: 0.27321  valid_loss 0.41198  valid_acc: 0.86678  lr: 0.009803  elapsed: 88
# val acc has not improved
# Epoch 59/100  train_loss: 0.27749  valid_loss 0.34419  valid_acc: 0.88130  lr: 0.009816  elapsed: 88
# val acc has not improved
# Epoch 60/100  train_loss: 0.27748  valid_loss 0.56025  valid_acc: 0.82152  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 61/100  train_loss: 0.28242  valid_loss 0.29862  valid_acc: 0.89325  lr: 0.009834  elapsed: 88
# val acc has not improved
# Epoch 62/100  train_loss: 0.27452  valid_loss 0.32315  valid_acc: 0.89582  lr: 0.009804  elapsed: 89
# val acc has not improved
# Epoch 63/100  train_loss: 0.26819  valid_loss 0.34518  valid_acc: 0.88301  lr: 0.009803  elapsed: 88
# val acc has not improved
# Epoch 64/100  train_loss: 0.25788  valid_loss 0.32960  valid_acc: 0.88471  lr: 0.009809  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 65, Accuracy : 0.9052092228864219
# Epoch 65/100  train_loss: 0.26689  valid_loss 0.25435  valid_acc: 0.90521  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 66/100  train_loss: 0.26387  valid_loss 0.33203  valid_acc: 0.89069  lr: 0.009799  elapsed: 88
# val acc has not improved
# Epoch 67/100  train_loss: 0.27138  valid_loss 0.46973  valid_acc: 0.83518  lr: 0.009806  elapsed: 88
# val acc has not improved
# Epoch 68/100  train_loss: 0.29051  valid_loss 0.32633  valid_acc: 0.88301  lr: 0.009829  elapsed: 88
# val acc has not improved
# Epoch 69/100  train_loss: 0.28816  valid_loss 0.33274  valid_acc: 0.88471  lr: 0.009809  elapsed: 88
# val acc has not improved
# Epoch 70/100  train_loss: 0.28980  valid_loss 0.32688  valid_acc: 0.88215  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 71/100  train_loss: 0.27900  valid_loss 0.34286  valid_acc: 0.89155  lr: 0.009809  elapsed: 88
# val acc has not improved
# Epoch 72/100  train_loss: 0.25386  valid_loss 0.30418  valid_acc: 0.88813  lr: 0.009805  elapsed: 88
# val acc has not improved
# Epoch 73/100  train_loss: 0.26360  valid_loss 0.34062  valid_acc: 0.87276  lr: 0.009807  elapsed: 88
# val acc has not improved
# Epoch 74/100  train_loss: 0.24806  valid_loss 0.32009  valid_acc: 0.88728  lr: 0.009813  elapsed: 88
# val acc has not improved
# Epoch 75/100  train_loss: 0.27290  valid_loss 0.40345  valid_acc: 0.85226  lr: 0.009807  elapsed: 88
# val acc has not improved
# Epoch 76/100  train_loss: 0.29070  valid_loss 0.33861  valid_acc: 0.87874  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 77/100  train_loss: 0.30341  valid_loss 0.34345  valid_acc: 0.88215  lr: 0.009811  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 78, Accuracy : 0.9077711357813835
# Epoch 78/100  train_loss: 0.26415  valid_loss 0.28096  valid_acc: 0.90777  lr: 0.009809  elapsed: 87
# val acc has not improved
# Epoch 79/100  train_loss: 0.25735  valid_loss 0.30589  valid_acc: 0.89155  lr: 0.009798  elapsed: 87
# val acc has not improved
# Epoch 80/100  train_loss: 0.26238  valid_loss 0.42447  valid_acc: 0.86849  lr: 0.009805  elapsed: 87
# val acc has not improved
# Epoch 81/100  train_loss: 0.26537  valid_loss 0.30629  valid_acc: 0.89496  lr: 0.009815  elapsed: 87
# val acc has not improved
# Epoch 82/100  train_loss: 0.24271  valid_loss 0.30566  valid_acc: 0.89496  lr: 0.009804  elapsed: 87
# val acc has not improved
# Epoch 83/100  train_loss: 0.27278  valid_loss 0.36866  valid_acc: 0.86422  lr: 0.009804  elapsed: 87
# val acc has not improved
# Epoch 84/100  train_loss: 0.25888  valid_loss 0.43725  valid_acc: 0.84287  lr: 0.009817  elapsed: 87
# val acc has not improved
# Epoch 85/100  train_loss: 0.25992  valid_loss 0.45577  valid_acc: 0.84629  lr: 0.009826  elapsed: 88
# val acc has not improved
# Epoch 86/100  train_loss: 0.24897  valid_loss 0.27904  valid_acc: 0.90692  lr: 0.009824  elapsed: 88
# val acc has not improved
# Epoch 87/100  train_loss: 0.26067  valid_loss 0.33658  valid_acc: 0.88044  lr: 0.009798  elapsed: 87
# val acc has not improved
# Epoch 88/100  train_loss: 0.25822  valid_loss 0.29280  valid_acc: 0.89582  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 89/100  train_loss: 0.23377  valid_loss 0.37279  valid_acc: 0.88386  lr: 0.009803  elapsed: 88
# val acc has not improved
# Epoch 90/100  train_loss: 0.24471  valid_loss 0.37192  valid_acc: 0.86678  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 91/100  train_loss: 0.25109  valid_loss 0.30700  valid_acc: 0.88898  lr: 0.009816  elapsed: 88
# val acc has not improved
# Epoch 92/100  train_loss: 0.24936  valid_loss 0.30295  valid_acc: 0.88557  lr: 0.009806  elapsed: 88
# val acc has not improved
# Epoch 93/100  train_loss: 0.23624  valid_loss 0.33694  valid_acc: 0.87788  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 94/100  train_loss: 0.26082  valid_loss 0.44143  valid_acc: 0.83006  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 95/100  train_loss: 0.25214  valid_loss 0.27645  valid_acc: 0.89155  lr: 0.009831  elapsed: 88
# val acc has not improved
# Epoch 96/100  train_loss: 0.24941  valid_loss 0.38326  valid_acc: 0.87020  lr: 0.009805  elapsed: 88
# val acc has not improved
# Epoch 97/100  train_loss: 0.24790  valid_loss 0.33643  valid_acc: 0.89325  lr: 0.009814  elapsed: 88
# val acc has not improved
# Epoch 98/100  train_loss: 0.25702  valid_loss 0.30951  valid_acc: 0.88557  lr: 0.009804  elapsed: 88
# val acc has not improved
# Epoch 99/100  train_loss: 0.25556  valid_loss 0.35349  valid_acc: 0.87617  lr: 0.009808  elapsed: 88
# val acc has not improved
# Epoch 100/100  train_loss: 0.25166  valid_loss 0.40659  valid_acc: 0.85824  lr: 0.009812  elapsed: 88
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.9077711357813835 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 2_th FOLD =================================
# predict values check :  [ 6.6504631  -0.97711807 -0.23170964  0.19234578 -3.5740068  -2.06374812]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 2_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 3_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7151.20it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4680
# number of valid images: 1170
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.294017094017094
# Epoch 1/100  train_loss: 2.53593  valid_loss 1.67760  valid_acc: 0.29402  lr: 0.010000  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.4393162393162393
# Epoch 2/100  train_loss: 1.53971  valid_loss 1.41951  valid_acc: 0.43932  lr: 0.009979  elapsed: 88
# val acc has not improved
# Epoch 3/100  train_loss: 1.49149  valid_loss 1.96168  valid_acc: 0.40598  lr: 0.009952  elapsed: 88
# val_acc has improved !!
# ...
# ========================== ༼ つ ◕_◕ ༽つ Model Load 3_th FOLD =================================
# predict values check :  [ 6.41929722 -0.37675408 -0.81399477 -0.05332035 -2.91866636 -2.26699233]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 3_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 4_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7275.70it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4683
# number of valid images: 1167
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.4361610968294773
# Epoch 1/100  train_loss: 2.36748  valid_loss 1.57851  valid_acc: 0.43616  lr: 0.010000  elapsed: 83
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.4481576692373608
# Epoch 2/100  train_loss: 1.54235  valid_loss 1.47614  valid_acc: 0.44816  lr: 0.009953  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.5244215938303342
# Epoch 3/100  train_loss: 1.46290  valid_loss 1.37636  valid_acc: 0.52442  lr: 0.009951  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.570694087403599
# Epoch 4/100  train_loss: 1.39509  valid_loss 1.20326  valid_acc: 0.57069  lr: 0.009932  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.6135389888603257
# Epoch 5/100  train_loss: 1.27033  valid_loss 1.04067  valid_acc: 0.61354  lr: 0.009920  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.6846615252784919
# Epoch 6/100  train_loss: 1.09217  valid_loss 0.92766  valid_acc: 0.68466  lr: 0.009907  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.7172236503856041
# Epoch 7/100  train_loss: 0.94732  valid_loss 1.00351  valid_acc: 0.71722  lr: 0.009885  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.7737789203084833
# Epoch 8/100  train_loss: 0.82653  valid_loss 0.80235  valid_acc: 0.77378  lr: 0.009874  elapsed: 86
# val acc has not improved
# Epoch 9/100  train_loss: 0.73552  valid_loss 0.75166  valid_acc: 0.73436  lr: 0.009853  elapsed: 86
# val acc has not improved
# Epoch 10/100  train_loss: 0.67378  valid_loss 0.83905  valid_acc: 0.76007  lr: 0.009868  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 11, Accuracy : 0.8140531276778064
# Epoch 11/100  train_loss: 0.58007  valid_loss 0.49184  valid_acc: 0.81405  lr: 0.009858  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.8191945158526135
# Epoch 12/100  train_loss: 0.53416  valid_loss 0.95192  valid_acc: 0.81919  lr: 0.009837  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.8243359040274207
# Epoch 13/100  train_loss: 0.50159  valid_loss 0.48736  valid_acc: 0.82434  lr: 0.009835  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 14, Accuracy : 0.8586118251928021
# Epoch 14/100  train_loss: 0.47433  valid_loss 0.42652  valid_acc: 0.85861  lr: 0.009833  elapsed: 85
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 15, Accuracy : 0.8620394173093402
# Epoch 15/100  train_loss: 0.45831  valid_loss 0.42832  valid_acc: 0.86204  lr: 0.009819  elapsed: 85
# val acc has not improved
# Epoch 16/100  train_loss: 0.42071  valid_loss 0.48318  valid_acc: 0.82262  lr: 0.009818  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.8757497857754927
# Epoch 17/100  train_loss: 0.40140  valid_loss 0.35581  valid_acc: 0.87575  lr: 0.009834  elapsed: 86
# val acc has not improved
# Epoch 18/100  train_loss: 0.38240  valid_loss 0.37191  valid_acc: 0.87489  lr: 0.009812  elapsed: 85
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 19, Accuracy : 0.8791773778920309
# Epoch 19/100  train_loss: 0.38171  valid_loss 0.47625  valid_acc: 0.87918  lr: 0.009812  elapsed: 85
# val acc has not improved
# Epoch 20/100  train_loss: 0.37341  valid_loss 0.39720  valid_acc: 0.86290  lr: 0.009811  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 21, Accuracy : 0.882604970008569
# Epoch 21/100  train_loss: 0.34842  valid_loss 0.35253  valid_acc: 0.88260  lr: 0.009817  elapsed: 86
# val acc has not improved
# Epoch 22/100  train_loss: 0.33168  valid_loss 0.45175  valid_acc: 0.84490  lr: 0.009809  elapsed: 86
# val acc has not improved
# Epoch 23/100  train_loss: 0.35237  valid_loss 0.38119  valid_acc: 0.86632  lr: 0.009825  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 24, Accuracy : 0.8920308483290489
# Epoch 24/100  train_loss: 0.32010  valid_loss 0.33616  valid_acc: 0.89203  lr: 0.009816  elapsed: 86
# val acc has not improved
# Epoch 25/100  train_loss: 0.32424  valid_loss 0.52956  valid_acc: 0.86118  lr: 0.009805  elapsed: 86
# val acc has not improved
# Epoch 26/100  train_loss: 0.31836  valid_loss 0.39821  valid_acc: 0.85604  lr: 0.009818  elapsed: 86
# val acc has not improved
# Epoch 27/100  train_loss: 0.30557  valid_loss 0.36525  valid_acc: 0.87661  lr: 0.009820  elapsed: 86
# val acc has not improved
# Epoch 28/100  train_loss: 0.30615  valid_loss 0.37781  valid_acc: 0.86118  lr: 0.009812  elapsed: 86
# val acc has not improved
# Epoch 29/100  train_loss: 0.30336  valid_loss 0.34118  valid_acc: 0.89117  lr: 0.009818  elapsed: 86
# val acc has not improved
# Epoch 30/100  train_loss: 0.29053  valid_loss 0.34987  valid_acc: 0.88518  lr: 0.009805  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 31, Accuracy : 0.895458440445587
# Epoch 31/100  train_loss: 0.29136  valid_loss 0.30428  valid_acc: 0.89546  lr: 0.009808  elapsed: 86
# val acc has not improved
# Epoch 32/100  train_loss: 0.28624  valid_loss 0.43454  valid_acc: 0.85004  lr: 0.009803  elapsed: 86
# val acc has not improved
# Epoch 33/100  train_loss: 0.29393  valid_loss 0.38185  valid_acc: 0.86889  lr: 0.009823  elapsed: 86
# val acc has not improved
# Epoch 34/100  train_loss: 0.27858  valid_loss 0.36820  valid_acc: 0.86804  lr: 0.009815  elapsed: 86
# val acc has not improved
# Epoch 35/100  train_loss: 0.27757  valid_loss 0.46805  valid_acc: 0.86375  lr: 0.009815  elapsed: 86
# val acc has not improved
# Epoch 36/100  train_loss: 0.27484  valid_loss 0.45032  valid_acc: 0.83719  lr: 0.009817  elapsed: 86
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 37, Accuracy : 0.910025706940874
# Epoch 37/100  train_loss: 0.28001  valid_loss 0.30205  valid_acc: 0.91003  lr: 0.009828  elapsed: 86
# val acc has not improved
# Epoch 38/100  train_loss: 0.29626  valid_loss 0.36541  valid_acc: 0.88003  lr: 0.009797  elapsed: 86
# val acc has not improved
# Epoch 39/100  train_loss: 0.28693  valid_loss 0.35885  valid_acc: 0.88003  lr: 0.009810  elapsed: 86
# val acc has not improved
# Epoch 40/100  train_loss: 0.28345  valid_loss 0.36956  valid_acc: 0.86632  lr: 0.009810  elapsed: 86
# val acc has not improved
# Epoch 41/100  train_loss: 0.26807  valid_loss 0.42986  valid_acc: 0.84062  lr: 0.009816  elapsed: 86
# val acc has not improved
# Epoch 42/100  train_loss: 0.27794  valid_loss 0.36480  valid_acc: 0.87575  lr: 0.009827  elapsed: 87
# val acc has not improved
# Epoch 43/100  train_loss: 0.26770  valid_loss 0.43141  valid_acc: 0.85861  lr: 0.009812  elapsed: 86
# val acc has not improved
# Epoch 44/100  train_loss: 0.26883  valid_loss 0.37205  valid_acc: 0.87489  lr: 0.009819  elapsed: 86
# val acc has not improved
# Epoch 45/100  train_loss: 0.26200  valid_loss 0.32927  valid_acc: 0.88260  lr: 0.009812  elapsed: 86
# val acc has not improved
# Epoch 46/100  train_loss: 0.26303  valid_loss 0.31091  valid_acc: 0.89717  lr: 0.009809  elapsed: 85
# val acc has not improved
# Epoch 47/100  train_loss: 0.26402  valid_loss 0.32523  valid_acc: 0.89289  lr: 0.009803  elapsed: 86
# val acc has not improved
# Epoch 48/100  train_loss: 0.25667  valid_loss 0.35025  valid_acc: 0.88603  lr: 0.009805  elapsed: 86
# val acc has not improved
# Epoch 49/100  train_loss: 0.25401  valid_loss 0.31312  valid_acc: 0.88775  lr: 0.009808  elapsed: 85
# val acc has not improved
# Epoch 50/100  train_loss: 0.27212  valid_loss 0.41448  valid_acc: 0.85347  lr: 0.009807  elapsed: 86
# val acc has not improved
# Epoch 51/100  train_loss: 0.26448  valid_loss 0.33494  valid_acc: 0.88775  lr: 0.009821  elapsed: 85
# val acc has not improved
# Epoch 52/100  train_loss: 0.25599  valid_loss 0.30260  valid_acc: 0.89374  lr: 0.009807  elapsed: 86
# val acc has not improved
# Epoch 53/100  train_loss: 0.24813  valid_loss 0.32046  valid_acc: 0.88432  lr: 0.009804  elapsed: 86
# val acc has not improved
# Epoch 54/100  train_loss: 0.24478  valid_loss 0.36727  valid_acc: 0.88518  lr: 0.009808  elapsed: 86
# val acc has not improved
# Epoch 55/100  train_loss: 0.25174  valid_loss 0.31851  valid_acc: 0.88946  lr: 0.009808  elapsed: 86
# val acc has not improved
# Epoch 56/100  train_loss: 0.27496  valid_loss 0.29671  valid_acc: 0.89889  lr: 0.009806  elapsed: 86
# val acc has not improved
# Epoch 57/100  train_loss: 0.23666  valid_loss 0.44708  valid_acc: 0.83205  lr: 0.009802  elapsed: 86
# val acc has not improved
# Epoch 58/100  train_loss: 0.26125  valid_loss 0.34099  valid_acc: 0.87404  lr: 0.009830  elapsed: 86
# val acc has not improved
# Epoch 59/100  train_loss: 0.26358  valid_loss 0.36544  valid_acc: 0.88860  lr: 0.009813  elapsed: 86
# val acc has not improved
# Epoch 60/100  train_loss: 0.24583  valid_loss 0.37306  valid_acc: 0.86547  lr: 0.009806  elapsed: 85
# val acc has not improved
# Epoch 61/100  train_loss: 0.26674  valid_loss 0.36486  valid_acc: 0.87404  lr: 0.009816  elapsed: 85
# val acc has not improved
# Epoch 62/100  train_loss: 0.26238  valid_loss 0.35722  valid_acc: 0.87746  lr: 0.009813  elapsed: 85
# val acc has not improved
# Epoch 63/100  train_loss: 0.26220  valid_loss 0.38131  valid_acc: 0.87147  lr: 0.009811  elapsed: 85
# val acc has not improved
# Epoch 64/100  train_loss: 0.25212  valid_loss 0.38075  valid_acc: 0.86461  lr: 0.009814  elapsed: 86
# val acc has not improved
# Epoch 65/100  train_loss: 0.26626  valid_loss 0.31921  valid_acc: 0.89632  lr: 0.009817  elapsed: 86
# val acc has not improved
# Epoch 66/100  train_loss: 0.25359  valid_loss 0.34041  valid_acc: 0.88775  lr: 0.009803  elapsed: 86
# val acc has not improved
# Epoch 67/100  train_loss: 0.26679  valid_loss 0.33600  valid_acc: 0.88346  lr: 0.009807  elapsed: 86
# val acc has not improved
# Epoch 68/100  train_loss: 0.25395  valid_loss 0.32215  valid_acc: 0.88175  lr: 0.009809  elapsed: 86
# val acc has not improved
# Epoch 69/100  train_loss: 0.26575  valid_loss 0.31377  valid_acc: 0.89289  lr: 0.009809  elapsed: 86
# val acc has not improved
# Epoch 70/100  train_loss: 0.26629  valid_loss 0.32937  valid_acc: 0.89460  lr: 0.009805  elapsed: 85
# val acc has not improved
# Epoch 71/100  train_loss: 0.25691  valid_loss 0.32259  valid_acc: 0.89289  lr: 0.009804  elapsed: 85
# val acc has not improved
# Epoch 72/100  train_loss: 0.25103  valid_loss 0.35283  valid_acc: 0.87918  lr: 0.009805  elapsed: 86
# val acc has not improved
# Epoch 73/100  train_loss: 0.24505  valid_loss 0.31370  valid_acc: 0.90231  lr: 0.009811  elapsed: 85
# val acc has not improved
# Epoch 74/100  train_loss: 0.24406  valid_loss 0.35607  valid_acc: 0.87232  lr: 0.009800  elapsed: 85
# val acc has not improved
# Epoch 75/100  train_loss: 0.25309  valid_loss 0.35265  valid_acc: 0.88089  lr: 0.009813  elapsed: 85
# val acc has not improved
# Epoch 76/100  train_loss: 0.24874  valid_loss 0.29866  valid_acc: 0.90403  lr: 0.009810  elapsed: 86
# val acc has not improved
# Epoch 77/100  train_loss: 0.24070  valid_loss 0.52655  valid_acc: 0.81148  lr: 0.009800  elapsed: 88
# val acc has not improved
# Epoch 78/100  train_loss: 0.26331  valid_loss 0.33504  valid_acc: 0.89032  lr: 0.009838  elapsed: 86
# val acc has not improved
# Epoch 79/100  train_loss: 0.25315  valid_loss 0.37462  valid_acc: 0.87489  lr: 0.009806  elapsed: 86
# val acc has not improved
# Epoch 80/100  train_loss: 0.25316  valid_loss 0.30392  valid_acc: 0.90403  lr: 0.009812  elapsed: 86
# val acc has not improved
# Epoch 81/100  train_loss: 0.22952  valid_loss 0.33769  valid_acc: 0.88689  lr: 0.009800  elapsed: 86
# val acc has not improved
# Epoch 82/100  train_loss: 0.23130  valid_loss 0.38600  valid_acc: 0.88003  lr: 0.009807  elapsed: 85
# val acc has not improved
# Epoch 83/100  train_loss: 0.24106  valid_loss 0.29340  valid_acc: 0.90317  lr: 0.009810  elapsed: 85
# val acc has not improved
# Epoch 84/100  train_loss: 0.24880  valid_loss 0.31967  valid_acc: 0.89117  lr: 0.009800  elapsed: 86
# val acc has not improved
# Epoch 85/100  train_loss: 0.25879  valid_loss 0.30917  valid_acc: 0.90060  lr: 0.009805  elapsed: 86
# val acc has not improved
# Epoch 86/100  train_loss: 0.24704  valid_loss 0.50579  valid_acc: 0.82005  lr: 0.009801  elapsed: 86
# val acc has not improved
# Epoch 87/100  train_loss: 0.24196  valid_loss 0.38849  valid_acc: 0.87661  lr: 0.009835  elapsed: 86
# val acc has not improved
# Epoch 88/100  train_loss: 0.25985  valid_loss 0.35376  valid_acc: 0.87404  lr: 0.009812  elapsed: 85
# val acc has not improved
# Epoch 89/100  train_loss: 0.26412  valid_loss 0.35113  valid_acc: 0.87832  lr: 0.009813  elapsed: 85
# val acc has not improved
# Epoch 90/100  train_loss: 0.25005  valid_loss 0.31904  valid_acc: 0.89546  lr: 0.009811  elapsed: 85
# val acc has not improved
# Epoch 91/100  train_loss: 0.24408  valid_loss 0.39715  valid_acc: 0.84662  lr: 0.009803  elapsed: 86
# val acc has not improved
# Epoch 92/100  train_loss: 0.25796  valid_loss 0.37343  valid_acc: 0.87489  lr: 0.009824  elapsed: 85
# val acc has not improved
# Epoch 93/100  train_loss: 0.24091  valid_loss 0.28403  valid_acc: 0.90746  lr: 0.009812  elapsed: 85
# val acc has not improved
# Epoch 94/100  train_loss: 0.23660  valid_loss 0.32391  valid_acc: 0.89032  lr: 0.009798  elapsed: 86
# val acc has not improved
# Epoch 95/100  train_loss: 0.24659  valid_loss 0.29256  valid_acc: 0.90488  lr: 0.009806  elapsed: 85
# val acc has not improved
# Epoch 96/100  train_loss: 0.25020  valid_loss 0.29078  valid_acc: 0.90574  lr: 0.009799  elapsed: 86
# val acc has not improved
# Epoch 97/100  train_loss: 0.25953  valid_loss 0.33332  valid_acc: 0.88346  lr: 0.009799  elapsed: 86
# val acc has not improved
# Epoch 98/100  train_loss: 0.23206  valid_loss 0.32713  valid_acc: 0.89203  lr: 0.009809  elapsed: 85
# val acc has not improved
# Epoch 99/100  train_loss: 0.26175  valid_loss 0.39057  valid_acc: 0.86461  lr: 0.009805  elapsed: 85
# val acc has not improved
# Epoch 100/100  train_loss: 0.26771  valid_loss 0.28759  valid_acc: 0.89546  lr: 0.009817  elapsed: 85
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.910025706940874 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 4_th FOLD =================================
# predict values check :  [ 6.44494629  0.36833781 -0.89352256  0.47639725 -2.97478914 -3.52153826]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 4_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
