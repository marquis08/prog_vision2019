# %% [markdown]
# # 세원님 baseline
# ---
# # - changes
#     model : resnext101_32x8d_wsl
#     transforms
#     optimizer -- SGD
#     scheduler -- cosineannealing
# ---

# %%
import gc
import os
import time
import numpy as np
import pandas as pd
from glob import glob
import tqdm
import argparse
import tqdm
from collections import defaultdict, Counter
from PIL import Image
import cv2

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch import nn, cuda
from torch.autograd import Variable 
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import CenterCrop

from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR
from utils import count_parameters, seed_everything, AdamW, CosineAnnealingWithRestartsLR

from efficientnet_pytorch import EfficientNet
import torchvision.models as models

from model import Baseline, Resnet18, Resnet50, Resnext50, Resnext101
from customs import mixup_data, mixup_criterion
from transforms import get_transform
from dataloader import make_loader, TestDataset

from torchvision.models.resnet import ResNet, Bottleneck

def _resnext(arch, block, layers, pretrained, progress, **kwargs):
    model = ResNet(block, layers, **kwargs)
# below 2 codes indicates not using pretrained weights
#     state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
#     model.load_state_dict(state_dict)
    return model

def resnext101_32x8d_wsl(progress=True, **kwargs):
    """Constructs a ResNeXt-101 32x8 model pre-trained on weakly-supervised data
    and finetuned on ImageNet from Figure 5 in
    `"Exploring the Limits of Weakly Supervised Pretraining" <https://arxiv.org/abs/1805.00932>`_
    Args:
        progress (bool): If True, displays a progress bar of the download to stderr.
    """
    kwargs['groups'] = 32
    kwargs['width_per_group'] = 8
    return _resnext('resnext101_32x8d', Bottleneck, [3, 4, 23, 3], False, progress, **kwargs)

def to_numpy(t):
        return t.cpu().detach().numpy()

def make_folds(df, n_folds: int) -> pd.DataFrame:

    cls_counts = Counter([classes for classes in df['label']])
    fold_cls_counts = defaultdict()
    for class_index in cls_counts.keys():
        fold_cls_counts[class_index] = np.zeros(n_folds, dtype=np.int)

    df['fold'] = -1
    pbar = tqdm.tqdm(total=len(df))

    def get_fold(row):
        class_index = row['label']
        counts = fold_cls_counts[class_index]
        fold = np.argmin(counts)
        counts[fold] += 1
        fold_cls_counts[class_index] = counts
        row['fold']=fold
        pbar.update()
        return row

    df = df.apply(get_fold, axis=1)
    return df

def make_label(label):
    if label == 'MA':
        return 1
    elif label == 'GMA':
        return 2
    elif label == 'BOY':
        return 3
    elif label == 'FA':
        return 4
    elif label == 'GFA':
        return 5
    #elif label == 'GIRL':
    else:
        return 6


class TrainDataset(Dataset):
    def __init__(self, df, mode='train', transforms=None):
        self.df = df
        self.mode = mode
        self.transform = transforms[self.mode]

    def __len__(self):            
        return len(self.df)

    def __getitem__(self, idx):

        image = Image.open(IMAGES_PATH + '/' + self.df['filename'][idx]).convert("RGB")

        if self.transform:
            image = self.transform(image)
        label = self.df['label'][idx]

        return image, label

def make_loader(df, transforms, batch_size=256, num_workers=0):

    dataset = TrainDataset(df, transforms2)
    # dataset = image, label from Glass_Dataset

    loader = DataLoader(dataset, # image, label
                        batch_size=batch_size,
                        shuffle=True, 
                        num_workers=num_workers, 
                        pin_memory=True)

    return loader

class TestDataset(Dataset):
        def __init__(self, df, transform=None):
            self.df = df
            self.transform = transform

        def __len__(self):
            return len(self.df)

        def __getitem__(self, idx):

            image = Image.open(IMAGES_PATH+'/'+self.df['filename'][idx]).convert('RGB')

            if self.transform:
                image = self.transform(image)

            return image

IMAGES_PATH = 'C:/SEOYILGUK/JOB_VISION/faces_images'
csv_path = 'C:/SEOYILGUK/JOB_VISION/train.csv'
train_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/train.csv')
test_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/test.csv')

def make_df(image_path, csv_path):
    csv_df = pd.read_csv(csv_path)
    path_df = pd.DataFrame()
    file_list = os.listdir(image_path)
    path_df['filename'] = file_list
    path_df = path_df.iloc[1:,:] # remove .DS_Store filename
    df = csv_df.merge(path_df, on='filename', how='left')
    df['label'] = df['label']-1
    print(df.label.value_counts())
    return df

#num_fold = 0 #select fold number for training
for num_fold in range(5):
    
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 STARTS {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
    train_csv = pd.read_csv("../JOB_VISION/train.csv")

    

    SEED = 42
    seed_everything(SEED)

    device = 'cuda'
    use_gpu = cuda.is_available()

    if use_gpu:
        print("enable gpu use")
    else:
        print("enable cpu for debugging")

    target_size = (128, 128)

    num_classes = 6
    model = resnext101_32x8d_wsl(num_classes=num_classes)
    model.cuda()

    #model = models.resnet50() 
    #model.fc = nn.Linear(2048, args.num_classes)

    # elif args.model == 'resnet18': 
    #     model = Resnet18(args.num_classes, dropout=False)
    # elif args.model == 'resnet50':
    #     model = Resnet50(args.num_classes, dropout=False)
    # elif args.model == 'efficient':
    #     model = EfficientNet.from_pretrained('efficientnet-b0')
    #     in_features = model._fc.in_features
    #     model._fc = nn.Linear(in_features, args.num_classes)
    # elif args.model == 'densenet201':
    #     model = models.densenet201(pretrained=True)
    #     model.classifier = nn.Linear(1920, args.num_classes)
    # elif args.model == 'resnext50':
    #     model = Resnext50(args.num_classes, dropout=False)
    # elif args.model == 'resnext101':
    #     model = Resnext101(args.num_classes, dropout=False)
    # elif args.model == 'mobilenet':
    #     assert args.input_size == 158
    #     model = torch.hub.load('pytorch/vision', 'mobilenet_v2', pretrained=True)
    #     model.classifier = nn.Sequential(nn.Dropout(0.2),
    #                         nn.Linear(1280, args.num_classes))
    # else:
    #     raise NotImplementedError

    if use_gpu:
        model = model.to(device)

    # optimizer = optim.Adam(model.parameters(), args.lr, weight_decay=0.00025)
    #optimizer = AdamW(model.parameters(), 2.5e-4, weight_decay=0.000025)
    optimizer = optim.SGD(model.parameters(), 0.01, momentum=0.9, weight_decay=0.0025)

    ###### SCHEDULER #######
    #scheduler = ReduceLROnPlateau(optimizer, 'max', patience=5, factor=0.5)

    eta_min = 0.000001
    T_max = 10
    T_mult = 1
    restart_decay = 0.97
    scheduler = CosineAnnealingWithRestartsLR(optimizer, T_max=T_max, eta_min=eta_min, T_mult=T_mult, restart_decay=restart_decay)

    #scheduler = StepLR(optimizer, step_size=5, gamma=0.5)

    criterion = nn.CrossEntropyLoss() 

    num_parameters = count_parameters(model)
    print("==== number of parameters that can be trained: {}".format(num_parameters))

    df = make_df(IMAGES_PATH, csv_path)

    # 5 stratifiedKFold
    folds = make_folds(df, 5)
    print("==== fold_df created")
    print(folds.head())

    train_df = folds[folds['fold'] != num_fold]
    valid_df = folds[folds['fold'] == num_fold]

    train_df = train_df[['filename', 'label']].reset_index(drop=True)
    valid_df = valid_df[['filename', 'label']].reset_index(drop=True)
    print("number of train images: {}".format(len(train_df)))
    print("number of valid images: {}".format(len(valid_df)))

    start_time = time.time()
    
    print("shape of the df: {}".format(df.shape))    
    
    data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(target_size, scale=(0.7, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(
                brightness=0.4,
                contrast=0.4,
                saturation=0.4,
            ),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5161, 0.4225, 0.3763], 
            [0.2442, 0.2184, 0.2164]
        )]),
    'valid': transforms.Compose([
        transforms.RandomResizedCrop(target_size, scale=(0.8, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5161, 0.4225, 0.3763], 
            [0.2442, 0.2184, 0.2164]
        )])
    }
    
    batch_size = 32
    train_dataset = TrainDataset(train_df, mode='train', transforms=data_transforms)
    valid_dataset = TrainDataset(valid_df, mode='valid', transforms=data_transforms)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    print("number train batches: {}".format(len(train_loader)))
    print("number valid batches: {}".format(len(valid_loader)))
    elapsed = time.time() - start_time
    print("elapsed: {:.0f}".format(elapsed))

    best_val_acc = 0
    grad_clip_step = 100
    grad_clip = 100
    step = 0
    # accumulation_step = 2

    print("start training")

    for epoch_idx in range(1, 100 + 1):

        start_time = time.time()

        train_loss = 0
        train_total_correct = 0
        model.train()
        optimizer.zero_grad()

        for batch_idx, (image, labels) in enumerate(train_loader):
            if use_gpu:
                image = image.to(device)
                labels = labels.to(device)

            # print("shape of the image: {}".format(image.shape))
            # print("shape of the labels: {}".format(labels.shape))
            # print(image)
            # print(labels)

            #if args.mixup_loss:
            #    inputs, targets_a, targets_b, lam = mixup_data(image, labels, alpha=0.4, device=device)
            #    inputs, targets_a, targets_b = map(Variable, (inputs, targets_a, targets_b))
            #    output = model(inputs)
            #    loss = mixup_criterion(criterion, output.to(device), targets_a.to(device), targets_b.to(device), lam)
            #else:
            output = model(image)
            loss = criterion(output, labels)

            # gradient explosion prevention
            if step > grad_clip_step:
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

            step += 1

            loss.backward()

            optimizer.step()
            optimizer.zero_grad()

            # output_prob = F.softmax(output, dim=1)

            train_loss += loss.item() / len(train_loader)

        # Validation Starts
        model.eval()
        valid_loss = 0
        valid_total_correct = 0

        with torch.no_grad():
            for batch_idx, (image, labels) in enumerate(valid_loader):
                if use_gpu:
                    image = image.to(device)
                    labels = labels.to(device)


                output = model(image)
                loss = criterion(output, labels)

                output_prob = F.softmax(output, dim=1)

                predict_vector = np.argmax(to_numpy(output_prob), axis=1)
                label_vector = to_numpy(labels)
                bool_vector = predict_vector == label_vector
                #print('val_pred', predict_vector[:5])
                #print('val_label', label_vector[:5])
                #print("shape of prediction vector: {}".format(predict_vector.shape))
                #print(predict_vector.head())
                #print("shape of label vector: {}".format(label_vector.shape))

                valid_loss += loss.item() / len(valid_loader)
                valid_total_correct += bool_vector.sum()


        elapsed = time.time() - start_time

        val_acc = valid_total_correct / len(valid_loader.dataset)

        # best val_acc checkpoint
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            print("val_acc has improved !! ")
            torch.save(model.state_dict(), 'resnext101_32x8d_wsl_fold_{}_best_model.pt'.format(num_fold))
            print("================ ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ".format(epoch_idx, best_val_acc))
            #file_save_name = 'best_acc' + '_' + str(num_fold)
            #print(file_save_name)
        else:
            print("val acc has not improved")

        lr = [_['lr'] for _ in optimizer.param_groups]

        #if args.scheduler == 'plateau':
        scheduler.step(val_acc)
        #else:
        #    scheduler.step()

        # nsml.save(epoch_idx)

        print("Epoch {}/{}  train_loss: {:.5f}  valid_loss {:.5f}  valid_acc: {:.5f}  lr: {:.6f}  elapsed: {:.0f}".format(
               epoch_idx, 100, train_loss, valid_loss, val_acc, lr[0], elapsed))
                #epoch_idx, args.epochs, train_loss, valid_loss, val_acc, lr[0], elapsed

#    IMAGES_PATH = 'C:/SEOYILGUK/JOB_VISION/faces_images'
#    test_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/test.csv')

    batch_size = 32
    num_workers = 0

    # model = models.resnet18(pretrained=False) 
    # model.fc = nn.Linear(512, args.num_classes)

    # checkpoint = 'team012/KHD2019_FUNDUS/93'
    # nsml.load(checkpoint, load_fn=load)

    test_transforms = transforms.Compose([
                        transforms.RandomResizedCrop(target_size, scale=(0.8, 1.0)),
                        transforms.RandomHorizontalFlip(),
                        transforms.ToTensor(),
                        transforms.Normalize(
                            [0.5161, 0.4225, 0.3763], 
                            [0.2442, 0.2184, 0.2164])
                    ])

    test_dataset = TestDataset(test_df, test_transforms)
    test_loader = DataLoader(test_dataset,
                             batch_size=batch_size,
                             shuffle=False, 
                             num_workers=num_workers, 
                             pin_memory=True)
    
    print("============== ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ====================================".format(epoch_idx, best_val_acc))
    print("========================== ༼ つ ◕_◕ ༽つ Model Load {}_th FOLD =================================".format(num_fold))
    model.load_state_dict(torch.load('resnext101_32x8d_wsl_fold_{}_best_model.pt'.format(num_fold)))

    model.eval()
    # for _ in range(tta):
        # print("tta {} predict".format(_+1))
    predictions = np.zeros((len(test_loader.dataset), 6))

    with torch.no_grad():
        for i, image in enumerate(test_loader):
            image = image.to(device)
            output = model(image) # output shape (batch_num, num_classes)

            predictions[i*batch_size: (i+1)*batch_size] = output.detach().cpu().numpy()
    print("predict values check : ",predictions[0])
    np.savetxt("../JOB_VISION/resnext101_32x8d_wsl_submission/resnext101_32x8d_wsl_{}_fold.csv".format(num_fold), predictions, delimiter=",")
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 SAVED {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
# Out:
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7567.51it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43296327924850553
# Epoch 1/100  train_loss: 2.65371  valid_loss 1.79770  valid_acc: 0.43296  lr: 0.010000  elapsed: 77
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.4987190435525192
# Epoch 2/100  train_loss: 1.51354  valid_loss 1.82631  valid_acc: 0.49872  lr: 0.009954  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.5217762596071733
# Epoch 3/100  train_loss: 1.43857  valid_loss 1.40180  valid_acc: 0.52178  lr: 0.009939  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.5619128949615713
# Epoch 4/100  train_loss: 1.37103  valid_loss 1.29201  valid_acc: 0.56191  lr: 0.009933  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5713065755764304
# Epoch 5/100  train_loss: 1.32028  valid_loss 1.77293  valid_acc: 0.57131  lr: 0.009922  elapsed: 82
# val acc has not improved
# Epoch 6/100  train_loss: 1.26005  valid_loss 1.34543  valid_acc: 0.56106  lr: 0.009920  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.6635354397950469
# Epoch 7/100  train_loss: 1.13660  valid_loss 0.91387  valid_acc: 0.66354  lr: 0.009923  elapsed: 82
# val acc has not improved
# Epoch 8/100  train_loss: 0.98816  valid_loss 0.98625  valid_acc: 0.66183  lr: 0.009892  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.726729291204099
# Epoch 9/100  train_loss: 0.87878  valid_loss 0.91676  valid_acc: 0.72673  lr: 0.009892  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7805294619982921
# Epoch 10/100  train_loss: 0.78344  valid_loss 0.60430  valid_acc: 0.78053  lr: 0.009870  elapsed: 82
# val acc has not improved
# Epoch 11/100  train_loss: 0.70724  valid_loss 0.99660  valid_acc: 0.72417  lr: 0.009850  elapsed: 82
# val acc has not improved
# Epoch 12/100  train_loss: 0.67118  valid_loss 0.78470  valid_acc: 0.77626  lr: 0.009871  elapsed: 82
# val acc has not improved
# Epoch 13/100  train_loss: 0.62635  valid_loss 0.88414  valid_acc: 0.76687  lr: 0.009852  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 14, Accuracy : 0.816396242527754
# Epoch 14/100  train_loss: 0.58554  valid_loss 0.50805  valid_acc: 0.81640  lr: 0.009856  elapsed: 82
# val acc has not improved
# Epoch 15/100  train_loss: 0.54735  valid_loss 0.55098  valid_acc: 0.81298  lr: 0.009836  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 16, Accuracy : 0.842869342442357
# Epoch 16/100  train_loss: 0.48858  valid_loss 0.48706  valid_acc: 0.84287  lr: 0.009838  elapsed: 82
# val acc has not improved
# Epoch 17/100  train_loss: 0.47289  valid_loss 0.60998  valid_acc: 0.82323  lr: 0.009826  elapsed: 82
# val acc has not improved
# Epoch 18/100  train_loss: 0.48480  valid_loss 0.54355  valid_acc: 0.81810  lr: 0.009834  elapsed: 82
# val acc has not improved
# Epoch 19/100  train_loss: 0.44687  valid_loss 1.44210  valid_acc: 0.79590  lr: 0.009836  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 20, Accuracy : 0.8497011101622545
# Epoch 20/100  train_loss: 0.41616  valid_loss 0.47092  valid_acc: 0.84970  lr: 0.009845  elapsed: 82
# val acc has not improved
# Epoch 21/100  train_loss: 0.41318  valid_loss 0.52489  valid_acc: 0.84714  lr: 0.009823  elapsed: 82
# val acc has not improved
# Epoch 22/100  train_loss: 0.41071  valid_loss 0.52127  valid_acc: 0.84116  lr: 0.009824  elapsed: 82
# val acc has not improved
# Epoch 23/100  train_loss: 0.36693  valid_loss 0.41721  valid_acc: 0.84885  lr: 0.009826  elapsed: 82
# val acc has not improved
# Epoch 24/100  train_loss: 0.38378  valid_loss 0.66842  valid_acc: 0.80700  lr: 0.009823  elapsed: 82
# val acc has not improved
# Epoch 25/100  train_loss: 0.37172  valid_loss 0.63484  valid_acc: 0.81554  lr: 0.009840  elapsed: 82
# val acc has not improved
# Epoch 26/100  train_loss: 0.36227  valid_loss 0.65948  valid_acc: 0.83945  lr: 0.009837  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 27, Accuracy : 0.8676345004269855
# Epoch 27/100  train_loss: 0.35447  valid_loss 0.49650  valid_acc: 0.86763  lr: 0.009827  elapsed: 82
# val acc has not improved
# Epoch 28/100  train_loss: 0.35693  valid_loss 0.39737  valid_acc: 0.86251  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 29/100  train_loss: 0.34836  valid_loss 0.40276  valid_acc: 0.86507  lr: 0.009818  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 30, Accuracy : 0.8761742100768574
# Epoch 30/100  train_loss: 0.34518  valid_loss 0.40194  valid_acc: 0.87617  lr: 0.009817  elapsed: 82
# val acc has not improved
# Epoch 31/100  train_loss: 0.33472  valid_loss 0.38470  valid_acc: 0.87617  lr: 0.009812  elapsed: 82
# val acc has not improved
# Epoch 32/100  train_loss: 0.35488  valid_loss 0.40001  valid_acc: 0.86763  lr: 0.009812  elapsed: 82
# val acc has not improved
# Epoch 33/100  train_loss: 0.34236  valid_loss 0.53946  valid_acc: 0.84202  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 34/100  train_loss: 0.32051  valid_loss 0.43615  valid_acc: 0.85739  lr: 0.009826  elapsed: 82
# val acc has not improved
# Epoch 35/100  train_loss: 0.31527  valid_loss 0.38028  valid_acc: 0.86934  lr: 0.009820  elapsed: 82
# val acc has not improved
# Epoch 36/100  train_loss: 0.31723  valid_loss 0.37262  valid_acc: 0.85739  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 37/100  train_loss: 0.32600  valid_loss 0.45184  valid_acc: 0.85739  lr: 0.009820  elapsed: 82
# val acc has not improved
# Epoch 38/100  train_loss: 0.32572  valid_loss 0.49815  valid_acc: 0.83689  lr: 0.009820  elapsed: 82
# val acc has not improved
# Epoch 39/100  train_loss: 0.32300  valid_loss 0.40170  valid_acc: 0.86422  lr: 0.009828  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 40, Accuracy : 0.8821520068317678
# Epoch 40/100  train_loss: 0.29442  valid_loss 0.32335  valid_acc: 0.88215  lr: 0.009817  elapsed: 82
# val acc has not improved
# Epoch 41/100  train_loss: 0.32489  valid_loss 0.50090  valid_acc: 0.84031  lr: 0.009809  elapsed: 82
# val acc has not improved
# Epoch 42/100  train_loss: 0.29206  valid_loss 0.37440  valid_acc: 0.87959  lr: 0.009827  elapsed: 82
# val acc has not improved
# Epoch 43/100  train_loss: 0.31335  valid_loss 0.44051  valid_acc: 0.85995  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 44/100  train_loss: 0.30583  valid_loss 0.39556  valid_acc: 0.86763  lr: 0.009819  elapsed: 82
# val acc has not improved
# Epoch 45/100  train_loss: 0.28287  valid_loss 0.42639  valid_acc: 0.86166  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 46/100  train_loss: 0.32057  valid_loss 0.41924  valid_acc: 0.84970  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 47/100  train_loss: 0.31194  valid_loss 0.47340  valid_acc: 0.83177  lr: 0.009823  elapsed: 82
# val acc has not improved
# Epoch 48/100  train_loss: 0.31836  valid_loss 0.42365  valid_acc: 0.86678  lr: 0.009830  elapsed: 82
# val acc has not improved
# Epoch 49/100  train_loss: 0.30850  valid_loss 0.54193  valid_acc: 0.84629  lr: 0.009816  elapsed: 82
# val acc has not improved
# Epoch 50/100  train_loss: 0.29481  valid_loss 0.42192  valid_acc: 0.86251  lr: 0.009824  elapsed: 82
# val acc has not improved
# Epoch 51/100  train_loss: 0.30889  valid_loss 0.33860  valid_acc: 0.87788  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 52/100  train_loss: 0.33466  valid_loss 0.48695  valid_acc: 0.85056  lr: 0.009811  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 53, Accuracy : 0.8872758326216909
# Epoch 53/100  train_loss: 0.29225  valid_loss 0.32910  valid_acc: 0.88728  lr: 0.009823  elapsed: 82
# val acc has not improved
# Epoch 54/100  train_loss: 0.29518  valid_loss 0.41820  valid_acc: 0.86080  lr: 0.009807  elapsed: 82
# val acc has not improved
# Epoch 55/100  train_loss: 0.29541  valid_loss 0.51355  valid_acc: 0.81896  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 56/100  train_loss: 0.27679  valid_loss 0.34723  valid_acc: 0.87617  lr: 0.009835  elapsed: 83
# val acc has not improved
# Epoch 57/100  train_loss: 0.29299  valid_loss 0.37356  valid_acc: 0.87190  lr: 0.009812  elapsed: 82
# val acc has not improved
# Epoch 58/100  train_loss: 0.28141  valid_loss 0.42756  valid_acc: 0.86678  lr: 0.009814  elapsed: 82
# val acc has not improved
# Epoch 59/100  train_loss: 0.28582  valid_loss 0.45961  valid_acc: 0.85056  lr: 0.009816  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 60, Accuracy : 0.892399658411614
# Epoch 60/100  train_loss: 0.30395  valid_loss 0.31660  valid_acc: 0.89240  lr: 0.009823  elapsed: 82
# val acc has not improved
# Epoch 61/100  train_loss: 0.30155  valid_loss 0.49749  valid_acc: 0.81298  lr: 0.009805  elapsed: 82
# val acc has not improved
# Epoch 62/100  train_loss: 0.30415  valid_loss 0.32056  valid_acc: 0.88386  lr: 0.009838  elapsed: 82
# val acc has not improved
# Epoch 63/100  train_loss: 0.27726  valid_loss 0.34012  valid_acc: 0.88471  lr: 0.009808  elapsed: 82
# val acc has not improved
# Epoch 64/100  train_loss: 0.27619  valid_loss 0.34968  valid_acc: 0.88898  lr: 0.009808  elapsed: 82
# val acc has not improved
# Epoch 65/100  train_loss: 0.28460  valid_loss 0.34644  valid_acc: 0.87788  lr: 0.009806  elapsed: 82
# val acc has not improved
# Epoch 66/100  train_loss: 0.35446  valid_loss 0.42291  valid_acc: 0.84885  lr: 0.009811  elapsed: 82
# val acc has not improved
# Epoch 67/100  train_loss: 0.30977  valid_loss 0.40254  valid_acc: 0.86080  lr: 0.009823  elapsed: 82
# val acc has not improved
# Epoch 68/100  train_loss: 0.27531  valid_loss 0.36173  valid_acc: 0.87361  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 69/100  train_loss: 0.29080  valid_loss 0.39098  valid_acc: 0.87617  lr: 0.009813  elapsed: 82
# val acc has not improved
# Epoch 70/100  train_loss: 0.28221  valid_loss 0.41670  valid_acc: 0.85141  lr: 0.009812  elapsed: 82
# val acc has not improved
# Epoch 71/100  train_loss: 0.28270  valid_loss 0.38378  valid_acc: 0.88471  lr: 0.009822  elapsed: 82
# val acc has not improved
# Epoch 72/100  train_loss: 0.28785  valid_loss 0.32854  valid_acc: 0.87959  lr: 0.009808  elapsed: 82
# val acc has not improved
# Epoch 73/100  train_loss: 0.26823  valid_loss 0.32457  valid_acc: 0.89155  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 74/100  train_loss: 0.27629  valid_loss 0.36125  valid_acc: 0.86166  lr: 0.009805  elapsed: 82
# val acc has not improved
# Epoch 75/100  train_loss: 0.27771  valid_loss 0.35730  valid_acc: 0.86507  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 76/100  train_loss: 0.28925  valid_loss 0.38656  valid_acc: 0.86763  lr: 0.009817  elapsed: 82
# val acc has not improved
# Epoch 77/100  train_loss: 0.26720  valid_loss 0.33204  valid_acc: 0.87959  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 78/100  train_loss: 0.29785  valid_loss 0.33266  valid_acc: 0.88557  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 79/100  train_loss: 0.27975  valid_loss 0.39187  valid_acc: 0.87190  lr: 0.009808  elapsed: 82
# val acc has not improved
# Epoch 80/100  train_loss: 0.27494  valid_loss 0.36673  valid_acc: 0.87703  lr: 0.009814  elapsed: 82
# val acc has not improved
# Epoch 81/100  train_loss: 0.28595  valid_loss 0.35740  valid_acc: 0.88044  lr: 0.009811  elapsed: 82
# val acc has not improved
# Epoch 82/100  train_loss: 0.26003  valid_loss 0.39314  valid_acc: 0.87447  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 83/100  train_loss: 0.26898  valid_loss 0.33105  valid_acc: 0.88044  lr: 0.009813  elapsed: 82
# val acc has not improved
# Epoch 84/100  train_loss: 0.27660  valid_loss 0.35001  valid_acc: 0.87959  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 85/100  train_loss: 0.27068  valid_loss 0.37416  valid_acc: 0.87788  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 86/100  train_loss: 0.27088  valid_loss 0.34351  valid_acc: 0.87788  lr: 0.009811  elapsed: 82
# val acc has not improved
# Epoch 87/100  train_loss: 0.27169  valid_loss 0.38579  valid_acc: 0.87020  lr: 0.009811  elapsed: 82
# val acc has not improved
# Epoch 88/100  train_loss: 0.28239  valid_loss 0.35505  valid_acc: 0.88130  lr: 0.009814  elapsed: 82
# val acc has not improved
# Epoch 89/100  train_loss: 0.26399  valid_loss 0.39879  valid_acc: 0.85995  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 90/100  train_loss: 0.26750  valid_loss 0.33324  valid_acc: 0.87703  lr: 0.009819  elapsed: 82
# val acc has not improved
# Epoch 91/100  train_loss: 0.26081  valid_loss 0.30539  valid_acc: 0.89155  lr: 0.009811  elapsed: 82
# val acc has not improved
# Epoch 92/100  train_loss: 0.24678  valid_loss 0.32872  valid_acc: 0.88301  lr: 0.009805  elapsed: 82
# val acc has not improved
# Epoch 93/100  train_loss: 0.26757  valid_loss 0.47157  valid_acc: 0.84116  lr: 0.009809  elapsed: 82
# val acc has not improved
# Epoch 94/100  train_loss: 0.25522  valid_loss 0.35389  valid_acc: 0.87703  lr: 0.009826  elapsed: 82
# val acc has not improved
# Epoch 95/100  train_loss: 0.26937  valid_loss 0.41275  valid_acc: 0.85824  lr: 0.009811  elapsed: 82
# val acc has not improved
# Epoch 96/100  train_loss: 0.26784  valid_loss 0.41056  valid_acc: 0.85056  lr: 0.009819  elapsed: 83
# val acc has not improved
# Epoch 97/100  train_loss: 0.27094  valid_loss 0.35600  valid_acc: 0.88044  lr: 0.009823  elapsed: 83
# val acc has not improved
# Epoch 98/100  train_loss: 0.25397  valid_loss 0.33770  valid_acc: 0.88215  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 99/100  train_loss: 0.27186  valid_loss 0.38233  valid_acc: 0.86080  lr: 0.009809  elapsed: 82
# val acc has not improved
# Epoch 100/100  train_loss: 0.26858  valid_loss 0.41235  valid_acc: 0.84714  lr: 0.009818  elapsed: 82
# ================ ༼ つ ◕_◕ ༽つ Model Load 0_th FOLD ===============
# predict values check :  [ 5.04064274 -0.14618826 -0.4607811   0.80180693 -3.06909561 -2.16203833]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7470.86it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.4073441502988898
# Epoch 1/100  train_loss: 2.44137  valid_loss 1.52207  valid_acc: 0.40734  lr: 0.010000  elapsed: 77
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.5072587532023911
# Epoch 2/100  train_loss: 1.51651  valid_loss 1.40639  valid_acc: 0.50726  lr: 0.009959  elapsed: 83
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.5269000853970965
# Epoch 3/100  train_loss: 1.39264  valid_loss 1.42982  valid_acc: 0.52690  lr: 0.009937  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.5644748078565329
# Epoch 4/100  train_loss: 1.32058  valid_loss 1.42845  valid_acc: 0.56447  lr: 0.009932  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5892399658411615
# Epoch 5/100  train_loss: 1.24826  valid_loss 1.16129  valid_acc: 0.58924  lr: 0.009922  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.667805294619983
# Epoch 6/100  train_loss: 1.09012  valid_loss 1.00836  valid_acc: 0.66781  lr: 0.009915  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.7019641332194705
# Epoch 7/100  train_loss: 0.93586  valid_loss 1.26070  valid_acc: 0.70196  lr: 0.009890  elapsed: 82
# val acc has not improved
# Epoch 8/100  train_loss: 0.86851  valid_loss 0.93802  valid_acc: 0.69940  lr: 0.009879  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.7446626814688301
# Epoch 9/100  train_loss: 0.79355  valid_loss 0.69896  valid_acc: 0.74466  lr: 0.009880  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7608881298035867
# Epoch 10/100  train_loss: 0.70985  valid_loss 0.80518  valid_acc: 0.76089  lr: 0.009864  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 11, Accuracy : 0.7856532877882152
# Epoch 11/100  train_loss: 0.66441  valid_loss 0.57900  valid_acc: 0.78565  lr: 0.009858  elapsed: 82
# val acc has not improved
# Epoch 12/100  train_loss: 0.58691  valid_loss 0.83805  valid_acc: 0.71734  lr: 0.009848  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.8223740392826644
# Epoch 13/100  train_loss: 0.56858  valid_loss 0.54484  valid_acc: 0.82237  lr: 0.009874  elapsed: 82
# val acc has not improved
# Epoch 14/100  train_loss: 0.54467  valid_loss 0.59612  valid_acc: 0.81298  lr: 0.009834  elapsed: 82
# val acc has not improved
# Epoch 15/100  train_loss: 0.48590  valid_loss 0.63185  valid_acc: 0.81554  lr: 0.009838  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 16, Accuracy : 0.8240819812126388
# Epoch 16/100  train_loss: 0.47745  valid_loss 0.69127  valid_acc: 0.82408  lr: 0.009837  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.8368915456874466
# Epoch 17/100  train_loss: 0.44410  valid_loss 0.43757  valid_acc: 0.83689  lr: 0.009833  elapsed: 82
# val acc has not improved
# Epoch 18/100  train_loss: 0.42681  valid_loss 0.50344  valid_acc: 0.83006  lr: 0.009828  elapsed: 82
# val acc has not improved
# Epoch 19/100  train_loss: 0.42964  valid_loss 0.51773  valid_acc: 0.83006  lr: 0.009831  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 20, Accuracy : 0.838599487617421
# Epoch 20/100  train_loss: 0.42686  valid_loss 0.54662  valid_acc: 0.83860  lr: 0.009831  elapsed: 83
# val acc has not improved
# Epoch 21/100  train_loss: 0.40794  valid_loss 0.43238  valid_acc: 0.83348  lr: 0.009827  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 22, Accuracy : 0.842869342442357
# Epoch 22/100  train_loss: 0.37803  valid_loss 0.42444  valid_acc: 0.84287  lr: 0.009830  elapsed: 82
# val acc has not improved
# Epoch 23/100  train_loss: 0.36294  valid_loss 0.50573  valid_acc: 0.83262  lr: 0.009826  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 24, Accuracy : 0.8497011101622545
# Epoch 24/100  train_loss: 0.38754  valid_loss 0.47823  valid_acc: 0.84970  lr: 0.009830  elapsed: 87
# val acc has not improved
# Epoch 25/100  train_loss: 0.34615  valid_loss 0.46408  valid_acc: 0.83775  lr: 0.009823  elapsed: 84
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 26, Accuracy : 0.856532877882152
# Epoch 26/100  train_loss: 0.34545  valid_loss 0.49615  valid_acc: 0.85653  lr: 0.009828  elapsed: 82
# val acc has not improved
# Epoch 27/100  train_loss: 0.33756  valid_loss 0.55527  valid_acc: 0.82750  lr: 0.009820  elapsed: 83
# val acc has not improved
# Epoch 28/100  train_loss: 0.34349  valid_loss 0.43184  valid_acc: 0.84799  lr: 0.009832  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 29, Accuracy : 0.8727583262169086
# Epoch 29/100  train_loss: 0.35085  valid_loss 0.39469  valid_acc: 0.87276  lr: 0.009824  elapsed: 82
# val acc has not improved
# Epoch 30/100  train_loss: 0.33130  valid_loss 0.70059  valid_acc: 0.83262  lr: 0.009813  elapsed: 82
# val acc has not improved
# Epoch 31/100  train_loss: 0.32854  valid_loss 0.40105  valid_acc: 0.85653  lr: 0.009830  elapsed: 83
# val acc has not improved
# Epoch 32/100  train_loss: 0.34341  valid_loss 0.43064  valid_acc: 0.86934  lr: 0.009820  elapsed: 82
# val acc has not improved
# Epoch 33/100  train_loss: 0.31387  valid_loss 1.17501  valid_acc: 0.78309  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 34/100  train_loss: 0.35963  valid_loss 0.38450  valid_acc: 0.85824  lr: 0.009849  elapsed: 82
# val acc has not improved
# Epoch 35/100  train_loss: 0.32281  valid_loss 0.45636  valid_acc: 0.82494  lr: 0.009819  elapsed: 83
# val acc has not improved
# Epoch 36/100  train_loss: 0.32181  valid_loss 0.44800  valid_acc: 0.84458  lr: 0.009833  elapsed: 83
# val acc has not improved
# Epoch 37/100  train_loss: 0.35664  valid_loss 0.39343  valid_acc: 0.85568  lr: 0.009825  elapsed: 83
# val acc has not improved
# Epoch 38/100  train_loss: 0.34006  valid_loss 0.49229  valid_acc: 0.83433  lr: 0.009820  elapsed: 85
# val acc has not improved
# Epoch 39/100  train_loss: 0.33073  valid_loss 0.44116  valid_acc: 0.83177  lr: 0.009829  elapsed: 85
# val acc has not improved
# Epoch 40/100  train_loss: 0.31612  valid_loss 0.41568  valid_acc: 0.85226  lr: 0.009830  elapsed: 83
# val acc has not improved
# Epoch 41/100  train_loss: 0.29998  valid_loss 0.38483  valid_acc: 0.85653  lr: 0.009822  elapsed: 83
# val acc has not improved
# Epoch 42/100  train_loss: 0.29592  valid_loss 0.44373  valid_acc: 0.85141  lr: 0.009820  elapsed: 84
# val acc has not improved
# Epoch 43/100  train_loss: 0.27824  valid_loss 0.54038  valid_acc: 0.82750  lr: 0.009822  elapsed: 82
# val acc has not improved
# Epoch 44/100  train_loss: 0.30552  valid_loss 0.67581  valid_acc: 0.78907  lr: 0.009832  elapsed: 81
# val acc has not improved
# Epoch 45/100  train_loss: 0.33039  valid_loss 0.62941  valid_acc: 0.82323  lr: 0.009847  elapsed: 81
# val acc has not improved
# Epoch 46/100  train_loss: 0.30068  valid_loss 0.47721  valid_acc: 0.84799  lr: 0.009834  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 47, Accuracy : 0.8736122971818958
# Epoch 47/100  train_loss: 0.29185  valid_loss 0.37873  valid_acc: 0.87361  lr: 0.009824  elapsed: 82
# val acc has not improved
# Epoch 48/100  train_loss: 0.29850  valid_loss 0.42500  valid_acc: 0.85397  lr: 0.009813  elapsed: 82
# val acc has not improved
# Epoch 49/100  train_loss: 0.28524  valid_loss 0.42857  valid_acc: 0.85909  lr: 0.009821  elapsed: 82
# val acc has not improved
# Epoch 50/100  train_loss: 0.28668  valid_loss 0.39192  valid_acc: 0.86593  lr: 0.009819  elapsed: 82
# val acc has not improved
# Epoch 51/100  train_loss: 0.28836  valid_loss 0.46616  valid_acc: 0.83689  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 52/100  train_loss: 0.27295  valid_loss 0.43382  valid_acc: 0.86422  lr: 0.009828  elapsed: 81
# val acc has not improved
# Epoch 53/100  train_loss: 0.31168  valid_loss 0.39582  valid_acc: 0.87276  lr: 0.009817  elapsed: 82
# val acc has not improved
# Epoch 54/100  train_loss: 0.29165  valid_loss 0.39526  valid_acc: 0.85909  lr: 0.009813  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 55, Accuracy : 0.8795900939368061
# Epoch 55/100  train_loss: 0.28999  valid_loss 0.35445  valid_acc: 0.87959  lr: 0.009819  elapsed: 81
# val acc has not improved
# Epoch 56/100  train_loss: 0.28153  valid_loss 0.44574  valid_acc: 0.84116  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 57/100  train_loss: 0.28032  valid_loss 0.36471  valid_acc: 0.86507  lr: 0.009826  elapsed: 82
# val acc has not improved
# Epoch 58/100  train_loss: 0.28945  valid_loss 0.56584  valid_acc: 0.80017  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 59/100  train_loss: 0.34158  valid_loss 0.41992  valid_acc: 0.85568  lr: 0.009843  elapsed: 81
# val acc has not improved
# Epoch 60/100  train_loss: 0.32596  valid_loss 0.48434  valid_acc: 0.83091  lr: 0.009820  elapsed: 81
# val acc has not improved
# Epoch 61/100  train_loss: 0.28815  valid_loss 0.41231  valid_acc: 0.85141  lr: 0.009831  elapsed: 81
# val acc has not improved
# Epoch 62/100  train_loss: 0.30466  valid_loss 0.39807  valid_acc: 0.85909  lr: 0.009822  elapsed: 81
# val acc has not improved
# Epoch 63/100  train_loss: 0.28823  valid_loss 0.34794  valid_acc: 0.87703  lr: 0.009819  elapsed: 81
# val acc has not improved
# Epoch 64/100  train_loss: 0.27319  valid_loss 0.35681  valid_acc: 0.87959  lr: 0.009811  elapsed: 82
# val acc has not improved
# Epoch 65/100  train_loss: 0.27167  valid_loss 0.68174  valid_acc: 0.77028  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 66/100  train_loss: 0.26445  valid_loss 0.45723  valid_acc: 0.85056  lr: 0.009854  elapsed: 82
# val acc has not improved
# Epoch 67/100  train_loss: 0.28768  valid_loss 0.49924  valid_acc: 0.82579  lr: 0.009823  elapsed: 83
# val acc has not improved
# Epoch 68/100  train_loss: 0.28709  valid_loss 0.39035  valid_acc: 0.86166  lr: 0.009833  elapsed: 82
# val acc has not improved
# Epoch 69/100  train_loss: 0.28833  valid_loss 0.42819  valid_acc: 0.84629  lr: 0.009818  elapsed: 83
# val acc has not improved
# Epoch 70/100  train_loss: 0.27836  valid_loss 0.38905  valid_acc: 0.86422  lr: 0.009824  elapsed: 82
# val acc has not improved
# Epoch 71/100  train_loss: 0.27584  valid_loss 0.36623  valid_acc: 0.87361  lr: 0.009817  elapsed: 82
# val acc has not improved
# Epoch 72/100  train_loss: 0.27577  valid_loss 0.39231  valid_acc: 0.86080  lr: 0.009813  elapsed: 83
# val acc has not improved
# Epoch 73/100  train_loss: 0.26369  valid_loss 0.38298  valid_acc: 0.87447  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 74/100  train_loss: 0.27835  valid_loss 0.34960  valid_acc: 0.87105  lr: 0.009813  elapsed: 82
# val acc has not improved
# Epoch 75/100  train_loss: 0.26019  valid_loss 0.36004  valid_acc: 0.87532  lr: 0.009814  elapsed: 83
# val acc has not improved
# Epoch 76/100  train_loss: 0.26596  valid_loss 0.38163  valid_acc: 0.86849  lr: 0.009812  elapsed: 83
# val acc has not improved
# Epoch 77/100  train_loss: 0.25905  valid_loss 0.38654  valid_acc: 0.86763  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 78/100  train_loss: 0.26417  valid_loss 0.38474  valid_acc: 0.86422  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 79/100  train_loss: 0.28227  valid_loss 0.54358  valid_acc: 0.80444  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 80/100  train_loss: 0.29233  valid_loss 0.39314  valid_acc: 0.86422  lr: 0.009841  elapsed: 81
# val acc has not improved
# Epoch 81/100  train_loss: 0.25916  valid_loss 0.40887  valid_acc: 0.86934  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 82/100  train_loss: 0.25624  valid_loss 0.42016  valid_acc: 0.86336  lr: 0.009815  elapsed: 81
# val acc has not improved
# Epoch 83/100  train_loss: 0.27056  valid_loss 0.37488  valid_acc: 0.87532  lr: 0.009817  elapsed: 82
# val acc has not improved
# Epoch 84/100  train_loss: 0.26433  valid_loss 0.35484  valid_acc: 0.87276  lr: 0.009812  elapsed: 82
# val acc has not improved
# Epoch 85/100  train_loss: 0.27161  valid_loss 0.45049  valid_acc: 0.84202  lr: 0.009813  elapsed: 82
# val acc has not improved
# Epoch 86/100  train_loss: 0.27554  valid_loss 0.39807  valid_acc: 0.86849  lr: 0.009826  elapsed: 82
# val acc has not improved
# Epoch 87/100  train_loss: 0.26263  valid_loss 0.35517  valid_acc: 0.87190  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 88/100  train_loss: 0.25361  valid_loss 0.43075  valid_acc: 0.84714  lr: 0.009814  elapsed: 82
# val acc has not improved
# Epoch 89/100  train_loss: 0.25405  valid_loss 0.38106  valid_acc: 0.86934  lr: 0.009824  elapsed: 81
# val acc has not improved
# Epoch 90/100  train_loss: 0.25314  valid_loss 0.52523  valid_acc: 0.82152  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 91/100  train_loss: 0.29282  valid_loss 0.42642  valid_acc: 0.84885  lr: 0.009834  elapsed: 82
# val acc has not improved
# Epoch 92/100  train_loss: 0.28921  valid_loss 0.37366  valid_acc: 0.86763  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 93/100  train_loss: 0.25686  valid_loss 0.41562  valid_acc: 0.85226  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 94/100  train_loss: 0.27156  valid_loss 0.36543  valid_acc: 0.87788  lr: 0.009822  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 95, Accuracy : 0.8847139197267293
# Epoch 95/100  train_loss: 0.25336  valid_loss 0.33812  valid_acc: 0.88471  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 96/100  train_loss: 0.26029  valid_loss 0.40201  valid_acc: 0.85482  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 97/100  train_loss: 0.25303  valid_loss 0.45854  valid_acc: 0.84458  lr: 0.009821  elapsed: 82
# val acc has not improved
# Epoch 98/100  train_loss: 0.25072  valid_loss 0.35106  valid_acc: 0.87276  lr: 0.009825  elapsed: 81
# val acc has not improved
# Epoch 99/100  train_loss: 0.24547  valid_loss 0.44432  valid_acc: 0.84202  lr: 0.009813  elapsed: 82
# val acc has not improved
# Epoch 100/100  train_loss: 0.27511  valid_loss 0.41285  valid_acc: 0.86166  lr: 0.009826  elapsed: 81
# ================ ༼ つ ◕_◕ ༽つ Model Load 1_th FOLD ===============
# predict values check :  [ 4.61537743 -0.39962125  0.78290927 -0.08536927 -3.04421067 -1.87034273]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 2_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7014.02it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43467122117847995
# Epoch 1/100  train_loss: 2.51098  valid_loss 1.62513  valid_acc: 0.43467  lr: 0.010000  elapsed: 76
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.43552519214346713
# Epoch 2/100  train_loss: 1.51571  valid_loss 1.45561  valid_acc: 0.43553  lr: 0.009953  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.4517506404782237
# Epoch 3/100  train_loss: 1.45244  valid_loss 1.38190  valid_acc: 0.45175  lr: 0.009953  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.5362937660119556
# Epoch 4/100  train_loss: 1.40594  valid_loss 1.29939  valid_acc: 0.53629  lr: 0.009950  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5687446626814688
# Epoch 5/100  train_loss: 1.35232  valid_loss 1.20441  valid_acc: 0.56874  lr: 0.009929  elapsed: 82
# val acc has not improved
# Epoch 6/100  train_loss: 1.35920  valid_loss 1.37281  valid_acc: 0.55081  lr: 0.009920  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.6310845431255337
# Epoch 7/100  train_loss: 1.24612  valid_loss 1.10757  valid_acc: 0.63108  lr: 0.009925  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.6883005977796754
# Epoch 8/100  train_loss: 1.04990  valid_loss 0.94604  valid_acc: 0.68830  lr: 0.009902  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.7292912040990607
# Epoch 9/100  train_loss: 0.89315  valid_loss 0.78325  valid_acc: 0.72929  lr: 0.009884  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7668659265584971
# Epoch 10/100  train_loss: 0.78333  valid_loss 0.77951  valid_acc: 0.76687  lr: 0.009869  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 11, Accuracy : 0.7822374039282665
# Epoch 11/100  train_loss: 0.72585  valid_loss 0.57562  valid_acc: 0.78224  lr: 0.009856  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.7950469684030743
# Epoch 12/100  train_loss: 0.67824  valid_loss 0.58952  valid_acc: 0.79505  lr: 0.009850  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.8061485909479078
# Epoch 13/100  train_loss: 0.62197  valid_loss 0.52582  valid_acc: 0.80615  lr: 0.009845  elapsed: 81
# val acc has not improved
# Epoch 14/100  train_loss: 0.55583  valid_loss 1.23949  valid_acc: 0.62681  lr: 0.009841  elapsed: 81
# val acc has not improved
# Epoch 15/100  train_loss: 0.72912  valid_loss 0.50696  valid_acc: 0.80359  lr: 0.009903  elapsed: 81
# val acc has not improved
# Epoch 16/100  train_loss: 0.58856  valid_loss 0.55188  valid_acc: 0.80273  lr: 0.009842  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.8129803586678053
# Epoch 17/100  train_loss: 0.52188  valid_loss 0.53617  valid_acc: 0.81298  lr: 0.009842  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 18, Accuracy : 0.8283518360375747
# Epoch 18/100  train_loss: 0.48642  valid_loss 0.46557  valid_acc: 0.82835  lr: 0.009838  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 19, Accuracy : 0.8539709649871904
# Epoch 19/100  train_loss: 0.48096  valid_loss 0.40646  valid_acc: 0.85397  lr: 0.009832  elapsed: 81
# val acc has not improved
# Epoch 20/100  train_loss: 0.41769  valid_loss 0.48140  valid_acc: 0.83860  lr: 0.009821  elapsed: 81
# val acc has not improved
# Epoch 21/100  train_loss: 0.42222  valid_loss 0.42653  valid_acc: 0.85056  lr: 0.009827  elapsed: 81
# val acc has not improved
# Epoch 22/100  train_loss: 0.38900  valid_loss 0.45990  valid_acc: 0.84543  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 23/100  train_loss: 0.40429  valid_loss 0.42377  valid_acc: 0.84372  lr: 0.009825  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 24, Accuracy : 0.8633646456020495
# Epoch 24/100  train_loss: 0.37487  valid_loss 0.39475  valid_acc: 0.86336  lr: 0.009825  elapsed: 81
# val acc has not improved
# Epoch 25/100  train_loss: 0.37506  valid_loss 0.43286  valid_acc: 0.84799  lr: 0.009817  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 26, Accuracy : 0.8727583262169086
# Epoch 26/100  train_loss: 0.37452  valid_loss 0.36755  valid_acc: 0.87276  lr: 0.009824  elapsed: 81
# val acc has not improved
# Epoch 27/100  train_loss: 0.35446  valid_loss 0.45365  valid_acc: 0.83860  lr: 0.009813  elapsed: 81
# val acc has not improved
# Epoch 28/100  train_loss: 0.35835  valid_loss 0.41775  valid_acc: 0.85482  lr: 0.009827  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 29, Accuracy : 0.8753202391118702
# Epoch 29/100  train_loss: 0.35486  valid_loss 0.34705  valid_acc: 0.87532  lr: 0.009821  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 30, Accuracy : 0.8770281810418445
# Epoch 30/100  train_loss: 0.35508  valid_loss 0.33930  valid_acc: 0.87703  lr: 0.009812  elapsed: 81
# val acc has not improved
# Epoch 31/100  train_loss: 0.33121  valid_loss 0.37293  valid_acc: 0.87276  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 32/100  train_loss: 0.36165  valid_loss 0.37815  valid_acc: 0.86336  lr: 0.009813  elapsed: 81
# val acc has not improved
# Epoch 33/100  train_loss: 0.34358  valid_loss 0.39182  valid_acc: 0.86678  lr: 0.009817  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 34, Accuracy : 0.8932536293766012
# Epoch 34/100  train_loss: 0.32729  valid_loss 0.32428  valid_acc: 0.89325  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 35/100  train_loss: 0.32680  valid_loss 0.43385  valid_acc: 0.84970  lr: 0.009804  elapsed: 81
# val acc has not improved
# Epoch 36/100  train_loss: 0.33004  valid_loss 0.38901  valid_acc: 0.86507  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 37/100  train_loss: 0.33016  valid_loss 0.39044  valid_acc: 0.86593  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 38/100  train_loss: 0.32880  valid_loss 0.33876  valid_acc: 0.88130  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 39/100  train_loss: 0.30884  valid_loss 0.42185  valid_acc: 0.85482  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 40/100  train_loss: 0.32654  valid_loss 0.38757  valid_acc: 0.86593  lr: 0.009821  elapsed: 81
# val acc has not improved
# Epoch 41/100  train_loss: 0.31651  valid_loss 0.44708  valid_acc: 0.84031  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 42/100  train_loss: 0.32162  valid_loss 0.32885  valid_acc: 0.88215  lr: 0.009827  elapsed: 81
# val acc has not improved
# Epoch 43/100  train_loss: 0.30136  valid_loss 0.33605  valid_acc: 0.88130  lr: 0.009809  elapsed: 81
# val acc has not improved
# Epoch 44/100  train_loss: 0.29849  valid_loss 0.44544  valid_acc: 0.85482  lr: 0.009810  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 45, Accuracy : 0.8941076003415884
# Epoch 45/100  train_loss: 0.28678  valid_loss 0.31613  valid_acc: 0.89411  lr: 0.009821  elapsed: 81
# val acc has not improved
# Epoch 46/100  train_loss: 0.31308  valid_loss 0.31221  valid_acc: 0.88301  lr: 0.009804  elapsed: 81
# val acc has not improved
# Epoch 47/100  train_loss: 0.29053  valid_loss 0.36416  valid_acc: 0.86934  lr: 0.009809  elapsed: 81
# val acc has not improved
# Epoch 48/100  train_loss: 0.30380  valid_loss 0.31190  valid_acc: 0.88642  lr: 0.009815  elapsed: 81
# val acc has not improved
# Epoch 49/100  train_loss: 0.30242  valid_loss 0.40538  valid_acc: 0.84970  lr: 0.009807  elapsed: 81
# val acc has not improved
# Epoch 50/100  train_loss: 0.29528  valid_loss 0.35060  valid_acc: 0.87959  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 51/100  train_loss: 0.30492  valid_loss 0.36917  valid_acc: 0.86934  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 52/100  train_loss: 0.29637  valid_loss 0.40986  valid_acc: 0.84458  lr: 0.009815  elapsed: 81
# val acc has not improved
# Epoch 53/100  train_loss: 0.31338  valid_loss 0.38927  valid_acc: 0.88215  lr: 0.009825  elapsed: 81
# val acc has not improved
# Epoch 54/100  train_loss: 0.32640  valid_loss 0.35480  valid_acc: 0.87276  lr: 0.009809  elapsed: 81
# val acc has not improved
# Epoch 55/100  train_loss: 0.30649  valid_loss 0.43348  valid_acc: 0.85056  lr: 0.009813  elapsed: 81
# val acc has not improved
# Epoch 56/100  train_loss: 0.28785  valid_loss 0.31185  valid_acc: 0.88898  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 57/100  train_loss: 0.30759  valid_loss 0.34968  valid_acc: 0.86678  lr: 0.009806  elapsed: 81
# val acc has not improved
# Epoch 58/100  train_loss: 0.28340  valid_loss 0.39954  valid_acc: 0.86593  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 59/100  train_loss: 0.28556  valid_loss 0.32877  valid_acc: 0.88898  lr: 0.009816  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 60, Accuracy : 0.89666951323655
# Epoch 60/100  train_loss: 0.29255  valid_loss 0.30554  valid_acc: 0.89667  lr: 0.009806  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 61, Accuracy : 0.9043552519214346
# Epoch 61/100  train_loss: 0.28890  valid_loss 0.30147  valid_acc: 0.90436  lr: 0.009803  elapsed: 81
# val acc has not improved
# Epoch 62/100  train_loss: 0.29083  valid_loss 0.31021  valid_acc: 0.89240  lr: 0.009800  elapsed: 81
# val acc has not improved
# Epoch 63/100  train_loss: 0.29354  valid_loss 0.31550  valid_acc: 0.88471  lr: 0.009805  elapsed: 81
# val acc has not improved
# Epoch 64/100  train_loss: 0.26812  valid_loss 0.33272  valid_acc: 0.86678  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 65/100  train_loss: 0.28092  valid_loss 0.30066  valid_acc: 0.90179  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 66/100  train_loss: 0.27875  valid_loss 0.39053  valid_acc: 0.85739  lr: 0.009801  elapsed: 82
# val acc has not improved
# Epoch 67/100  train_loss: 0.29098  valid_loss 0.39873  valid_acc: 0.85995  lr: 0.009820  elapsed: 82
# val acc has not improved
# Epoch 68/100  train_loss: 0.28722  valid_loss 0.29770  valid_acc: 0.89667  lr: 0.009819  elapsed: 81
# val acc has not improved
# Epoch 69/100  train_loss: 0.29618  valid_loss 0.40549  valid_acc: 0.86251  lr: 0.009803  elapsed: 81
# val acc has not improved
# Epoch 70/100  train_loss: 0.27925  valid_loss 0.32269  valid_acc: 0.88386  lr: 0.009818  elapsed: 81
# val acc has not improved
# Epoch 71/100  train_loss: 0.27921  valid_loss 0.34718  valid_acc: 0.89155  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 72/100  train_loss: 0.26821  valid_loss 0.36849  valid_acc: 0.88044  lr: 0.009805  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 73, Accuracy : 0.9060631938514091
# Epoch 73/100  train_loss: 0.28922  valid_loss 0.28536  valid_acc: 0.90606  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 74/100  train_loss: 0.27443  valid_loss 0.31963  valid_acc: 0.88898  lr: 0.009799  elapsed: 81
# val acc has not improved
# Epoch 75/100  train_loss: 0.28492  valid_loss 0.35257  valid_acc: 0.86422  lr: 0.009806  elapsed: 81
# val acc has not improved
# Epoch 76/100  train_loss: 0.27517  valid_loss 0.40114  valid_acc: 0.85312  lr: 0.009817  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 77, Accuracy : 0.9120409906063194
# Epoch 77/100  train_loss: 0.28950  valid_loss 0.25743  valid_acc: 0.91204  lr: 0.009822  elapsed: 81
# val acc has not improved
# Epoch 78/100  train_loss: 0.28470  valid_loss 0.31492  valid_acc: 0.88386  lr: 0.009796  elapsed: 81
# val acc has not improved
# Epoch 79/100  train_loss: 0.27132  valid_loss 0.52810  valid_acc: 0.82494  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 80/100  train_loss: 0.28645  valid_loss 0.33060  valid_acc: 0.88301  lr: 0.009833  elapsed: 81
# val acc has not improved
# Epoch 81/100  train_loss: 0.26726  valid_loss 0.27630  valid_acc: 0.90436  lr: 0.009809  elapsed: 81
# val acc has not improved
# Epoch 82/100  train_loss: 0.26106  valid_loss 0.27672  valid_acc: 0.90094  lr: 0.009800  elapsed: 81
# val acc has not improved
# Epoch 83/100  train_loss: 0.28991  valid_loss 0.39238  valid_acc: 0.85824  lr: 0.009801  elapsed: 81
# val acc has not improved
# Epoch 84/100  train_loss: 0.27759  valid_loss 0.44422  valid_acc: 0.83689  lr: 0.009819  elapsed: 81
# val acc has not improved
# Epoch 85/100  train_loss: 0.28331  valid_loss 0.39291  valid_acc: 0.86763  lr: 0.009828  elapsed: 81
# val acc has not improved
# Epoch 86/100  train_loss: 0.26115  valid_loss 0.34045  valid_acc: 0.88642  lr: 0.009815  elapsed: 81
# val acc has not improved
# Epoch 87/100  train_loss: 0.28316  valid_loss 0.39419  valid_acc: 0.85653  lr: 0.009807  elapsed: 81
# val acc has not improved
# Epoch 88/100  train_loss: 0.28075  valid_loss 0.35335  valid_acc: 0.87276  lr: 0.009820  elapsed: 81
# val acc has not improved
# Epoch 89/100  train_loss: 0.27360  valid_loss 0.30191  valid_acc: 0.88557  lr: 0.009813  elapsed: 81
# val acc has not improved
# Epoch 90/100  train_loss: 0.26384  valid_loss 0.35378  valid_acc: 0.87703  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 91/100  train_loss: 0.26720  valid_loss 0.38989  valid_acc: 0.86422  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 92/100  train_loss: 0.25936  valid_loss 0.24349  valid_acc: 0.90692  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 93/100  train_loss: 0.24987  valid_loss 0.35106  valid_acc: 0.87190  lr: 0.009798  elapsed: 81
# val acc has not improved
# Epoch 94/100  train_loss: 0.27552  valid_loss 0.39489  valid_acc: 0.85312  lr: 0.009814  elapsed: 81
# val acc has not improved
# Epoch 95/100  train_loss: 0.26215  valid_loss 0.43052  valid_acc: 0.83945  lr: 0.009822  elapsed: 81
# val acc has not improved
# Epoch 96/100  train_loss: 0.25749  valid_loss 0.34530  valid_acc: 0.88215  lr: 0.009827  elapsed: 81
# val acc has not improved
# Epoch 97/100  train_loss: 0.26782  valid_loss 0.34751  valid_acc: 0.87874  lr: 0.009809  elapsed: 81
# val acc has not improved
# Epoch 98/100  train_loss: 0.27132  valid_loss 0.29581  valid_acc: 0.89240  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 99/100  train_loss: 0.27014  valid_loss 0.40863  valid_acc: 0.86422  lr: 0.009805  elapsed: 81
# val acc has not improved
# Epoch 100/100  train_loss: 0.26602  valid_loss 0.36958  valid_acc: 0.86849  lr: 0.009817  elapsed: 81
# ================ ༼ つ ◕_◕ ༽つ Model Load 2_th FOLD ===============
# predict values check :  [ 4.87038326  0.9324019  -0.07593625 -0.20510486 -2.85994601 -2.66942787]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 2_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 3_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7204.04it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4680
# number of valid images: 1170
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.44017094017094016
# Epoch 1/100  train_loss: 2.32929  valid_loss 1.50388  valid_acc: 0.44017  lr: 0.010000  elapsed: 75
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.4478632478632479
# Epoch 2/100  train_loss: 1.53612  valid_loss 1.42141  valid_acc: 0.44786  lr: 0.009952  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.5324786324786325
# Epoch 3/100  train_loss: 1.43199  valid_loss 1.33489  valid_acc: 0.53248  lr: 0.009951  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.5367521367521367
# Epoch 4/100  train_loss: 1.35076  valid_loss 1.26012  valid_acc: 0.53675  lr: 0.009930  elapsed: 81
# val_acc has improved !!
# ...
# val acc has not improved
# Epoch 100/100  train_loss: 0.26299  valid_loss 0.35560  valid_acc: 0.87778  lr: 0.009812  elapsed: 81
# ================ ༼ つ ◕_◕ ༽つ Model Load 3_th FOLD ===============
# predict values check :  [ 6.5520587   0.10874185 -0.99231857 -0.10806592 -2.91510296 -2.66461039]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 3_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 4_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 86754630
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7266.69it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4683
# number of valid images: 1167
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43958868894601544
# Epoch 1/100  train_loss: 2.28923  valid_loss 1.48066  valid_acc: 0.43959  lr: 0.010000  elapsed: 75
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.5201371036846615
# Epoch 2/100  train_loss: 1.54998  valid_loss 1.34261  valid_acc: 0.52014  lr: 0.009952  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.5372750642673522
# Epoch 3/100  train_loss: 1.40926  valid_loss 1.30702  valid_acc: 0.53728  lr: 0.009933  elapsed: 81
# val acc has not improved
# Epoch 4/100  train_loss: 1.34504  valid_loss 1.31819  valid_acc: 0.52185  lr: 0.009929  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5638389031705227
# Epoch 5/100  train_loss: 1.30760  valid_loss 1.32589  valid_acc: 0.56384  lr: 0.009933  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.6589545844044559
# Epoch 6/100  train_loss: 1.17224  valid_loss 0.93976  valid_acc: 0.65895  lr: 0.009922  elapsed: 81
# val acc has not improved
# Epoch 7/100  train_loss: 1.00221  valid_loss 0.95270  valid_acc: 0.62811  lr: 0.009893  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.7257926306769494
# Epoch 8/100  train_loss: 0.88154  valid_loss 0.72031  valid_acc: 0.72579  lr: 0.009903  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.7840616966580977
# Epoch 9/100  train_loss: 0.81472  valid_loss 0.59070  valid_acc: 0.78406  lr: 0.009871  elapsed: 81
# val acc has not improved
# Epoch 10/100  train_loss: 0.75234  valid_loss 0.82582  valid_acc: 0.72579  lr: 0.009849  elapsed: 81
# val acc has not improved
# Epoch 11/100  train_loss: 0.66606  valid_loss 0.63574  valid_acc: 0.77549  lr: 0.009871  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.805484147386461
# Epoch 12/100  train_loss: 0.63103  valid_loss 0.55194  valid_acc: 0.80548  lr: 0.009852  elapsed: 81
# val acc has not improved
# Epoch 13/100  train_loss: 0.60917  valid_loss 0.74383  valid_acc: 0.78663  lr: 0.009841  elapsed: 81
# val acc has not improved
# Epoch 14/100  train_loss: 0.56804  valid_loss 0.62501  valid_acc: 0.78749  lr: 0.009848  elapsed: 81
# val acc has not improved
# Epoch 15/100  train_loss: 0.53322  valid_loss 0.82819  valid_acc: 0.74893  lr: 0.009848  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 16, Accuracy : 0.8457583547557841
# Epoch 16/100  train_loss: 0.49401  valid_loss 0.42416  valid_acc: 0.84576  lr: 0.009862  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.8466152527849186
# Epoch 17/100  train_loss: 0.46934  valid_loss 0.49520  valid_acc: 0.84662  lr: 0.009825  elapsed: 81
# val acc has not improved
# Epoch 18/100  train_loss: 0.45131  valid_loss 0.56273  valid_acc: 0.81577  lr: 0.009824  elapsed: 81
# val acc has not improved
# Epoch 19/100  train_loss: 0.44727  valid_loss 0.62535  valid_acc: 0.81662  lr: 0.009837  elapsed: 81
# val acc has not improved
# Epoch 20/100  train_loss: 0.41646  valid_loss 0.49233  valid_acc: 0.84319  lr: 0.009836  elapsed: 81
# val acc has not improved
# Epoch 21/100  train_loss: 0.40365  valid_loss 0.72507  valid_acc: 0.84490  lr: 0.009826  elapsed: 81
# val acc has not improved
# Epoch 22/100  train_loss: 0.41178  valid_loss 0.62037  valid_acc: 0.77806  lr: 0.009825  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 23, Accuracy : 0.8534704370179949
# Epoch 23/100  train_loss: 0.41293  valid_loss 0.45398  valid_acc: 0.85347  lr: 0.009851  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 24, Accuracy : 0.8620394173093402
# Epoch 24/100  train_loss: 0.37764  valid_loss 0.40471  valid_acc: 0.86204  lr: 0.009821  elapsed: 81
# val acc has not improved
# Epoch 25/100  train_loss: 0.38593  valid_loss 0.85225  valid_acc: 0.81405  lr: 0.009818  elapsed: 81
# val acc has not improved
# Epoch 26/100  train_loss: 0.36291  valid_loss 0.41522  valid_acc: 0.85433  lr: 0.009837  elapsed: 81
# val acc has not improved
# Epoch 27/100  train_loss: 0.34837  valid_loss 0.44832  valid_acc: 0.84490  lr: 0.009821  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 28, Accuracy : 0.8766066838046273
# Epoch 28/100  train_loss: 0.35064  valid_loss 0.36437  valid_acc: 0.87661  lr: 0.009825  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 29, Accuracy : 0.8834618680377035
# Epoch 29/100  train_loss: 0.36348  valid_loss 0.33401  valid_acc: 0.88346  lr: 0.009812  elapsed: 81
# val acc has not improved
# Epoch 30/100  train_loss: 0.34737  valid_loss 0.53613  valid_acc: 0.80034  lr: 0.009809  elapsed: 81
# val acc has not improved
# Epoch 31/100  train_loss: 0.33396  valid_loss 0.45911  valid_acc: 0.84319  lr: 0.009843  elapsed: 81
# val acc has not improved
# Epoch 32/100  train_loss: 0.36010  valid_loss 0.51582  valid_acc: 0.82434  lr: 0.009826  elapsed: 81
# val acc has not improved
# Epoch 33/100  train_loss: 0.34551  valid_loss 0.47611  valid_acc: 0.82091  lr: 0.009833  elapsed: 81
# val acc has not improved
# Epoch 34/100  train_loss: 0.31470  valid_loss 0.37782  valid_acc: 0.86975  lr: 0.009835  elapsed: 81
# val acc has not improved
# Epoch 35/100  train_loss: 0.30968  valid_loss 0.39387  valid_acc: 0.87318  lr: 0.009815  elapsed: 81
# val acc has not improved
# Epoch 36/100  train_loss: 0.31406  valid_loss 0.52313  valid_acc: 0.84062  lr: 0.009813  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 37, Accuracy : 0.8920308483290489
# Epoch 37/100  train_loss: 0.30875  valid_loss 0.34136  valid_acc: 0.89203  lr: 0.009827  elapsed: 81
# val acc has not improved
# Epoch 38/100  train_loss: 0.32648  valid_loss 0.33849  valid_acc: 0.87918  lr: 0.009805  elapsed: 81
# val acc has not improved
# Epoch 39/100  train_loss: 0.30384  valid_loss 0.45911  valid_acc: 0.82862  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 40/100  train_loss: 0.31762  valid_loss 0.34893  valid_acc: 0.87575  lr: 0.009832  elapsed: 81
# val acc has not improved
# Epoch 41/100  train_loss: 0.30656  valid_loss 0.42655  valid_acc: 0.85004  lr: 0.009812  elapsed: 81
# val acc has not improved
# Epoch 42/100  train_loss: 0.32244  valid_loss 0.38157  valid_acc: 0.88089  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 43/100  train_loss: 0.30015  valid_loss 0.54201  valid_acc: 0.82005  lr: 0.009810  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 44, Accuracy : 0.8937446443873179
# Epoch 44/100  train_loss: 0.29685  valid_loss 0.35818  valid_acc: 0.89374  lr: 0.009835  elapsed: 81
# val acc has not improved
# Epoch 45/100  train_loss: 0.29483  valid_loss 0.52132  valid_acc: 0.82005  lr: 0.009804  elapsed: 81
# val acc has not improved
# Epoch 46/100  train_loss: 0.29332  valid_loss 0.36478  valid_acc: 0.88003  lr: 0.009835  elapsed: 81
# val acc has not improved
# Epoch 47/100  train_loss: 0.31097  valid_loss 0.39243  valid_acc: 0.86461  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 48/100  train_loss: 0.30783  valid_loss 1.12098  valid_acc: 0.83890  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 49/100  train_loss: 0.30070  valid_loss 0.37888  valid_acc: 0.86375  lr: 0.009827  elapsed: 81
# val acc has not improved
# Epoch 50/100  train_loss: 0.29452  valid_loss 0.36225  valid_acc: 0.87746  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 51/100  train_loss: 0.29427  valid_loss 0.36437  valid_acc: 0.86632  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 52/100  train_loss: 0.29149  valid_loss 0.34938  valid_acc: 0.88775  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 53/100  train_loss: 0.28340  valid_loss 0.45568  valid_acc: 0.83548  lr: 0.009807  elapsed: 81
# val acc has not improved
# Epoch 54/100  train_loss: 0.29262  valid_loss 0.37850  valid_acc: 0.87832  lr: 0.009829  elapsed: 81
# val acc has not improved
# Epoch 55/100  train_loss: 0.29638  valid_loss 0.36707  valid_acc: 0.87746  lr: 0.009811  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 56, Accuracy : 0.8946015424164524
# Epoch 56/100  train_loss: 0.29794  valid_loss 0.31456  valid_acc: 0.89460  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 57/100  train_loss: 0.29192  valid_loss 0.42425  valid_acc: 0.84919  lr: 0.009804  elapsed: 81
# val acc has not improved
# Epoch 58/100  train_loss: 0.28207  valid_loss 0.32580  valid_acc: 0.88003  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 59/100  train_loss: 0.28005  valid_loss 0.33518  valid_acc: 0.88946  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 60/100  train_loss: 0.26407  valid_loss 0.42994  valid_acc: 0.85690  lr: 0.009806  elapsed: 81
# val acc has not improved
# Epoch 61/100  train_loss: 0.28016  valid_loss 0.41453  valid_acc: 0.86204  lr: 0.009820  elapsed: 81
# val acc has not improved
# Epoch 62/100  train_loss: 0.29589  valid_loss 0.37171  valid_acc: 0.87832  lr: 0.009818  elapsed: 81
# val acc has not improved
# Epoch 63/100  train_loss: 0.28236  valid_loss 0.51284  valid_acc: 0.84833  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 64/100  train_loss: 0.27546  valid_loss 0.35856  valid_acc: 0.87489  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 65/100  train_loss: 0.28018  valid_loss 0.33151  valid_acc: 0.88518  lr: 0.009812  elapsed: 81
# val acc has not improved
# Epoch 66/100  train_loss: 0.27578  valid_loss 0.30562  valid_acc: 0.88603  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 67/100  train_loss: 0.27850  valid_loss 0.38308  valid_acc: 0.86632  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 68/100  train_loss: 0.29605  valid_loss 0.38677  valid_acc: 0.86718  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 69/100  train_loss: 0.29638  valid_loss 0.35714  valid_acc: 0.88260  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 70/100  train_loss: 0.28104  valid_loss 0.34992  valid_acc: 0.87746  lr: 0.009809  elapsed: 81
# val acc has not improved
# Epoch 71/100  train_loss: 0.27933  valid_loss 0.36415  valid_acc: 0.87575  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 72/100  train_loss: 0.27379  valid_loss 0.49966  valid_acc: 0.84319  lr: 0.009812  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 73, Accuracy : 0.8988860325621251
# Epoch 73/100  train_loss: 0.27683  valid_loss 0.32340  valid_acc: 0.89889  lr: 0.009826  elapsed: 81
# val acc has not improved
# Epoch 74/100  train_loss: 0.27009  valid_loss 0.33925  valid_acc: 0.87575  lr: 0.009802  elapsed: 81
# val acc has not improved
# Epoch 75/100  train_loss: 0.28813  valid_loss 0.55395  valid_acc: 0.80805  lr: 0.009812  elapsed: 81
# val acc has not improved
# Epoch 76/100  train_loss: 0.28813  valid_loss 0.34848  valid_acc: 0.88003  lr: 0.009840  elapsed: 81
# val acc has not improved
# Epoch 77/100  train_loss: 0.25283  valid_loss 0.33784  valid_acc: 0.89717  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 78/100  train_loss: 0.28651  valid_loss 0.33990  valid_acc: 0.87061  lr: 0.009803  elapsed: 81
# val acc has not improved
# Epoch 79/100  train_loss: 0.26897  valid_loss 0.38568  valid_acc: 0.86632  lr: 0.009814  elapsed: 81
# val acc has not improved
# Epoch 80/100  train_loss: 0.27431  valid_loss 0.33782  valid_acc: 0.88518  lr: 0.009816  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 81, Accuracy : 0.9023136246786633
# Epoch 81/100  train_loss: 0.25677  valid_loss 0.29750  valid_acc: 0.90231  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 82/100  train_loss: 0.28123  valid_loss 0.34509  valid_acc: 0.88518  lr: 0.009800  elapsed: 81
# val acc has not improved
# Epoch 83/100  train_loss: 0.27317  valid_loss 0.31891  valid_acc: 0.89546  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 84/100  train_loss: 0.27626  valid_loss 0.38187  valid_acc: 0.87147  lr: 0.009803  elapsed: 81
# val acc has not improved
# Epoch 85/100  train_loss: 0.25763  valid_loss 0.42380  valid_acc: 0.85690  lr: 0.009814  elapsed: 81
# val acc has not improved
# Epoch 86/100  train_loss: 0.25780  valid_loss 0.30579  valid_acc: 0.89117  lr: 0.009820  elapsed: 81
# val acc has not improved
# Epoch 87/100  train_loss: 0.25952  valid_loss 0.40204  valid_acc: 0.87061  lr: 0.009805  elapsed: 81
# val acc has not improved
# Epoch 88/100  train_loss: 0.27776  valid_loss 0.33505  valid_acc: 0.88089  lr: 0.009814  elapsed: 81
# val acc has not improved
# Epoch 89/100  train_loss: 0.27097  valid_loss 0.34435  valid_acc: 0.88432  lr: 0.009810  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 90, Accuracy : 0.9074550128534704
# Epoch 90/100  train_loss: 0.25137  valid_loss 0.28624  valid_acc: 0.90746  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 91/100  train_loss: 0.26969  valid_loss 0.39790  valid_acc: 0.85690  lr: 0.009798  elapsed: 81
# val acc has not improved
# Epoch 92/100  train_loss: 0.28988  valid_loss 0.37426  valid_acc: 0.86632  lr: 0.009820  elapsed: 81
# val acc has not improved
# Epoch 93/100  train_loss: 0.26645  valid_loss 0.33036  valid_acc: 0.87832  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 94/100  train_loss: 0.25578  valid_loss 0.54378  valid_acc: 0.81405  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 95/100  train_loss: 0.27057  valid_loss 0.34583  valid_acc: 0.88003  lr: 0.009837  elapsed: 86
# val acc has not improved
# Epoch 96/100  train_loss: 0.26244  valid_loss 0.35974  valid_acc: 0.87575  lr: 0.009810  elapsed: 82
# val acc has not improved
# Epoch 97/100  train_loss: 0.27625  valid_loss 0.40113  valid_acc: 0.86375  lr: 0.009812  elapsed: 81
# val acc has not improved
# Epoch 98/100  train_loss: 0.26626  valid_loss 0.34708  valid_acc: 0.88946  lr: 0.009817  elapsed: 83
# val acc has not improved
# Epoch 99/100  train_loss: 0.27323  valid_loss 0.43577  valid_acc: 0.86718  lr: 0.009806  elapsed: 82
# val acc has not improved
# Epoch 100/100  train_loss: 0.27659  valid_loss 0.31651  valid_acc: 0.88518  lr: 0.009816  elapsed: 82
# ================ ༼ つ ◕_◕ ༽つ Model Load 4_th FOLD ===============
# predict values check :  [ 5.40604305 -0.18897673 -0.29593635  0.48506075 -2.84063911 -2.57084036]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 4_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
