# %% [markdown]
# # 세원님 baseline
# ---
# # - changes
#     model : efficientnet_B5
#     transforms
#     optimizer -- SGD
#     scheduler -- cosineannealing
# ---

# %%
import gc
import os
import time
import numpy as np
import pandas as pd
from glob import glob
import tqdm
import argparse
import tqdm
from collections import defaultdict, Counter
from PIL import Image
import cv2

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch import nn, cuda
from torch.autograd import Variable 
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import CenterCrop

from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR
from utils import count_parameters, seed_everything, AdamW, CosineAnnealingWithRestartsLR

from efficientnet_pytorch import EfficientNet
import torchvision.models as models

from model import Baseline, Resnet18, Resnet50, Resnext50, Resnext101
from customs import mixup_data, mixup_criterion
from transforms import get_transform
from dataloader import make_loader, TestDataset

from torchvision.models.resnet import ResNet, Bottleneck

from efficientnet_pytorch import EfficientNet

def to_numpy(t):
        return t.cpu().detach().numpy()

def make_folds(df, n_folds: int) -> pd.DataFrame:

    cls_counts = Counter([classes for classes in df['label']])
    fold_cls_counts = defaultdict()
    for class_index in cls_counts.keys():
        fold_cls_counts[class_index] = np.zeros(n_folds, dtype=np.int)

    df['fold'] = -1
    pbar = tqdm.tqdm(total=len(df))

    def get_fold(row):
        class_index = row['label']
        counts = fold_cls_counts[class_index]
        fold = np.argmin(counts)
        counts[fold] += 1
        fold_cls_counts[class_index] = counts
        row['fold']=fold
        pbar.update()
        return row

    df = df.apply(get_fold, axis=1)
    return df

def make_label(label):
    if label == 'MA':
        return 1
    elif label == 'GMA':
        return 2
    elif label == 'BOY':
        return 3
    elif label == 'FA':
        return 4
    elif label == 'GFA':
        return 5
    #elif label == 'GIRL':
    else:
        return 6


class TrainDataset(Dataset):
    def __init__(self, df, mode='train', transforms=None):
        self.df = df
        self.mode = mode
        self.transform = transforms[self.mode]

    def __len__(self):            
        return len(self.df)

    def __getitem__(self, idx):

        image = Image.open(IMAGES_PATH + '/' + self.df['filename'][idx]).convert("RGB")

        if self.transform:
            image = self.transform(image)
        label = self.df['label'][idx]

        return image, label

def make_loader(df, transforms, batch_size=256, num_workers=0):

    dataset = TrainDataset(df, transforms2)
    # dataset = image, label from Glass_Dataset

    loader = DataLoader(dataset, # image, label
                        batch_size=batch_size,
                        shuffle=True, 
                        num_workers=num_workers, 
                        pin_memory=True)

    return loader

class TestDataset(Dataset):
        def __init__(self, df, transform=None):
            self.df = df
            self.transform = transform

        def __len__(self):
            return len(self.df)

        def __getitem__(self, idx):

            image = Image.open(IMAGES_PATH+'/'+self.df['filename'][idx]).convert('RGB')

            if self.transform:
                image = self.transform(image)

            return image

IMAGES_PATH = 'C:/SEOYILGUK/JOB_VISION/faces_images'
csv_path = 'C:/SEOYILGUK/JOB_VISION/train.csv'
train_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/train.csv')
test_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/test.csv')

def make_df(image_path, csv_path):
    csv_df = pd.read_csv(csv_path)
    path_df = pd.DataFrame()
    file_list = os.listdir(image_path)
    path_df['filename'] = file_list
    path_df = path_df.iloc[1:,:] # remove .DS_Store filename
    df = csv_df.merge(path_df, on='filename', how='left')
    df['label'] = df['label']-1
    print(df.label.value_counts())
    return df

#num_fold = 0 #select fold number for training
for num_fold in range(5):
    
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 STARTS {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
    train_csv = pd.read_csv("../JOB_VISION/train.csv")

    

    SEED = 42
    seed_everything(SEED)

    device = 'cuda'
    use_gpu = cuda.is_available()

    if use_gpu:
        print("enable gpu use")
    else:
        print("enable cpu for debugging")

    target_size = (128, 128)

    num_classes = 6
    model = EfficientNet.from_name('efficientnet-b5')
    model._fc = nn.Linear(2048, num_classes)
    model.cuda()

    #model = models.resnet50() 
    #model.fc = nn.Linear(2048, args.num_classes)

    # elif args.model == 'resnet18': 
    #     model = Resnet18(args.num_classes, dropout=False)
    # elif args.model == 'resnet50':
    #     model = Resnet50(args.num_classes, dropout=False)
    # elif args.model == 'efficient':
    #     model = EfficientNet.from_pretrained('efficientnet-b0')
    #     in_features = model._fc.in_features
    #     model._fc = nn.Linear(in_features, args.num_classes)
    # elif args.model == 'densenet201':
    #     model = models.densenet201(pretrained=True)
    #     model.classifier = nn.Linear(1920, args.num_classes)
    # elif args.model == 'resnext50':
    #     model = Resnext50(args.num_classes, dropout=False)
    # elif args.model == 'resnext101':
    #     model = Resnext101(args.num_classes, dropout=False)
    # elif args.model == 'mobilenet':
    #     assert args.input_size == 158
    #     model = torch.hub.load('pytorch/vision', 'mobilenet_v2', pretrained=True)
    #     model.classifier = nn.Sequential(nn.Dropout(0.2),
    #                         nn.Linear(1280, args.num_classes))
    # else:
    #     raise NotImplementedError

    if use_gpu:
        model = model.to(device)

    # optimizer = optim.Adam(model.parameters(), args.lr, weight_decay=0.00025)
    #optimizer = AdamW(model.parameters(), 2.5e-4, weight_decay=0.000025)
    optimizer = optim.SGD(model.parameters(), 0.01, momentum=0.9, weight_decay=0.0025)

    ###### SCHEDULER #######
    #scheduler = ReduceLROnPlateau(optimizer, 'max', patience=5, factor=0.5)

    eta_min = 0.000001
    T_max = 10
    T_mult = 1
    restart_decay = 0.97
    scheduler = CosineAnnealingWithRestartsLR(optimizer, T_max=T_max, eta_min=eta_min, T_mult=T_mult, restart_decay=restart_decay)

    #scheduler = StepLR(optimizer, step_size=5, gamma=0.5)

    criterion = nn.CrossEntropyLoss() 

    num_parameters = count_parameters(model)
    print("==== number of parameters that can be trained: {}".format(num_parameters))

    df = make_df(IMAGES_PATH, csv_path)

    # 5 stratifiedKFold
    folds = make_folds(df, 5)
    print("==== fold_df created")
    print(folds.head())

    train_df = folds[folds['fold'] != num_fold]
    valid_df = folds[folds['fold'] == num_fold]

    train_df = train_df[['filename', 'label']].reset_index(drop=True)
    valid_df = valid_df[['filename', 'label']].reset_index(drop=True)
    print("number of train images: {}".format(len(train_df)))
    print("number of valid images: {}".format(len(valid_df)))

    start_time = time.time()
    
    print("shape of the df: {}".format(df.shape))    
    
    data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(target_size, scale=(0.7, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(
                brightness=0.4,
                contrast=0.4,
                saturation=0.4,
            ),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5161, 0.4225, 0.3763], 
            [0.2442, 0.2184, 0.2164]
        )]),
    'valid': transforms.Compose([
        transforms.RandomResizedCrop(target_size, scale=(0.8, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5161, 0.4225, 0.3763], 
            [0.2442, 0.2184, 0.2164]
        )])
    }
    
    batch_size = 32
    train_dataset = TrainDataset(train_df, mode='train', transforms=data_transforms)
    valid_dataset = TrainDataset(valid_df, mode='valid', transforms=data_transforms)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    print("number train batches: {}".format(len(train_loader)))
    print("number valid batches: {}".format(len(valid_loader)))
    elapsed = time.time() - start_time
    print("elapsed: {:.0f}".format(elapsed))

    best_val_acc = 0
    grad_clip_step = 100
    grad_clip = 100
    step = 0
    # accumulation_step = 2

    print("start training")

    for epoch_idx in range(1, 100 + 1):

        start_time = time.time()

        train_loss = 0
        train_total_correct = 0
        model.train()
        optimizer.zero_grad()

        for batch_idx, (image, labels) in enumerate(train_loader):
            if use_gpu:
                image = image.to(device)
                labels = labels.to(device)

            # print("shape of the image: {}".format(image.shape))
            # print("shape of the labels: {}".format(labels.shape))
            # print(image)
            # print(labels)

            #if args.mixup_loss:
            #    inputs, targets_a, targets_b, lam = mixup_data(image, labels, alpha=0.4, device=device)
            #    inputs, targets_a, targets_b = map(Variable, (inputs, targets_a, targets_b))
            #    output = model(inputs)
            #    loss = mixup_criterion(criterion, output.to(device), targets_a.to(device), targets_b.to(device), lam)
            #else:
            output = model(image)
            loss = criterion(output, labels)

            # gradient explosion prevention
            if step > grad_clip_step:
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

            step += 1

            loss.backward()

            optimizer.step()
            optimizer.zero_grad()

            # output_prob = F.softmax(output, dim=1)

            train_loss += loss.item() / len(train_loader)

        # Validation Starts
        model.eval()
        valid_loss = 0
        valid_total_correct = 0

        with torch.no_grad():
            for batch_idx, (image, labels) in enumerate(valid_loader):
                if use_gpu:
                    image = image.to(device)
                    labels = labels.to(device)


                output = model(image)
                loss = criterion(output, labels)

                output_prob = F.softmax(output, dim=1)

                predict_vector = np.argmax(to_numpy(output_prob), axis=1)
                label_vector = to_numpy(labels)
                bool_vector = predict_vector == label_vector
                #print('val_pred', predict_vector[:5])
                #print('val_label', label_vector[:5])
                #print("shape of prediction vector: {}".format(predict_vector.shape))
                #print(predict_vector.head())
                #print("shape of label vector: {}".format(label_vector.shape))

                valid_loss += loss.item() / len(valid_loader)
                valid_total_correct += bool_vector.sum()


        elapsed = time.time() - start_time

        val_acc = valid_total_correct / len(valid_loader.dataset)

        # best val_acc checkpoint
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            print("val_acc has improved !! ")
            torch.save(model.state_dict(), 'efficientnet_B5_fold_{}_best_model.pt'.format(num_fold))
            print("================ ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ".format(epoch_idx, best_val_acc))
            #file_save_name = 'best_acc' + '_' + str(num_fold)
            #print(file_save_name)
        else:
            print("val acc has not improved")

        lr = [_['lr'] for _ in optimizer.param_groups]

        #if args.scheduler == 'plateau':
        scheduler.step(val_acc)
        #else:
        #    scheduler.step()

        # nsml.save(epoch_idx)

        print("Epoch {}/{}  train_loss: {:.5f}  valid_loss {:.5f}  valid_acc: {:.5f}  lr: {:.6f}  elapsed: {:.0f}".format(
               epoch_idx, 100, train_loss, valid_loss, val_acc, lr[0], elapsed))
                #epoch_idx, args.epochs, train_loss, valid_loss, val_acc, lr[0], elapsed

#    IMAGES_PATH = 'C:/SEOYILGUK/JOB_VISION/faces_images'
#    test_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/test.csv')

    batch_size = 32
    num_workers = 0

    # model = models.resnet18(pretrained=False) 
    # model.fc = nn.Linear(512, args.num_classes)

    # checkpoint = 'team012/KHD2019_FUNDUS/93'
    # nsml.load(checkpoint, load_fn=load)

    test_transforms = transforms.Compose([
                        transforms.RandomResizedCrop(target_size, scale=(0.8, 1.0)),
                        transforms.RandomHorizontalFlip(),
                        transforms.ToTensor(),
                        transforms.Normalize(
                            [0.5161, 0.4225, 0.3763], 
                            [0.2442, 0.2184, 0.2164])
                    ])

    test_dataset = TestDataset(test_df, test_transforms)
    test_loader = DataLoader(test_dataset,
                             batch_size=batch_size,
                             shuffle=False, 
                             num_workers=num_workers, 
                             pin_memory=True)
    
    print("============== ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ====================================".format(epoch_idx, best_val_acc))
    print("========================== ༼ つ ◕_◕ ༽つ Model Load {}_th FOLD =================================".format(num_fold))
    model.load_state_dict(torch.load('efficientnet_B5_fold_{}_best_model.pt'.format(num_fold)))

    model.eval()
    # for _ in range(tta):
        # print("tta {} predict".format(_+1))
    predictions = np.zeros((len(test_loader.dataset), 6))

    with torch.no_grad():
        for i, image in enumerate(test_loader):
            image = image.to(device)
            output = model(image) # output shape (batch_num, num_classes)

            predictions[i*batch_size: (i+1)*batch_size] = output.detach().cpu().numpy()
    print("predict values check : ",predictions[0])
    np.savetxt("../JOB_VISION/efficientnet_B5_submission/efficientnet_B5_{}_fold.csv".format(num_fold), predictions, delimiter=",")
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 SAVED {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
# Out:
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 28353078
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7022.43it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43894107600341586
# Epoch 1/100  train_loss: 1.55685  valid_loss 1.49865  valid_acc: 0.43894  lr: 0.010000  elapsed: 91
# val acc has not improved
# Epoch 2/100  train_loss: 1.48825  valid_loss 1.44355  valid_acc: 0.43894  lr: 0.009953  elapsed: 94
# val acc has not improved
# Epoch 3/100  train_loss: 1.43430  valid_loss 1.43022  valid_acc: 0.43894  lr: 0.009953  elapsed: 95
# val acc has not improved
# Epoch 4/100  train_loss: 1.36496  valid_loss 1.42985  valid_acc: 0.43894  lr: 0.009953  elapsed: 94
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5123825789923142
# Epoch 5/100  train_loss: 1.29967  valid_loss 1.36992  valid_acc: 0.51238  lr: 0.009953  elapsed: 94
# val acc has not improved
# Epoch 6/100  train_loss: 1.17279  valid_loss 1.29835  valid_acc: 0.50897  lr: 0.009935  elapsed: 94
# val acc has not improved
# Epoch 7/100  train_loss: 1.00961  valid_loss 1.25144  valid_acc: 0.49103  lr: 0.009936  elapsed: 94
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.730999146029035
# Epoch 8/100  train_loss: 0.82687  valid_loss 0.77068  valid_acc: 0.73100  lr: 0.009941  elapsed: 95
# val acc has not improved
# Epoch 9/100  train_loss: 0.72630  valid_loss 0.77858  valid_acc: 0.70965  lr: 0.009869  elapsed: 95
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7694278394534586
# Epoch 10/100  train_loss: 0.62940  valid_loss 0.74734  valid_acc: 0.76943  lr: 0.009876  elapsed: 94
# val acc has not improved
# Epoch 11/100  train_loss: 0.59228  valid_loss 0.76777  valid_acc: 0.74295  lr: 0.009855  elapsed: 94
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.7736976942783945
# Epoch 12/100  train_loss: 0.55867  valid_loss 0.65332  valid_acc: 0.77370  lr: 0.009864  elapsed: 94
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.7771135781383433
# Epoch 13/100  train_loss: 0.53745  valid_loss 0.60865  valid_acc: 0.77711  lr: 0.009853  elapsed: 94
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 14, Accuracy : 0.8274978650725875
# Epoch 14/100  train_loss: 0.51745  valid_loss 0.58537  valid_acc: 0.82750  lr: 0.009852  elapsed: 94
# val acc has not improved
# Epoch 15/100  train_loss: 0.49347  valid_loss 0.51735  valid_acc: 0.82237  lr: 0.009832  elapsed: 95
# val acc has not improved
# Epoch 16/100  train_loss: 0.47215  valid_loss 0.60880  valid_acc: 0.79249  lr: 0.009834  elapsed: 94
# val acc has not improved
# Epoch 17/100  train_loss: 0.45432  valid_loss 0.57060  valid_acc: 0.81554  lr: 0.009846  elapsed: 94
# val acc has not improved
# Epoch 18/100  train_loss: 0.48186  valid_loss 0.63206  valid_acc: 0.78053  lr: 0.009837  elapsed: 94
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 19, Accuracy : 0.8360375747224594
# Epoch 19/100  train_loss: 0.44444  valid_loss 0.53832  valid_acc: 0.83604  lr: 0.009850  elapsed: 95
# val acc has not improved
# Epoch 20/100  train_loss: 0.45666  valid_loss 0.49298  valid_acc: 0.83348  lr: 0.009829  elapsed: 94
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 21, Accuracy : 0.8368915456874466
# Epoch 21/100  train_loss: 0.43922  valid_loss 0.48402  valid_acc: 0.83689  lr: 0.009830  elapsed: 94
# val acc has not improved
# Epoch 22/100  train_loss: 0.43080  valid_loss 0.56197  valid_acc: 0.81469  lr: 0.009828  elapsed: 94
# val acc has not improved
# Epoch 23/100  train_loss: 0.43174  valid_loss 0.64893  valid_acc: 0.75149  lr: 0.009837  elapsed: 94
# val acc has not improved
# Epoch 24/100  train_loss: 0.43246  valid_loss 0.52173  valid_acc: 0.80786  lr: 0.009861  elapsed: 94
# val acc has not improved
# Epoch 25/100  train_loss: 0.42945  valid_loss 0.58894  valid_acc: 0.82408  lr: 0.009840  elapsed: 94
# val acc has not improved
# Epoch 26/100  train_loss: 0.41818  valid_loss 0.54057  valid_acc: 0.80956  lr: 0.009833  elapsed: 94
# val acc has not improved
# Epoch 27/100  train_loss: 0.40251  valid_loss 0.63060  valid_acc: 0.79590  lr: 0.009839  elapsed: 94
# val acc has not improved
# Epoch 28/100  train_loss: 0.42006  valid_loss 0.56969  valid_acc: 0.80871  lr: 0.009845  elapsed: 94
# val acc has not improved
# Epoch 29/100  train_loss: 0.40648  valid_loss 0.59937  valid_acc: 0.76687  lr: 0.009840  elapsed: 94
# val acc has not improved
# Epoch 30/100  train_loss: 0.40714  valid_loss 0.51616  valid_acc: 0.81896  lr: 0.009856  elapsed: 94
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 31, Accuracy : 0.856532877882152
# Epoch 31/100  train_loss: 0.39306  valid_loss 0.55761  valid_acc: 0.85653  lr: 0.009835  elapsed: 94
# val acc has not improved
# Epoch 32/100  train_loss: 0.40418  valid_loss 0.53336  valid_acc: 0.81810  lr: 0.009820  elapsed: 94
# val acc has not improved
# Epoch 33/100  train_loss: 0.37771  valid_loss 0.49094  valid_acc: 0.84885  lr: 0.009836  elapsed: 94
# val acc has not improved
# Epoch 34/100  train_loss: 0.40257  valid_loss 0.45171  valid_acc: 0.83091  lr: 0.009823  elapsed: 94
# val acc has not improved
# Epoch 35/100  train_loss: 0.40851  valid_loss 0.58330  valid_acc: 0.78736  lr: 0.009831  elapsed: 94
# val acc has not improved
# Epoch 36/100  train_loss: 0.38902  valid_loss 0.73823  valid_acc: 0.72331  lr: 0.009848  elapsed: 94
# val acc has not improved
# Epoch 37/100  train_loss: 0.39278  valid_loss 1.00129  valid_acc: 0.61230  lr: 0.009871  elapsed: 94
# val acc has not improved
# Epoch 38/100  train_loss: 0.39917  valid_loss 0.43841  valid_acc: 0.83689  lr: 0.009908  elapsed: 94
# val acc has not improved
# Epoch 39/100  train_loss: 0.37643  valid_loss 0.39531  valid_acc: 0.85397  lr: 0.009828  elapsed: 90
# val acc has not improved
# Epoch 40/100  train_loss: 0.38546  valid_loss 0.43653  valid_acc: 0.84287  lr: 0.009821  elapsed: 82
# val acc has not improved
# Epoch 41/100  train_loss: 0.39661  valid_loss 0.42896  valid_acc: 0.85312  lr: 0.009826  elapsed: 82
# val acc has not improved
# Epoch 42/100  train_loss: 0.39822  valid_loss 0.60268  valid_acc: 0.76857  lr: 0.009822  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 43, Accuracy : 0.8625106746370623
# Epoch 43/100  train_loss: 0.38048  valid_loss 0.40792  valid_acc: 0.86251  lr: 0.009855  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 44, Accuracy : 0.8667805294619982
# Epoch 44/100  train_loss: 0.38733  valid_loss 0.40452  valid_acc: 0.86678  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 45/100  train_loss: 0.39138  valid_loss 0.49303  valid_acc: 0.83604  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 46/100  train_loss: 0.39333  valid_loss 0.40572  valid_acc: 0.85653  lr: 0.009829  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 47, Accuracy : 0.8684884713919727
# Epoch 47/100  train_loss: 0.37481  valid_loss 0.36197  valid_acc: 0.86849  lr: 0.009820  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 48, Accuracy : 0.8736122971818958
# Epoch 48/100  train_loss: 0.37762  valid_loss 0.36609  valid_acc: 0.87361  lr: 0.009815  elapsed: 82
# val acc has not improved
# Epoch 49/100  train_loss: 0.37731  valid_loss 0.38271  valid_acc: 0.86507  lr: 0.009813  elapsed: 81
# val acc has not improved
# Epoch 50/100  train_loss: 0.39608  valid_loss 0.39357  valid_acc: 0.86507  lr: 0.009817  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 51, Accuracy : 0.8761742100768574
# Epoch 51/100  train_loss: 0.37848  valid_loss 0.35605  valid_acc: 0.87617  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 52/100  train_loss: 0.38153  valid_loss 0.71364  valid_acc: 0.74808  lr: 0.009812  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 53, Accuracy : 0.8804440649017934
# Epoch 53/100  train_loss: 0.36983  valid_loss 0.35842  valid_acc: 0.88044  lr: 0.009863  elapsed: 81
# val acc has not improved
# Epoch 54/100  train_loss: 0.37572  valid_loss 0.41517  valid_acc: 0.84031  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 55/100  train_loss: 0.37955  valid_loss 0.36841  valid_acc: 0.86507  lr: 0.009827  elapsed: 81
# val acc has not improved
# Epoch 56/100  train_loss: 0.38541  valid_loss 0.36637  valid_acc: 0.86849  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 57/100  train_loss: 0.38739  valid_loss 0.32589  valid_acc: 0.87959  lr: 0.009815  elapsed: 81
# val acc has not improved
# Epoch 58/100  train_loss: 0.38589  valid_loss 0.52398  valid_acc: 0.81725  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 59/100  train_loss: 0.37670  valid_loss 0.36568  valid_acc: 0.88044  lr: 0.009836  elapsed: 81
# val acc has not improved
# Epoch 60/100  train_loss: 0.38202  valid_loss 1.08219  valid_acc: 0.63108  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 61/100  train_loss: 0.37621  valid_loss 0.56261  valid_acc: 0.78822  lr: 0.009902  elapsed: 81
# val acc has not improved
# Epoch 62/100  train_loss: 0.36195  valid_loss 0.64164  valid_acc: 0.79334  lr: 0.009848  elapsed: 81
# val acc has not improved
# Epoch 63/100  train_loss: 0.36221  valid_loss 0.37815  valid_acc: 0.87447  lr: 0.009846  elapsed: 81
# val acc has not improved
# Epoch 64/100  train_loss: 0.37904  valid_loss 0.42063  valid_acc: 0.84714  lr: 0.009813  elapsed: 81
# val acc has not improved
# Epoch 65/100  train_loss: 0.38612  valid_loss 0.40416  valid_acc: 0.85824  lr: 0.009824  elapsed: 81
# val acc has not improved
# Epoch 66/100  train_loss: 0.38387  valid_loss 0.40791  valid_acc: 0.87959  lr: 0.009819  elapsed: 81
# val acc has not improved
# Epoch 67/100  train_loss: 0.36065  valid_loss 0.59208  valid_acc: 0.76687  lr: 0.009810  elapsed: 81
# val acc has not improved
# Epoch 68/100  train_loss: 0.36741  valid_loss 0.37723  valid_acc: 0.87703  lr: 0.009856  elapsed: 82
# val acc has not improved
# Epoch 69/100  train_loss: 0.37509  valid_loss 0.41263  valid_acc: 0.85909  lr: 0.009811  elapsed: 82
# val acc has not improved
# Epoch 70/100  train_loss: 0.37775  valid_loss 0.56419  valid_acc: 0.80956  lr: 0.009819  elapsed: 82
# val acc has not improved
# Epoch 71/100  train_loss: 0.36887  valid_loss 0.37465  valid_acc: 0.86422  lr: 0.009839  elapsed: 82
# val acc has not improved
# Epoch 72/100  train_loss: 0.36636  valid_loss 0.39793  valid_acc: 0.86593  lr: 0.009817  elapsed: 81
# val acc has not improved
# Epoch 73/100  train_loss: 0.36921  valid_loss 0.45377  valid_acc: 0.84543  lr: 0.009816  elapsed: 81
# val acc has not improved
# Epoch 74/100  train_loss: 0.37682  valid_loss 0.54500  valid_acc: 0.81640  lr: 0.009825  elapsed: 82
# val acc has not improved
# Epoch 75/100  train_loss: 0.37083  valid_loss 0.41863  valid_acc: 0.86251  lr: 0.009836  elapsed: 81
# val acc has not improved
# Epoch 76/100  train_loss: 0.35690  valid_loss 0.54837  valid_acc: 0.80102  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 77/100  train_loss: 0.36967  valid_loss 0.40895  valid_acc: 0.85141  lr: 0.009843  elapsed: 83
# val acc has not improved
# Epoch 78/100  train_loss: 0.36929  valid_loss 0.41062  valid_acc: 0.85141  lr: 0.009822  elapsed: 82
# val acc has not improved
# Epoch 79/100  train_loss: 0.36828  valid_loss 0.39392  valid_acc: 0.85739  lr: 0.009822  elapsed: 80
# val acc has not improved
# Epoch 80/100  train_loss: 0.37808  valid_loss 0.41223  valid_acc: 0.84885  lr: 0.009820  elapsed: 81
# val acc has not improved
# Epoch 81/100  train_loss: 0.35409  valid_loss 0.51782  valid_acc: 0.81383  lr: 0.009823  elapsed: 80
# val acc has not improved
# Epoch 82/100  train_loss: 0.34762  valid_loss 0.41548  valid_acc: 0.84458  lr: 0.009837  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 83, Accuracy : 0.8838599487617421
# Epoch 83/100  train_loss: 0.38215  valid_loss 0.32890  valid_acc: 0.88386  lr: 0.009825  elapsed: 81
# val acc has not improved
# Epoch 84/100  train_loss: 0.36185  valid_loss 0.41339  valid_acc: 0.85653  lr: 0.009808  elapsed: 81
# val acc has not improved
# Epoch 85/100  train_loss: 0.37063  valid_loss 0.57107  valid_acc: 0.80359  lr: 0.009820  elapsed: 80
# val acc has not improved
# Epoch 86/100  train_loss: 0.37197  valid_loss 0.47519  valid_acc: 0.82835  lr: 0.009842  elapsed: 80
# val acc has not improved
# Epoch 87/100  train_loss: 0.36181  valid_loss 0.50353  valid_acc: 0.82579  lr: 0.009832  elapsed: 81
# val acc has not improved
# Epoch 88/100  train_loss: 0.36166  valid_loss 0.39194  valid_acc: 0.86593  lr: 0.009833  elapsed: 80
# val acc has not improved
# Epoch 89/100  train_loss: 0.36559  valid_loss 0.34714  valid_acc: 0.87276  lr: 0.009816  elapsed: 80
# val acc has not improved
# Epoch 90/100  train_loss: 0.34436  valid_loss 0.47838  valid_acc: 0.84031  lr: 0.009813  elapsed: 81
# val acc has not improved
# Epoch 91/100  train_loss: 0.38016  valid_loss 0.55785  valid_acc: 0.80188  lr: 0.009827  elapsed: 80
# val acc has not improved
# Epoch 92/100  train_loss: 0.36301  valid_loss 0.35759  valid_acc: 0.88215  lr: 0.009842  elapsed: 81
# val acc has not improved
# Epoch 93/100  train_loss: 0.36621  valid_loss 0.56031  valid_acc: 0.80700  lr: 0.009809  elapsed: 81
# val acc has not improved
# Epoch 94/100  train_loss: 0.36141  valid_loss 0.45851  valid_acc: 0.84970  lr: 0.009840  elapsed: 81
# val acc has not improved
# Epoch 95/100  train_loss: 0.35807  valid_loss 0.39588  valid_acc: 0.85312  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 96/100  train_loss: 0.37016  valid_loss 0.42247  valid_acc: 0.85995  lr: 0.009822  elapsed: 80
# val acc has not improved
# Epoch 97/100  train_loss: 0.35608  valid_loss 0.33648  valid_acc: 0.87788  lr: 0.009819  elapsed: 80
# val acc has not improved
# Epoch 98/100  train_loss: 0.39189  valid_loss 0.35022  valid_acc: 0.87788  lr: 0.009811  elapsed: 80
# val acc has not improved
# Epoch 99/100  train_loss: 0.36973  valid_loss 0.42439  valid_acc: 0.85226  lr: 0.009811  elapsed: 81
# val acc has not improved
# Epoch 100/100  train_loss: 0.36139  valid_loss 0.41174  valid_acc: 0.86166  lr: 0.009822  elapsed: 80
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8838599487617421 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 0_th FOLD =================================
# predict values check :  [ 4.33498955 -1.03500271  0.02311569  1.30108809 -3.32699633 -1.29909086]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 28353078
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7195.17it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43894107600341586
# Epoch 1/100  train_loss: 1.56155  valid_loss 1.50179  valid_acc: 0.43894  lr: 0.010000  elapsed: 72
# val acc has not improved
# Epoch 2/100  train_loss: 1.46663  valid_loss 1.43670  valid_acc: 0.43894  lr: 0.009953  elapsed: 81
# val acc has not improved
# Epoch 3/100  train_loss: 1.39803  valid_loss 1.43206  valid_acc: 0.43894  lr: 0.009953  elapsed: 81
# val acc has not improved
# Epoch 4/100  train_loss: 1.35254  valid_loss 1.44593  valid_acc: 0.43894  lr: 0.009953  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5772843723313408
# Epoch 5/100  train_loss: 1.18301  valid_loss 1.27450  valid_acc: 0.57728  lr: 0.009953  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.6404782237403929
# Epoch 6/100  train_loss: 0.97536  valid_loss 0.98327  valid_acc: 0.64048  lr: 0.009918  elapsed: 80
# val acc has not improved
# Epoch 7/100  train_loss: 0.74680  valid_loss 0.91852  valid_acc: 0.62938  lr: 0.009899  elapsed: 84
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.748932536293766
# Epoch 8/100  train_loss: 0.68339  valid_loss 0.74855  valid_acc: 0.74893  lr: 0.009903  elapsed: 88
# val acc has not improved
# Epoch 9/100  train_loss: 0.61204  valid_loss 0.68655  valid_acc: 0.74125  lr: 0.009862  elapsed: 87
# val acc has not improved
# Epoch 10/100  train_loss: 0.54476  valid_loss 0.72982  valid_acc: 0.73954  lr: 0.009865  elapsed: 87
# val acc has not improved
# Epoch 11/100  train_loss: 0.53806  valid_loss 0.69269  valid_acc: 0.73015  lr: 0.009866  elapsed: 87
# val acc has not improved
# Epoch 12/100  train_loss: 0.50387  valid_loss 0.80977  valid_acc: 0.70367  lr: 0.009869  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.7668659265584971
# Epoch 13/100  train_loss: 0.47686  valid_loss 0.62512  valid_acc: 0.76687  lr: 0.009878  elapsed: 87
# val acc has not improved
# Epoch 14/100  train_loss: 0.46302  valid_loss 0.67534  valid_acc: 0.76430  lr: 0.009856  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 15, Accuracy : 0.8112724167378309
# Epoch 15/100  train_loss: 0.48828  valid_loss 0.61459  valid_acc: 0.81127  lr: 0.009857  elapsed: 88
# val acc has not improved
# Epoch 16/100  train_loss: 0.45178  valid_loss 0.80173  valid_acc: 0.69001  lr: 0.009838  elapsed: 87
# val acc has not improved
# Epoch 17/100  train_loss: 0.44491  valid_loss 0.65265  valid_acc: 0.75918  lr: 0.009883  elapsed: 87
# val acc has not improved
# Epoch 18/100  train_loss: 0.45865  valid_loss 0.58187  valid_acc: 0.80786  lr: 0.009858  elapsed: 88
# val acc has not improved
# Epoch 19/100  train_loss: 0.42663  valid_loss 0.60225  valid_acc: 0.78480  lr: 0.009840  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 20, Accuracy : 0.8223740392826644
# Epoch 20/100  train_loss: 0.41931  valid_loss 0.51633  valid_acc: 0.82237  lr: 0.009849  elapsed: 88
# val acc has not improved
# Epoch 21/100  train_loss: 0.41362  valid_loss 0.64917  valid_acc: 0.76516  lr: 0.009834  elapsed: 88
# val acc has not improved
# Epoch 22/100  train_loss: 0.43545  valid_loss 0.60160  valid_acc: 0.78138  lr: 0.009856  elapsed: 87
# val acc has not improved
# Epoch 23/100  train_loss: 0.41993  valid_loss 0.67855  valid_acc: 0.74979  lr: 0.009850  elapsed: 87
# val acc has not improved
# Epoch 24/100  train_loss: 0.41641  valid_loss 0.64729  valid_acc: 0.80615  lr: 0.009862  elapsed: 87
# val acc has not improved
# Epoch 25/100  train_loss: 0.41092  valid_loss 0.67924  valid_acc: 0.74295  lr: 0.009841  elapsed: 88
# val acc has not improved
# Epoch 26/100  train_loss: 0.39034  valid_loss 0.62351  valid_acc: 0.76943  lr: 0.009864  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 27, Accuracy : 0.8309137489325363
# Epoch 27/100  train_loss: 0.38129  valid_loss 0.49785  valid_acc: 0.83091  lr: 0.009855  elapsed: 88
# val acc has not improved
# Epoch 28/100  train_loss: 0.39407  valid_loss 0.57121  valid_acc: 0.81640  lr: 0.009831  elapsed: 87
# val acc has not improved
# Epoch 29/100  train_loss: 0.38981  valid_loss 0.50309  valid_acc: 0.82323  lr: 0.009836  elapsed: 87
# val acc has not improved
# Epoch 30/100  train_loss: 0.38508  valid_loss 0.73493  valid_acc: 0.70453  lr: 0.009834  elapsed: 87
# val acc has not improved
# Epoch 31/100  train_loss: 0.38198  valid_loss 0.56024  valid_acc: 0.78822  lr: 0.009878  elapsed: 87
# val acc has not improved
# Epoch 32/100  train_loss: 0.40038  valid_loss 0.51709  valid_acc: 0.82494  lr: 0.009848  elapsed: 87
# val acc has not improved
# Epoch 33/100  train_loss: 0.39992  valid_loss 0.57508  valid_acc: 0.80017  lr: 0.009833  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 34, Accuracy : 0.8471391972672929
# Epoch 34/100  train_loss: 0.39303  valid_loss 0.41901  valid_acc: 0.84714  lr: 0.009843  elapsed: 87
# val acc has not improved
# Epoch 35/100  train_loss: 0.37925  valid_loss 0.69354  valid_acc: 0.74210  lr: 0.009824  elapsed: 87
# val acc has not improved
# Epoch 36/100  train_loss: 0.37911  valid_loss 0.55642  valid_acc: 0.79761  lr: 0.009865  elapsed: 87
# val acc has not improved
# Epoch 37/100  train_loss: 0.38045  valid_loss 0.53867  valid_acc: 0.81127  lr: 0.009844  elapsed: 87
# val acc has not improved
# Epoch 38/100  train_loss: 0.39119  valid_loss 0.43555  valid_acc: 0.83348  lr: 0.009838  elapsed: 88
# val acc has not improved
# Epoch 39/100  train_loss: 0.38687  valid_loss 0.52076  valid_acc: 0.80188  lr: 0.009830  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 40, Accuracy : 0.8684884713919727
# Epoch 40/100  train_loss: 0.38312  valid_loss 0.39667  valid_acc: 0.86849  lr: 0.009842  elapsed: 81
# val acc has not improved
# Epoch 41/100  train_loss: 0.38772  valid_loss 0.47717  valid_acc: 0.83775  lr: 0.009815  elapsed: 81
# val acc has not improved
# Epoch 42/100  train_loss: 0.39500  valid_loss 0.52579  valid_acc: 0.81213  lr: 0.009828  elapsed: 81
# val acc has not improved
# Epoch 43/100  train_loss: 0.36706  valid_loss 0.45529  valid_acc: 0.84970  lr: 0.009838  elapsed: 81
# val acc has not improved
# Epoch 44/100  train_loss: 0.37437  valid_loss 0.42496  valid_acc: 0.84287  lr: 0.009823  elapsed: 81
# val acc has not improved
# Epoch 45/100  train_loss: 0.38200  valid_loss 0.44942  valid_acc: 0.84116  lr: 0.009826  elapsed: 81
# val acc has not improved
# Epoch 46/100  train_loss: 0.39491  valid_loss 0.56227  valid_acc: 0.79249  lr: 0.009826  elapsed: 81
# val acc has not improved
# Epoch 47/100  train_loss: 0.37211  valid_loss 0.62215  valid_acc: 0.79505  lr: 0.009846  elapsed: 81
# val acc has not improved
# Epoch 48/100  train_loss: 0.36986  valid_loss 0.51889  valid_acc: 0.81640  lr: 0.009845  elapsed: 80
# val acc has not improved
# Epoch 49/100  train_loss: 0.37694  valid_loss 0.49692  valid_acc: 0.81640  lr: 0.009836  elapsed: 83
# val acc has not improved
# Epoch 50/100  train_loss: 0.37458  valid_loss 0.40259  valid_acc: 0.86166  lr: 0.009836  elapsed: 83
# val acc has not improved
# Epoch 51/100  train_loss: 0.37592  valid_loss 0.66566  valid_acc: 0.80615  lr: 0.009818  elapsed: 83
# val acc has not improved
# Epoch 52/100  train_loss: 0.38749  valid_loss 0.44010  valid_acc: 0.84116  lr: 0.009841  elapsed: 81
# val acc has not improved
# Epoch 53/100  train_loss: 0.36524  valid_loss 0.39576  valid_acc: 0.84543  lr: 0.009826  elapsed: 81
# val acc has not improved
# Epoch 54/100  train_loss: 0.36440  valid_loss 0.51691  valid_acc: 0.80615  lr: 0.009825  elapsed: 81
# val acc has not improved
# Epoch 55/100  train_loss: 0.37065  valid_loss 0.41411  valid_acc: 0.84799  lr: 0.009841  elapsed: 81
# val acc has not improved
# Epoch 56/100  train_loss: 0.36967  valid_loss 0.40358  valid_acc: 0.86336  lr: 0.009824  elapsed: 81
# val acc has not improved
# Epoch 57/100  train_loss: 0.36712  valid_loss 0.49922  valid_acc: 0.83860  lr: 0.009817  elapsed: 80
# val acc has not improved
# Epoch 58/100  train_loss: 0.36962  valid_loss 0.60245  valid_acc: 0.78053  lr: 0.009827  elapsed: 80
# val acc has not improved
# Epoch 59/100  train_loss: 0.34215  valid_loss 0.42125  valid_acc: 0.83433  lr: 0.009850  elapsed: 81
# val acc has not improved
# Epoch 60/100  train_loss: 0.36551  valid_loss 1.35422  valid_acc: 0.56362  lr: 0.009829  elapsed: 81
# val acc has not improved
# Epoch 61/100  train_loss: 0.37847  valid_loss 0.39622  valid_acc: 0.84885  lr: 0.009922  elapsed: 81
# val acc has not improved
# Epoch 62/100  train_loss: 0.37385  valid_loss 0.47870  valid_acc: 0.82664  lr: 0.009823  elapsed: 80
# val acc has not improved
# Epoch 63/100  train_loss: 0.35396  valid_loss 0.56554  valid_acc: 0.80359  lr: 0.009832  elapsed: 81
# val acc has not improved
# Epoch 64/100  train_loss: 0.37176  valid_loss 0.40221  valid_acc: 0.85739  lr: 0.009842  elapsed: 81
# val acc has not improved
# Epoch 65/100  train_loss: 0.35966  valid_loss 0.50620  valid_acc: 0.82494  lr: 0.009820  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 66, Accuracy : 0.8736122971818958
# Epoch 66/100  train_loss: 0.37221  valid_loss 0.36180  valid_acc: 0.87361  lr: 0.009833  elapsed: 81
# val acc has not improved
# Epoch 67/100  train_loss: 0.36080  valid_loss 0.41666  valid_acc: 0.85568  lr: 0.009813  elapsed: 80
# val acc has not improved
# Epoch 68/100  train_loss: 0.35867  valid_loss 0.45447  valid_acc: 0.83860  lr: 0.009820  elapsed: 82
# val acc has not improved
# Epoch 69/100  train_loss: 0.34674  valid_loss 0.43357  valid_acc: 0.84372  lr: 0.009827  elapsed: 81
# val acc has not improved
# Epoch 70/100  train_loss: 0.36891  valid_loss 0.63868  valid_acc: 0.80956  lr: 0.009825  elapsed: 80
# val acc has not improved
# Epoch 71/100  train_loss: 0.35531  valid_loss 0.45886  valid_acc: 0.85141  lr: 0.009839  elapsed: 80
# val acc has not improved
# Epoch 72/100  train_loss: 0.35606  valid_loss 0.56241  valid_acc: 0.80102  lr: 0.009822  elapsed: 80
# val acc has not improved
# Epoch 73/100  train_loss: 0.35778  valid_loss 0.46497  valid_acc: 0.83091  lr: 0.009843  elapsed: 80
# val acc has not improved
# Epoch 74/100  train_loss: 0.37621  valid_loss 0.63786  valid_acc: 0.78309  lr: 0.009831  elapsed: 81
# val acc has not improved
# Epoch 75/100  train_loss: 0.32911  valid_loss 0.50829  valid_acc: 0.83604  lr: 0.009849  elapsed: 80
# val acc has not improved
# Epoch 76/100  train_loss: 0.36403  valid_loss 0.39856  valid_acc: 0.84970  lr: 0.009829  elapsed: 80
# val acc has not improved
# Epoch 77/100  train_loss: 0.35838  valid_loss 0.57585  valid_acc: 0.81298  lr: 0.009823  elapsed: 80
# val acc has not improved
# Epoch 78/100  train_loss: 0.36212  valid_loss 0.41297  valid_acc: 0.85482  lr: 0.009838  elapsed: 80
# val acc has not improved
# Epoch 79/100  train_loss: 0.34508  valid_loss 0.49949  valid_acc: 0.83091  lr: 0.009821  elapsed: 81
# val acc has not improved
# Epoch 80/100  train_loss: 0.36657  valid_loss 0.37285  valid_acc: 0.87020  lr: 0.009831  elapsed: 81
# val acc has not improved
# Epoch 81/100  train_loss: 0.36453  valid_loss 0.50712  valid_acc: 0.82664  lr: 0.009814  elapsed: 80
# val acc has not improved
# Epoch 82/100  train_loss: 0.35412  valid_loss 0.41421  valid_acc: 0.86080  lr: 0.009832  elapsed: 80
# val acc has not improved
# Epoch 83/100  train_loss: 0.35944  valid_loss 0.51960  valid_acc: 0.82152  lr: 0.009818  elapsed: 80
# val acc has not improved
# Epoch 84/100  train_loss: 0.35280  valid_loss 0.38809  valid_acc: 0.86166  lr: 0.009834  elapsed: 80
# val acc has not improved
# Epoch 85/100  train_loss: 0.34688  valid_loss 0.39700  valid_acc: 0.86336  lr: 0.009818  elapsed: 80
# val acc has not improved
# Epoch 86/100  train_loss: 0.34302  valid_loss 0.46066  valid_acc: 0.83604  lr: 0.009817  elapsed: 80
# val acc has not improved
# Epoch 87/100  train_loss: 0.35751  valid_loss 0.39122  valid_acc: 0.86507  lr: 0.009829  elapsed: 80
# val acc has not improved
# Epoch 88/100  train_loss: 0.35475  valid_loss 0.40900  valid_acc: 0.85568  lr: 0.009817  elapsed: 80
# val acc has not improved
# Epoch 89/100  train_loss: 0.34320  valid_loss 0.46839  valid_acc: 0.83177  lr: 0.009820  elapsed: 80
# val acc has not improved
# Epoch 90/100  train_loss: 0.33667  valid_loss 0.46619  valid_acc: 0.84714  lr: 0.009830  elapsed: 80
# val acc has not improved
# Epoch 91/100  train_loss: 0.34805  valid_loss 0.47929  valid_acc: 0.82152  lr: 0.009824  elapsed: 81
# val acc has not improved
# Epoch 92/100  train_loss: 0.34892  valid_loss 0.62332  valid_acc: 0.78138  lr: 0.009834  elapsed: 80
# val acc has not improved
# Epoch 93/100  train_loss: 0.35783  valid_loss 0.67275  valid_acc: 0.76943  lr: 0.009850  elapsed: 80
# val acc has not improved
# Epoch 94/100  train_loss: 0.35710  valid_loss 0.50050  valid_acc: 0.82750  lr: 0.009855  elapsed: 80
# val acc has not improved
# Epoch 95/100  train_loss: 0.35330  valid_loss 0.50258  valid_acc: 0.81725  lr: 0.009832  elapsed: 80
# val acc has not improved
# Epoch 96/100  train_loss: 0.33663  valid_loss 0.47321  valid_acc: 0.84458  lr: 0.009836  elapsed: 80
# val acc has not improved
# Epoch 97/100  train_loss: 0.33995  valid_loss 0.62769  valid_acc: 0.77370  lr: 0.009825  elapsed: 80
# val acc has not improved
# Epoch 98/100  train_loss: 0.34556  valid_loss 0.39438  valid_acc: 0.85568  lr: 0.009853  elapsed: 80
# val acc has not improved
# Epoch 99/100  train_loss: 0.35410  valid_loss 0.48781  valid_acc: 0.83945  lr: 0.009820  elapsed: 80
# val acc has not improved
# Epoch 100/100  train_loss: 0.36523  valid_loss 0.57390  valid_acc: 0.80359  lr: 0.009827  elapsed: 80
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8736122971818958 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 1_th FOLD =================================
# predict values check :  [ 4.61536407 -0.14132948  0.13475642 -0.27490193 -2.73077941 -1.59539652]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 2_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 28353078
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7204.02it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43894107600341586
# Epoch 1/100  train_loss: 1.54793  valid_loss 1.53124  valid_acc: 0.43894  lr: 0.010000  elapsed: 72
# val acc has not improved
# Epoch 2/100  train_loss: 1.51464  valid_loss 1.43960  valid_acc: 0.43894  lr: 0.009953  elapsed: 80
# val acc has not improved
# Epoch 3/100  train_loss: 1.44642  valid_loss 1.43099  valid_acc: 0.43894  lr: 0.009953  elapsed: 80
# val acc has not improved
# Epoch 4/100  train_loss: 1.35669  valid_loss 1.43396  valid_acc: 0.43894  lr: 0.009953  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.4893253629376601
# Epoch 5/100  train_loss: 1.13305  valid_loss 1.20737  valid_acc: 0.48933  lr: 0.009953  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.5542271562766866
# Epoch 6/100  train_loss: 0.92528  valid_loss 1.19464  valid_acc: 0.55423  lr: 0.009941  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.6319385140905209
# Epoch 7/100  train_loss: 0.79488  valid_loss 1.15836  valid_acc: 0.63194  lr: 0.009924  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.7053800170794193
# Epoch 8/100  train_loss: 0.73385  valid_loss 0.82962  valid_acc: 0.70538  lr: 0.009902  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.7463706233988044
# Epoch 9/100  train_loss: 0.63548  valid_loss 0.72742  valid_acc: 0.74637  lr: 0.009878  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7762596071733561
# Epoch 10/100  train_loss: 0.58315  valid_loss 0.67919  valid_acc: 0.77626  lr: 0.009863  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 11, Accuracy : 0.8035866780529461
# Epoch 11/100  train_loss: 0.57489  valid_loss 0.61337  valid_acc: 0.80359  lr: 0.009852  elapsed: 80
# val acc has not improved
# Epoch 12/100  train_loss: 0.51191  valid_loss 0.69956  valid_acc: 0.77455  lr: 0.009842  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.8368915456874466
# Epoch 13/100  train_loss: 0.50027  valid_loss 0.58126  valid_acc: 0.83689  lr: 0.009853  elapsed: 80
# val acc has not improved
# Epoch 14/100  train_loss: 0.48090  valid_loss 0.63301  valid_acc: 0.78565  lr: 0.009828  elapsed: 80
# val acc has not improved
# Epoch 15/100  train_loss: 0.46241  valid_loss 0.81373  valid_acc: 0.69001  lr: 0.009848  elapsed: 80
# val acc has not improved
# Epoch 16/100  train_loss: 0.46735  valid_loss 0.56316  valid_acc: 0.77968  lr: 0.009883  elapsed: 80
# val acc has not improved
# Epoch 17/100  train_loss: 0.44361  valid_loss 0.52191  valid_acc: 0.81213  lr: 0.009851  elapsed: 81
# val acc has not improved
# Epoch 18/100  train_loss: 0.46277  valid_loss 0.61466  valid_acc: 0.78651  lr: 0.009838  elapsed: 80
# val acc has not improved
# Epoch 19/100  train_loss: 0.44679  valid_loss 0.63876  valid_acc: 0.81383  lr: 0.009848  elapsed: 80
# val acc has not improved
# Epoch 20/100  train_loss: 0.42815  valid_loss 0.74550  valid_acc: 0.75149  lr: 0.009837  elapsed: 80
# val acc has not improved
# Epoch 21/100  train_loss: 0.43148  valid_loss 0.52678  valid_acc: 0.80444  lr: 0.009861  elapsed: 80
# val acc has not improved
# Epoch 22/100  train_loss: 0.43067  valid_loss 0.67148  valid_acc: 0.75491  lr: 0.009841  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 23, Accuracy : 0.8488471391972673
# Epoch 23/100  train_loss: 0.42907  valid_loss 0.46133  valid_acc: 0.84885  lr: 0.009860  elapsed: 80
# val acc has not improved
# Epoch 24/100  train_loss: 0.42973  valid_loss 0.79744  valid_acc: 0.73271  lr: 0.009823  elapsed: 80
# val acc has not improved
# Epoch 25/100  train_loss: 0.42586  valid_loss 0.67151  valid_acc: 0.78138  lr: 0.009868  elapsed: 80
# val acc has not improved
# Epoch 26/100  train_loss: 0.43196  valid_loss 0.56447  valid_acc: 0.82835  lr: 0.009850  elapsed: 80
# val acc has not improved
# Epoch 27/100  train_loss: 0.40334  valid_loss 0.62290  valid_acc: 0.77284  lr: 0.009832  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 28, Accuracy : 0.8531169940222032
# Epoch 28/100  train_loss: 0.41307  valid_loss 0.44113  valid_acc: 0.85312  lr: 0.009853  elapsed: 81
# val acc has not improved
# Epoch 29/100  train_loss: 0.39948  valid_loss 0.62284  valid_acc: 0.82237  lr: 0.009822  elapsed: 80
# val acc has not improved
# Epoch 30/100  train_loss: 0.40186  valid_loss 0.48873  valid_acc: 0.84372  lr: 0.009834  elapsed: 80
# val acc has not improved
# Epoch 31/100  train_loss: 0.40666  valid_loss 0.61634  valid_acc: 0.76260  lr: 0.009825  elapsed: 80
# val acc has not improved
# Epoch 32/100  train_loss: 0.41774  valid_loss 0.59528  valid_acc: 0.78736  lr: 0.009857  elapsed: 80
# val acc has not improved
# Epoch 33/100  train_loss: 0.41830  valid_loss 0.60738  valid_acc: 0.76601  lr: 0.009848  elapsed: 81
# val acc has not improved
# Epoch 34/100  train_loss: 0.39627  valid_loss 0.47303  valid_acc: 0.83860  lr: 0.009856  elapsed: 80
# val acc has not improved
# Epoch 35/100  train_loss: 0.40136  valid_loss 0.41924  valid_acc: 0.84031  lr: 0.009827  elapsed: 80
# val acc has not improved
# Epoch 36/100  train_loss: 0.39862  valid_loss 0.42627  valid_acc: 0.83348  lr: 0.009827  elapsed: 80
# val acc has not improved
# Epoch 37/100  train_loss: 0.39788  valid_loss 0.44444  valid_acc: 0.84799  lr: 0.009830  elapsed: 80
# val acc has not improved
# Epoch 38/100  train_loss: 0.39210  valid_loss 0.39956  valid_acc: 0.84543  lr: 0.009824  elapsed: 81
# val acc has not improved
# Epoch 39/100  train_loss: 0.39880  valid_loss 0.44404  valid_acc: 0.83689  lr: 0.009825  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 40, Accuracy : 0.8633646456020495
# Epoch 40/100  train_loss: 0.39158  valid_loss 0.37330  valid_acc: 0.86336  lr: 0.009828  elapsed: 80
# val acc has not improved
# Epoch 41/100  train_loss: 0.39531  valid_loss 0.47833  valid_acc: 0.83689  lr: 0.009817  elapsed: 80
# val acc has not improved
# Epoch 42/100  train_loss: 0.39698  valid_loss 0.56496  valid_acc: 0.78138  lr: 0.009828  elapsed: 80
# val acc has not improved
# Epoch 43/100  train_loss: 0.40334  valid_loss 0.36253  valid_acc: 0.86166  lr: 0.009850  elapsed: 80
# val acc has not improved
# Epoch 44/100  train_loss: 0.40189  valid_loss 0.40155  valid_acc: 0.86080  lr: 0.009818  elapsed: 80
# val acc has not improved
# Epoch 45/100  train_loss: 0.37795  valid_loss 0.66540  valid_acc: 0.76516  lr: 0.009818  elapsed: 80
# val acc has not improved
# Epoch 46/100  train_loss: 0.39358  valid_loss 0.37691  valid_acc: 0.85824  lr: 0.009856  elapsed: 80
# val acc has not improved
# Epoch 47/100  train_loss: 0.37855  valid_loss 0.55545  valid_acc: 0.78565  lr: 0.009819  elapsed: 86
# val acc has not improved
# Epoch 48/100  train_loss: 0.39669  valid_loss 0.40975  valid_acc: 0.84287  lr: 0.009848  elapsed: 87
# val acc has not improved
# Epoch 49/100  train_loss: 0.38198  valid_loss 0.35364  valid_acc: 0.86251  lr: 0.009826  elapsed: 87
# val acc has not improved
# Epoch 50/100  train_loss: 0.37491  valid_loss 0.63965  valid_acc: 0.77455  lr: 0.009818  elapsed: 88
# val acc has not improved
# Epoch 51/100  train_loss: 0.39007  valid_loss 0.58859  valid_acc: 0.76260  lr: 0.009853  elapsed: 88
# val acc has not improved
# Epoch 52/100  train_loss: 0.37301  valid_loss 0.47672  valid_acc: 0.82494  lr: 0.009857  elapsed: 88
# val acc has not improved
# Epoch 53/100  train_loss: 0.38478  valid_loss 0.58441  valid_acc: 0.76857  lr: 0.009833  elapsed: 87
# val acc has not improved
# Epoch 54/100  train_loss: 0.36310  valid_loss 0.43357  valid_acc: 0.83433  lr: 0.009855  elapsed: 88
# val acc has not improved
# Epoch 55/100  train_loss: 0.37492  valid_loss 0.38846  valid_acc: 0.85995  lr: 0.009829  elapsed: 87
# val acc has not improved
# Epoch 56/100  train_loss: 0.37442  valid_loss 0.52858  valid_acc: 0.80786  lr: 0.009819  elapsed: 88
# val acc has not improved
# Epoch 57/100  train_loss: 0.37670  valid_loss 0.42151  valid_acc: 0.84287  lr: 0.009840  elapsed: 87
# val acc has not improved
# Epoch 58/100  train_loss: 0.36112  valid_loss 0.41358  valid_acc: 0.83945  lr: 0.009826  elapsed: 87
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 59, Accuracy : 0.8795900939368061
# Epoch 59/100  train_loss: 0.36395  valid_loss 0.34215  valid_acc: 0.87959  lr: 0.009827  elapsed: 87
# val acc has not improved
# Epoch 60/100  train_loss: 0.37227  valid_loss 0.47104  valid_acc: 0.82323  lr: 0.009810  elapsed: 88
# val acc has not improved
# Epoch 61/100  train_loss: 0.37823  valid_loss 0.45173  valid_acc: 0.83604  lr: 0.009834  elapsed: 87
# val acc has not improved
# Epoch 62/100  train_loss: 0.36022  valid_loss 0.39522  valid_acc: 0.85824  lr: 0.009829  elapsed: 87
# val acc has not improved
# Epoch 63/100  train_loss: 0.36562  valid_loss 0.49531  valid_acc: 0.83860  lr: 0.009819  elapsed: 89
# val acc has not improved
# Epoch 64/100  train_loss: 0.36828  valid_loss 0.40065  valid_acc: 0.85226  lr: 0.009827  elapsed: 89
# val acc has not improved
# Epoch 65/100  train_loss: 0.36725  valid_loss 0.31123  valid_acc: 0.87532  lr: 0.009822  elapsed: 88
# val acc has not improved
# Epoch 66/100  train_loss: 0.38998  valid_loss 0.43838  valid_acc: 0.84714  lr: 0.009812  elapsed: 88
# val acc has not improved
# Epoch 67/100  train_loss: 0.38106  valid_loss 0.35741  valid_acc: 0.87020  lr: 0.009824  elapsed: 88
# val acc has not improved
# Epoch 68/100  train_loss: 0.35450  valid_loss 0.61365  valid_acc: 0.77370  lr: 0.009814  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 69, Accuracy : 0.8906917164816396
# Epoch 69/100  train_loss: 0.38097  valid_loss 0.32919  valid_acc: 0.89069  lr: 0.009853  elapsed: 87
# val acc has not improved
# Epoch 70/100  train_loss: 0.36483  valid_loss 0.38080  valid_acc: 0.86336  lr: 0.009806  elapsed: 87
# val acc has not improved
# Epoch 71/100  train_loss: 0.36247  valid_loss 0.36578  valid_acc: 0.87105  lr: 0.009817  elapsed: 87
# val acc has not improved
# Epoch 72/100  train_loss: 0.36385  valid_loss 0.33670  valid_acc: 0.87874  lr: 0.009814  elapsed: 87
# val acc has not improved
# Epoch 73/100  train_loss: 0.36244  valid_loss 0.38344  valid_acc: 0.85653  lr: 0.009811  elapsed: 88
# val acc has not improved
# Epoch 74/100  train_loss: 0.36670  valid_loss 0.36769  valid_acc: 0.86934  lr: 0.009820  elapsed: 88
# val acc has not improved
# Epoch 75/100  train_loss: 0.35592  valid_loss 0.36011  valid_acc: 0.85824  lr: 0.009815  elapsed: 88
# val acc has not improved
# Epoch 76/100  train_loss: 0.35879  valid_loss 0.42679  valid_acc: 0.84458  lr: 0.009819  elapsed: 87
# val acc has not improved
# Epoch 77/100  train_loss: 0.36674  valid_loss 0.40152  valid_acc: 0.84372  lr: 0.009825  elapsed: 87
# val acc has not improved
# Epoch 78/100  train_loss: 0.35325  valid_loss 0.32153  valid_acc: 0.87190  lr: 0.009825  elapsed: 89
# val acc has not improved
# Epoch 79/100  train_loss: 0.34965  valid_loss 0.38196  valid_acc: 0.87447  lr: 0.009814  elapsed: 83
# val acc has not improved
# Epoch 80/100  train_loss: 0.35927  valid_loss 0.34322  valid_acc: 0.87703  lr: 0.009813  elapsed: 80
# val acc has not improved
# Epoch 81/100  train_loss: 0.36598  valid_loss 0.47651  valid_acc: 0.83945  lr: 0.009811  elapsed: 80
# val acc has not improved
# Epoch 82/100  train_loss: 0.36039  valid_loss 0.40228  valid_acc: 0.85653  lr: 0.009827  elapsed: 81
# val acc has not improved
# Epoch 83/100  train_loss: 0.35341  valid_loss 0.37616  valid_acc: 0.88130  lr: 0.009820  elapsed: 80
# val acc has not improved
# Epoch 84/100  train_loss: 0.34993  valid_loss 0.51864  valid_acc: 0.82067  lr: 0.009810  elapsed: 80
# val acc has not improved
# Epoch 85/100  train_loss: 0.36016  valid_loss 0.38046  valid_acc: 0.86934  lr: 0.009835  elapsed: 80
# val acc has not improved
# Epoch 86/100  train_loss: 0.36228  valid_loss 0.51568  valid_acc: 0.81383  lr: 0.009815  elapsed: 80
# val acc has not improved
# Epoch 87/100  train_loss: 0.36387  valid_loss 0.78139  valid_acc: 0.71648  lr: 0.009837  elapsed: 81
# val acc has not improved
# Epoch 88/100  train_loss: 0.35948  valid_loss 0.39116  valid_acc: 0.85397  lr: 0.009874  elapsed: 83
# val acc has not improved
# Epoch 89/100  train_loss: 0.34662  valid_loss 0.59799  valid_acc: 0.78309  lr: 0.009821  elapsed: 81
# val acc has not improved
# Epoch 90/100  train_loss: 0.35471  valid_loss 0.35421  valid_acc: 0.87276  lr: 0.009849  elapsed: 81
# val acc has not improved
# Epoch 91/100  train_loss: 0.35384  valid_loss 0.39368  valid_acc: 0.86080  lr: 0.009813  elapsed: 81
# val acc has not improved
# Epoch 92/100  train_loss: 0.36646  valid_loss 0.40973  valid_acc: 0.84970  lr: 0.009818  elapsed: 81
# val acc has not improved
# Epoch 93/100  train_loss: 0.35523  valid_loss 0.31909  valid_acc: 0.88471  lr: 0.009823  elapsed: 80
# val acc has not improved
# Epoch 94/100  train_loss: 0.34897  valid_loss 0.51789  valid_acc: 0.79932  lr: 0.009808  elapsed: 80
# val acc has not improved
# Epoch 95/100  train_loss: 0.34082  valid_loss 0.53470  valid_acc: 0.84372  lr: 0.009843  elapsed: 80
# val acc has not improved
# Epoch 96/100  train_loss: 0.36117  valid_loss 0.49565  valid_acc: 0.82664  lr: 0.009825  elapsed: 80
# val acc has not improved
# Epoch 97/100  train_loss: 0.35797  valid_loss 0.33605  valid_acc: 0.87276  lr: 0.009832  elapsed: 80
# val acc has not improved
# Epoch 98/100  train_loss: 0.33817  valid_loss 0.42003  valid_acc: 0.85482  lr: 0.009813  elapsed: 80
# val acc has not improved
# Epoch 99/100  train_loss: 0.35707  valid_loss 0.30591  valid_acc: 0.88557  lr: 0.009821  elapsed: 80
# val acc has not improved
# Epoch 100/100  train_loss: 0.34682  valid_loss 0.51659  valid_acc: 0.80017  lr: 0.009808  elapsed: 80
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8906917164816396 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 2_th FOLD =================================
# predict values check :  [ 4.2198143  -0.65279162  0.89311957 -0.2188946  -3.28047824 -0.96104991]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 2_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 3_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 28353078
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7518.86it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4680
# number of valid images: 1170
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43846153846153846
# Epoch 1/100  train_loss: 1.56420  valid_loss 1.50451  valid_acc: 0.43846  lr: 0.010000  elapsed: 71
# val acc has not improved
# Epoch 2/100  train_loss: 1.49738  valid_loss 1.44918  valid_acc: 0.43846  lr: 0.009953  elapsed: 80
# val acc has not improved
# Epoch 3/100  train_loss: 1.44375  valid_loss 1.43865  valid_acc: 0.43846  lr: 0.009953  elapsed: 80
# val acc has not improved
# Epoch 4/100  train_loss: 1.34941  valid_loss 1.42893  valid_acc: 0.43846  lr: 0.009953  elapsed: 80
# val acc has not improved
# Epoch 5/100  train_loss: 1.21772  valid_loss 1.39583  valid_acc: 0.43846  lr: 0.009953  elapsed: 80
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.6222222222222222
# Epoch 6/100  train_loss: 0.99326  valid_loss 1.03203  valid_acc: 0.62222  lr: 0.009953  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.7230769230769231
# Epoch 7/100  train_loss: 0.81927  valid_loss 0.79807  valid_acc: 0.72308  lr: 0.009905  elapsed: 81
# val acc has not improved
# Epoch 8/100  train_loss: 0.70585  valid_loss 0.93856  valid_acc: 0.64957  lr: 0.009872  elapsed: 82
# val acc has not improved
# Epoch 9/100  train_loss: 0.65696  valid_loss 0.87485  valid_acc: 0.60684  lr: 0.009896  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7982905982905983
# Epoch 10/100  train_loss: 0.58553  valid_loss 0.56446  valid_acc: 0.79829  lr: 0.009909  elapsed: 81
# val acc has not improved
# Epoch 11/100  train_loss: 0.54379  valid_loss 0.62243  valid_acc: 0.78120  lr: 0.009844  elapsed: 81
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.8213675213675213
# Epoch 12/100  train_loss: 0.51961  valid_loss 0.53535  valid_acc: 0.82137  lr: 0.009850  elapsed: 80
# val acc has not improved
# ...
# val acc has not improved
# Epoch 99/100  train_loss: 0.36249  valid_loss 0.36345  valid_acc: 0.86667  lr: 0.009818  elapsed: 92
# val acc has not improved
# Epoch 100/100  train_loss: 0.34810  valid_loss 0.39343  valid_acc: 0.86496  lr: 0.009816  elapsed: 92
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8965811965811966 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 3_th FOLD =================================
# predict values check :  [ 6.07417202 -0.07198411 -0.25511163  0.97926736 -3.91047859 -2.83270788]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 3_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 4_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 28353078
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 6723.76it/s]
# ==== fold_df created
#         filename  label  fold
# 0  face_3267.png      0     1
# 1   face_587.png      3     0
# 2  face_6585.png      3     1
# 3  face_3094.png      3     2
# 4  face_1170.png      3     3
# number of train images: 4683
# number of valid images: 1167
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 0
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43958868894601544
# Epoch 1/100  train_loss: 1.52612  valid_loss 1.51129  valid_acc: 0.43959  lr: 0.010000  elapsed: 82
# val acc has not improved
# Epoch 2/100  train_loss: 1.49163  valid_loss 1.43880  valid_acc: 0.43959  lr: 0.009952  elapsed: 92
# val acc has not improved
# Epoch 3/100  train_loss: 1.42737  valid_loss 1.42927  valid_acc: 0.43959  lr: 0.009952  elapsed: 91
# val acc has not improved
# Epoch 4/100  train_loss: 1.33063  valid_loss 1.43571  valid_acc: 0.43959  lr: 0.009952  elapsed: 92
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5801199657240789
# Epoch 5/100  train_loss: 1.10138  valid_loss 1.36276  valid_acc: 0.58012  lr: 0.009952  elapsed: 92
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.6795201371036846
# Epoch 6/100  train_loss: 0.82533  valid_loss 0.88534  valid_acc: 0.67952  lr: 0.009917  elapsed: 91
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.702656383890317
# Epoch 7/100  train_loss: 0.73814  valid_loss 0.74303  valid_acc: 0.70266  lr: 0.009887  elapsed: 91
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.7549271636675235
# Epoch 8/100  train_loss: 0.62060  valid_loss 0.68384  valid_acc: 0.75493  lr: 0.009879  elapsed: 91
# val acc has not improved
# Epoch 9/100  train_loss: 0.57521  valid_loss 0.67674  valid_acc: 0.74807  lr: 0.009860  elapsed: 91
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.7686375321336761
# Epoch 10/100  train_loss: 0.53073  valid_loss 0.61317  valid_acc: 0.76864  lr: 0.009863  elapsed: 91
# val acc has not improved
# Epoch 11/100  train_loss: 0.50609  valid_loss 0.73045  valid_acc: 0.73865  lr: 0.009855  elapsed: 91
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.8226221079691517
# Epoch 12/100  train_loss: 0.49686  valid_loss 0.54273  valid_acc: 0.82262  lr: 0.009866  elapsed: 91
# val acc has not improved
# Epoch 13/100  train_loss: 0.47845  valid_loss 0.66190  valid_acc: 0.72751  lr: 0.009834  elapsed: 91
# val acc has not improved
# Epoch 14/100  train_loss: 0.45338  valid_loss 0.59193  valid_acc: 0.78492  lr: 0.009870  elapsed: 92
# val acc has not improved
# Epoch 15/100  train_loss: 0.45347  valid_loss 0.61134  valid_acc: 0.77892  lr: 0.009849  elapsed: 92
# val acc has not improved
# Epoch 16/100  train_loss: 0.44537  valid_loss 0.60711  valid_acc: 0.78320  lr: 0.009851  elapsed: 91
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.8269065981148244
# Epoch 17/100  train_loss: 0.42941  valid_loss 0.50534  valid_acc: 0.82691  lr: 0.009849  elapsed: 91
# val acc has not improved
# Epoch 18/100  train_loss: 0.41999  valid_loss 0.51040  valid_acc: 0.81234  lr: 0.009832  elapsed: 92
# val acc has not improved
# Epoch 19/100  train_loss: 0.41495  valid_loss 0.57001  valid_acc: 0.81662  lr: 0.009838  elapsed: 91
# val acc has not improved
# Epoch 20/100  train_loss: 0.42930  valid_loss 0.64594  valid_acc: 0.75750  lr: 0.009836  elapsed: 92
# val acc has not improved
# Epoch 21/100  train_loss: 0.42035  valid_loss 0.53045  valid_acc: 0.82177  lr: 0.009859  elapsed: 92
# val acc has not improved
# Epoch 22/100  train_loss: 0.41280  valid_loss 0.51177  valid_acc: 0.81320  lr: 0.009834  elapsed: 92
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 23, Accuracy : 0.8526135389888603
# Epoch 23/100  train_loss: 0.40598  valid_loss 0.51233  valid_acc: 0.85261  lr: 0.009838  elapsed: 91
# val acc has not improved
# Epoch 24/100  train_loss: 0.40645  valid_loss 0.55628  valid_acc: 0.80720  lr: 0.009822  elapsed: 91
# val acc has not improved
# Epoch 25/100  train_loss: 0.40553  valid_loss 0.55297  valid_acc: 0.79606  lr: 0.009840  elapsed: 91
# val acc has not improved
# Epoch 26/100  train_loss: 0.38237  valid_loss 0.67700  valid_acc: 0.72408  lr: 0.009844  elapsed: 91
# val acc has not improved
# Epoch 27/100  train_loss: 0.40052  valid_loss 0.49524  valid_acc: 0.82862  lr: 0.009871  elapsed: 91
# val acc has not improved
# Epoch 28/100  train_loss: 0.40216  valid_loss 0.62571  valid_acc: 0.79606  lr: 0.009832  elapsed: 92
# val acc has not improved
# Epoch 29/100  train_loss: 0.37873  valid_loss 0.48168  valid_acc: 0.85261  lr: 0.009844  elapsed: 85
# val acc has not improved
# Epoch 30/100  train_loss: 0.38083  valid_loss 0.64707  valid_acc: 0.76264  lr: 0.009822  elapsed: 81
# val acc has not improved
# Epoch 31/100  train_loss: 0.38130  valid_loss 0.47166  valid_acc: 0.82348  lr: 0.009857  elapsed: 81
# val acc has not improved
# Epoch 32/100  train_loss: 0.39122  valid_loss 0.41879  valid_acc: 0.85004  lr: 0.009834  elapsed: 82
# val acc has not improved
# Epoch 33/100  train_loss: 0.37935  valid_loss 0.46590  valid_acc: 0.84319  lr: 0.009823  elapsed: 84
# val acc has not improved
# Epoch 34/100  train_loss: 0.37337  valid_loss 0.58331  valid_acc: 0.75407  lr: 0.009826  elapsed: 85
# val acc has not improved
# Epoch 35/100  train_loss: 0.38344  valid_loss 0.43278  valid_acc: 0.84404  lr: 0.009860  elapsed: 83
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 36, Accuracy : 0.8543273350471294
# Epoch 36/100  train_loss: 0.37523  valid_loss 0.45310  valid_acc: 0.85433  lr: 0.009825  elapsed: 82
# val acc has not improved
# Epoch 37/100  train_loss: 0.37081  valid_loss 0.43491  valid_acc: 0.85004  lr: 0.009821  elapsed: 82
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 38, Accuracy : 0.8860325621251071
# Epoch 38/100  train_loss: 0.35958  valid_loss 0.34349  valid_acc: 0.88603  lr: 0.009823  elapsed: 82
# val acc has not improved
# Epoch 39/100  train_loss: 0.37227  valid_loss 0.50992  valid_acc: 0.81148  lr: 0.009808  elapsed: 82
# val acc has not improved
# Epoch 40/100  train_loss: 0.36995  valid_loss 0.40032  valid_acc: 0.86204  lr: 0.009838  elapsed: 82
# val acc has not improved
# Epoch 41/100  train_loss: 0.37782  valid_loss 0.45840  valid_acc: 0.82519  lr: 0.009818  elapsed: 82
# val acc has not improved
# Epoch 42/100  train_loss: 0.36518  valid_loss 0.45850  valid_acc: 0.83890  lr: 0.009833  elapsed: 82
# val acc has not improved
# Epoch 43/100  train_loss: 0.37709  valid_loss 0.45577  valid_acc: 0.85433  lr: 0.009827  elapsed: 82
# val acc has not improved
# Epoch 44/100  train_loss: 0.36558  valid_loss 0.40034  valid_acc: 0.86889  lr: 0.009821  elapsed: 88
# val acc has not improved
# Epoch 45/100  train_loss: 0.35973  valid_loss 0.39259  valid_acc: 0.85604  lr: 0.009815  elapsed: 91
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 46, Accuracy : 0.8877463581833762
# Epoch 46/100  train_loss: 0.36699  valid_loss 0.34179  valid_acc: 0.88775  lr: 0.009820  elapsed: 89
# val acc has not improved
# Epoch 47/100  train_loss: 0.36188  valid_loss 0.33509  valid_acc: 0.88775  lr: 0.009807  elapsed: 88
# val acc has not improved
# Epoch 48/100  train_loss: 0.36252  valid_loss 0.38146  valid_acc: 0.85518  lr: 0.009807  elapsed: 88
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 49, Accuracy : 0.8903170522707797
# Epoch 49/100  train_loss: 0.37508  valid_loss 0.32965  valid_acc: 0.89032  lr: 0.009821  elapsed: 88
# val acc has not improved
# Epoch 50/100  train_loss: 0.37582  valid_loss 0.48711  valid_acc: 0.83890  lr: 0.009806  elapsed: 88
# val acc has not improved
# Epoch 51/100  train_loss: 0.37092  valid_loss 0.47245  valid_acc: 0.83462  lr: 0.009827  elapsed: 88
# val acc has not improved
# Epoch 52/100  train_loss: 0.35257  valid_loss 0.37758  valid_acc: 0.86889  lr: 0.009829  elapsed: 88
# val acc has not improved
# Epoch 53/100  train_loss: 0.36872  valid_loss 0.49106  valid_acc: 0.84490  lr: 0.009815  elapsed: 89
# val acc has not improved
# Epoch 54/100  train_loss: 0.35898  valid_loss 0.34059  valid_acc: 0.88175  lr: 0.009825  elapsed: 89
# val acc has not improved
# Epoch 55/100  train_loss: 0.35486  valid_loss 0.50084  valid_acc: 0.82605  lr: 0.009809  elapsed: 89
# val acc has not improved
# Epoch 56/100  train_loss: 0.37090  valid_loss 0.38426  valid_acc: 0.86290  lr: 0.009833  elapsed: 89
# val acc has not improved
# Epoch 57/100  train_loss: 0.35961  valid_loss 0.40849  valid_acc: 0.86889  lr: 0.009817  elapsed: 89
# val acc has not improved
# Epoch 58/100  train_loss: 0.36267  valid_loss 0.36754  valid_acc: 0.87489  lr: 0.009815  elapsed: 89
# val acc has not improved
# Epoch 59/100  train_loss: 0.35190  valid_loss 0.37252  valid_acc: 0.86804  lr: 0.009812  elapsed: 89
# val acc has not improved
# Epoch 60/100  train_loss: 0.35976  valid_loss 0.35079  valid_acc: 0.87489  lr: 0.009815  elapsed: 89
# val acc has not improved
# Epoch 61/100  train_loss: 0.35575  valid_loss 0.42148  valid_acc: 0.85518  lr: 0.009812  elapsed: 89
# val acc has not improved
# Epoch 62/100  train_loss: 0.36001  valid_loss 0.38737  valid_acc: 0.87147  lr: 0.009821  elapsed: 89
# val acc has not improved
# Epoch 63/100  train_loss: 0.35900  valid_loss 0.44530  valid_acc: 0.85090  lr: 0.009814  elapsed: 90
# val acc has not improved
# Epoch 64/100  train_loss: 0.34243  valid_loss 0.44967  valid_acc: 0.84233  lr: 0.009822  elapsed: 89
# val acc has not improved
# Epoch 65/100  train_loss: 0.35073  valid_loss 0.39125  valid_acc: 0.85775  lr: 0.009826  elapsed: 89
# val acc has not improved
# Epoch 66/100  train_loss: 0.34955  valid_loss 0.43297  valid_acc: 0.84576  lr: 0.009820  elapsed: 89
# val acc has not improved
# Epoch 67/100  train_loss: 0.34587  valid_loss 0.38428  valid_acc: 0.86718  lr: 0.009825  elapsed: 89
# val acc has not improved
# Epoch 68/100  train_loss: 0.34965  valid_loss 0.35370  valid_acc: 0.87746  lr: 0.009816  elapsed: 89
# val acc has not improved
# Epoch 69/100  train_loss: 0.36314  valid_loss 0.39097  valid_acc: 0.87489  lr: 0.009811  elapsed: 89
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 70, Accuracy : 0.895458440445587
# Epoch 70/100  train_loss: 0.36560  valid_loss 0.30316  valid_acc: 0.89546  lr: 0.009812  elapsed: 89
# val acc has not improved
# Epoch 71/100  train_loss: 0.34818  valid_loss 0.38714  valid_acc: 0.86204  lr: 0.009803  elapsed: 90
# val acc has not improved
# Epoch 72/100  train_loss: 0.34160  valid_loss 0.41881  valid_acc: 0.85861  lr: 0.009818  elapsed: 90
# val acc has not improved
# Epoch 73/100  train_loss: 0.34909  valid_loss 0.35470  valid_acc: 0.88689  lr: 0.009819  elapsed: 89
# val acc has not improved
# Epoch 74/100  train_loss: 0.35336  valid_loss 0.38236  valid_acc: 0.86804  lr: 0.009807  elapsed: 90
# val acc has not improved
# Epoch 75/100  train_loss: 0.32503  valid_loss 0.36032  valid_acc: 0.87489  lr: 0.009815  elapsed: 90
# val acc has not improved
# Epoch 76/100  train_loss: 0.35429  valid_loss 0.39254  valid_acc: 0.86889  lr: 0.009812  elapsed: 90
# val acc has not improved
# Epoch 77/100  train_loss: 0.34654  valid_loss 0.35690  valid_acc: 0.86889  lr: 0.009815  elapsed: 90
# val acc has not improved
# Epoch 78/100  train_loss: 0.34818  valid_loss 0.43996  valid_acc: 0.85261  lr: 0.009815  elapsed: 90
# val acc has not improved
# Epoch 79/100  train_loss: 0.33953  valid_loss 0.34990  valid_acc: 0.88175  lr: 0.009822  elapsed: 89
# val acc has not improved
# Epoch 80/100  train_loss: 0.34501  valid_loss 0.40906  valid_acc: 0.85947  lr: 0.009809  elapsed: 89
# val acc has not improved
# Epoch 81/100  train_loss: 0.34307  valid_loss 0.33539  valid_acc: 0.87404  lr: 0.009819  elapsed: 89
# val acc has not improved
# Epoch 82/100  train_loss: 0.35228  valid_loss 0.53889  valid_acc: 0.83290  lr: 0.009813  elapsed: 89
# val acc has not improved
# Epoch 83/100  train_loss: 0.34151  valid_loss 0.58055  valid_acc: 0.80206  lr: 0.009830  elapsed: 89
# val acc has not improved
# Epoch 84/100  train_loss: 0.36170  valid_loss 0.29817  valid_acc: 0.89289  lr: 0.009842  elapsed: 89
# val acc has not improved
# Epoch 85/100  train_loss: 0.35605  valid_loss 0.42911  valid_acc: 0.85004  lr: 0.009805  elapsed: 89
# val acc has not improved
# Epoch 86/100  train_loss: 0.34569  valid_loss 0.38177  valid_acc: 0.86718  lr: 0.009823  elapsed: 89
# val acc has not improved
# Epoch 87/100  train_loss: 0.33522  valid_loss 0.37045  valid_acc: 0.87661  lr: 0.009816  elapsed: 89
# val acc has not improved
# Epoch 88/100  train_loss: 0.33789  valid_loss 0.38446  valid_acc: 0.85347  lr: 0.009812  elapsed: 89
# val acc has not improved
# Epoch 89/100  train_loss: 0.35659  valid_loss 0.56038  valid_acc: 0.80034  lr: 0.009821  elapsed: 89
# val acc has not improved
# Epoch 90/100  train_loss: 0.35152  valid_loss 0.36447  valid_acc: 0.87832  lr: 0.009843  elapsed: 89
# val acc has not improved
# Epoch 91/100  train_loss: 0.34019  valid_loss 0.36857  valid_acc: 0.87232  lr: 0.009811  elapsed: 89
# val acc has not improved
# Epoch 92/100  train_loss: 0.35162  valid_loss 0.52715  valid_acc: 0.81577  lr: 0.009813  elapsed: 89
# val acc has not improved
# Epoch 93/100  train_loss: 0.35999  valid_loss 0.46931  valid_acc: 0.83376  lr: 0.009837  elapsed: 90
# val acc has not improved
# Epoch 94/100  train_loss: 0.34280  valid_loss 0.33543  valid_acc: 0.88603  lr: 0.009829  elapsed: 89
# val acc has not improved
# Epoch 95/100  train_loss: 0.34324  valid_loss 0.57206  valid_acc: 0.79092  lr: 0.009808  elapsed: 89
# val acc has not improved
# Epoch 96/100  train_loss: 0.34761  valid_loss 0.59672  valid_acc: 0.78320  lr: 0.009846  elapsed: 89
# val acc has not improved
# Epoch 97/100  train_loss: 0.34723  valid_loss 0.37097  valid_acc: 0.87832  lr: 0.009849  elapsed: 89
# val acc has not improved
# Epoch 98/100  train_loss: 0.35400  valid_loss 0.49380  valid_acc: 0.82177  lr: 0.009811  elapsed: 89
# val acc has not improved
# Epoch 99/100  train_loss: 0.34928  valid_loss 0.33046  valid_acc: 0.88689  lr: 0.009834  elapsed: 89
# val acc has not improved
# Epoch 100/100  train_loss: 0.33477  valid_loss 0.38579  valid_acc: 0.86889  lr: 0.009807  elapsed: 89
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.895458440445587 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 4_th FOLD =================================
# predict values check :  [ 5.2552495   0.18557265 -0.42619357  0.25103959 -2.66955113 -2.60319161]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 4_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
