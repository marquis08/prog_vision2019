# %%
import gc
import os
import time
import numpy as np
import pandas as pd
from glob import glob
import tqdm
import argparse
import tqdm
from collections import defaultdict, Counter
from PIL import Image
import cv2

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch import nn, cuda
from torch.autograd import Variable 
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import CenterCrop

from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR
from utils import count_parameters, seed_everything, AdamW, CosineAnnealingWithRestartsLR

from efficientnet_pytorch import EfficientNet
import torchvision.models as models

from model import Baseline, Resnet18, Resnet50, Resnext50, Resnext101
from customs import mixup_data, mixup_criterion
from transforms import get_transform
from dataloader import make_loader, TestDataset

#num_fold = 0 #select fold number for training
for num_fold in range(5):
    
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 STARTS {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
    train_csv = pd.read_csv("../JOB_VISION/train.csv")

    def to_numpy(t):
        return t.cpu().detach().numpy()

    def make_folds(df, n_folds: int) -> pd.DataFrame:

        cls_counts = Counter([classes for classes in df['label']])
        fold_cls_counts = defaultdict()
        for class_index in cls_counts.keys():
            fold_cls_counts[class_index] = np.zeros(n_folds, dtype=np.int)

        df['fold'] = -1
        pbar = tqdm.tqdm(total=len(df))

        def get_fold(row):
            class_index = row['label']
            counts = fold_cls_counts[class_index]
            fold = np.argmin(counts)
            counts[fold] += 1
            fold_cls_counts[class_index] = counts
            row['fold']=fold
            pbar.update()
            return row

        df = df.apply(get_fold, axis=1)
        return df

    def make_label(label):
        if label == 'MA':
            return 1
        elif label == 'GMA':
            return 2
        elif label == 'BOY':
            return 3
        elif label == 'FA':
            return 4
        elif label == 'GFA':
            return 5
        #elif label == 'GIRL':
        else:
            return 6

    def make_csv(folder_path):
        folder_list = os.listdir(folder_path)
        print(folder_list)

        result_df = pd.DataFrame(columns=['path', 'label'])
        #print('current path: ', folder_path)
        #print('current file list', os.listdir(folder_path))
        for folder in folder_list:
            file_list = glob(folder_path + '/' + folder + '/*png')

            for file in file_list:
                # print('folder: ', folder)
                # print('file: ', file)
                result_df = result_df.append(pd.DataFrame([(file, folder)], columns=['path', 'label']), ignore_index=True)
        # print(result_df.head())

        result_df['label'] = result_df['label'].apply(lambda x: make_label(x))
        result_df['label'] = result_df['label']-1
        #print(result_df.head())
        return result_df

    SEED = 42
    seed_everything(SEED)

    device = 'cuda'
    use_gpu = cuda.is_available()

    if use_gpu:
        print("enable gpu use")
    else:
        print("enable cpu for debugging")


    target_size = (128, 128)

    num_classes = 6
    model = models.resnet50(pretrained=False) 
    model.fc = nn.Linear(2048, num_classes)

    #model = models.resnet50() 
    #model.fc = nn.Linear(2048, args.num_classes)

    # elif args.model == 'resnet18': 
    #     model = Resnet18(args.num_classes, dropout=False)
    # elif args.model == 'resnet50':
    #     model = Resnet50(args.num_classes, dropout=False)
    # elif args.model == 'efficient':
    #     model = EfficientNet.from_pretrained('efficientnet-b0')
    #     in_features = model._fc.in_features
    #     model._fc = nn.Linear(in_features, args.num_classes)
    # elif args.model == 'densenet201':
    #     model = models.densenet201(pretrained=True)
    #     model.classifier = nn.Linear(1920, args.num_classes)
    # elif args.model == 'resnext50':
    #     model = Resnext50(args.num_classes, dropout=False)
    # elif args.model == 'resnext101':
    #     model = Resnext101(args.num_classes, dropout=False)
    # elif args.model == 'mobilenet':
    #     assert args.input_size == 158
    #     model = torch.hub.load('pytorch/vision', 'mobilenet_v2', pretrained=True)
    #     model.classifier = nn.Sequential(nn.Dropout(0.2),
    #                         nn.Linear(1280, args.num_classes))
    # else:
    #     raise NotImplementedError

    if use_gpu:
        model = model.to(device)

    # optimizer = optim.Adam(model.parameters(), args.lr, weight_decay=0.00025)
    optimizer = AdamW(model.parameters(), 2.5e-4, weight_decay=0.000025)
    #optimizer = optim.SGD(model.parameters(), args.lr, momentum=0.9, weight_decay=0.025)

    ###### SCHEDULER #######
    scheduler = ReduceLROnPlateau(optimizer, 'max', patience=5, factor=0.5)

    #eta_min = 0.00001
    #T_max = 10
    #T_mult = 1
    #restart_decay = 0.97
    #scheduler = CosineAnnealingWithRestartsLR(optimizer, T_max=T_max, eta_min=eta_min, T_mult=T_mult, restart_decay=restart_decay)

    #scheduler = StepLR(optimizer, step_size=5, gamma=0.5)

    criterion = nn.CrossEntropyLoss() 

    num_parameters = count_parameters(model)
    print("==== number of parameters that can be trained: {}".format(num_parameters))

    folder_path = 'C:/SEOYILGUK/JOB_VISION/train/'
    IMAGE_PATH = folder_path + 'train_images/'
    df = make_csv(folder_path)
    print(df['label'].value_counts())

    # 5 stratifiedKFold
    folds = make_folds(df, 5)
    print("==== fold_df created")
    print(folds.head())

    train_df = folds[folds['fold'] != num_fold]
    valid_df = folds[folds['fold'] == num_fold]

    train_df = train_df[['path', 'label']].reset_index(drop=True)
    valid_df = valid_df[['path', 'label']].reset_index(drop=True)
    print("number of train images: {}".format(len(train_df)))
    print("number of valid images: {}".format(len(valid_df)))

    start_time = time.time()
    

    print("shape of the df: {}".format(df.shape))

    class Glass_Dataset(Dataset):
        def __init__(self, df, transform1=None, transform2=None):
            self.df = df
            self.transform1 = transform1
            self.transform2 = transform2

            self.image_list = []

            for path in self.df['path']:
                #print(path)
                image = cv2.imread(path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = Image.fromarray(image)
                image = self.transform1(image)
                self.image_list.append(image)

        def __len__(self):
            return len(self.df)

        def __getitem__(self, idx):

            # img_path = self.df.iloc[idx, 0]
            # print(img_path)
            # image = cv2.imread(img_path)
            # image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            # image = Image.fromarray(image)

            # if self.transform:
            #     image = self.transform(image)
            image = self.image_list[idx]

            if self.transform2:
                image = self.transform2(image)

            label = self.df['label'][idx]

            return image, label

    def make_loader(df, transforms1, transforms2, batch_size=256, num_workers=0):

        dataset = Glass_Dataset(df, transforms1, transforms2)
        # dataset = image, label from Glass_Dataset

        loader = DataLoader(dataset, # image, label
                            batch_size=batch_size,
                            shuffle=True, 
                            num_workers=num_workers, 
                            pin_memory=True)

        return loader

    train_augments = 'horizontal_flip, vertical_flip, Affine'
    augment_ratio = 0.5
    valid_augments = 'horizontal_flip, vertical_flip'
    transform1 = transforms.Compose([transforms.RandomRotation(180), transforms.ColorJitter()])
    #transforms2
    train_transforms = get_transform(target_size, 'horizontal_flip, vertical_flip, Affine', augment_ratio)
    valid_transforms = get_transform(target_size, 'horizontal_flip, vertical_flip', augment_ratio)


    train_loader = make_loader(train_df, transform1, train_transforms, batch_size=32 ,num_workers=0)
    valid_loader = make_loader(valid_df, transform1, valid_transforms, batch_size=32 ,num_workers=0)
    print("number train batches: {}".format(len(train_loader)))
    print("number valid batches: {}".format(len(valid_loader)))
    elapsed = time.time() - start_time
    print("elapsed: {:.0f}".format(elapsed))

    best_val_acc = 0
    grad_clip_step = 100
    grad_clip = 100
    step = 0
    # accumulation_step = 2

    print("start training")

    for epoch_idx in range(1, 200 + 1):

        start_time = time.time()

        train_loss = 0
        train_total_correct = 0
        model.train()
        optimizer.zero_grad()

        for batch_idx, (image, labels) in enumerate(train_loader):
            if use_gpu:
                image = image.to(device)
                labels = labels.to(device)

            # print("shape of the image: {}".format(image.shape))
            # print("shape of the labels: {}".format(labels.shape))
            # print(image)
            # print(labels)

            #if args.mixup_loss:
            #    inputs, targets_a, targets_b, lam = mixup_data(image, labels, alpha=0.4, device=device)
            #    inputs, targets_a, targets_b = map(Variable, (inputs, targets_a, targets_b))
            #    output = model(inputs)
            #    loss = mixup_criterion(criterion, output.to(device), targets_a.to(device), targets_b.to(device), lam)
            #else:
            output = model(image)
            loss = criterion(output, labels)

            # gradient explosion prevention
            if step > grad_clip_step:
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

            step += 1

            loss.backward()

            optimizer.step()
            optimizer.zero_grad()

            # output_prob = F.softmax(output, dim=1)

            train_loss += loss.item() / len(train_loader)


        model.eval()
        valid_loss = 0
        valid_total_correct = 0

        with torch.no_grad():
            for batch_idx, (image, labels) in enumerate(valid_loader):
                if use_gpu:
                    image = image.to(device)
                    labels = labels.to(device)


                output = model(image)
                loss = criterion(output, labels)

                output_prob = F.softmax(output, dim=1)

                predict_vector = np.argmax(to_numpy(output_prob), axis=1)
                label_vector = to_numpy(labels)
                bool_vector = predict_vector == label_vector
                #print('val_pred', predict_vector[:5])
                #print('val_label', label_vector[:5])
                #print("shape of prediction vector: {}".format(predict_vector.shape))
                #print(predict_vector.head())
                #print("shape of label vector: {}".format(label_vector.shape))

                valid_loss += loss.item() / len(valid_loader)
                valid_total_correct += bool_vector.sum()


        elapsed = time.time() - start_time

        val_acc = valid_total_correct / len(valid_loader.dataset)

        # best val_acc checkpoint
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            print("val_acc has improved !! ")
            torch.save(model.state_dict(), 'resnet50_fold_{}_best_model.pt'.format(num_fold))
            print("================ ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ".format(epoch_idx, best_val_acc))
            #file_save_name = 'best_acc' + '_' + str(num_fold)
            #print(file_save_name)
        else:
            print("val acc has not improved")

        lr = [_['lr'] for _ in optimizer.param_groups]

        #if args.scheduler == 'plateau':
        scheduler.step(val_acc)
        #else:
        #    scheduler.step()

        # nsml.save(epoch_idx)

        print("Epoch {}/{}  train_loss: {:.5f}  valid_loss {:.5f}  valid_acc: {:.5f}  lr: {:.6f}  elapsed: {:.0f}".format(
               epoch_idx, 200, train_loss, valid_loss, val_acc, lr[0], elapsed))
                #epoch_idx, args.epochs, train_loss, valid_loss, val_acc, lr[0], elapsed

    IMAGES_PATH = 'C:/SEOYILGUK/JOB_VISION/faces_images'
    test_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/test.csv')

    class TestDataset(Dataset):
        def __init__(self, df, transform=None):
            self.df = df
            self.transform = transform

        def __len__(self):
            return len(self.df)

        def __getitem__(self, idx):

            image = Image.open(IMAGES_PATH+'/'+self.df['filename'][idx]).convert('RGB')

            if self.transform:
                image = self.transform(image)

            return image

    batch_size = 1
    num_workers = 0

    # model = models.resnet18(pretrained=False) 
    # model.fc = nn.Linear(512, args.num_classes)

    # checkpoint = 'team012/KHD2019_FUNDUS/93'
    # nsml.load(checkpoint, load_fn=load)


    test_transforms = transforms.Compose([transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    test_dataset = TestDataset(test_df, test_transforms)
    test_loader = DataLoader(test_dataset,
                             batch_size=batch_size,
                             shuffle=False, 
                             num_workers=num_workers, 
                             pin_memory=True)
    
    print("============== ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ====================================".format(epoch_idx, best_val_acc))
    print("========================== ༼ つ ◕_◕ ༽つ Model Load {}_th FOLD =================================".format(num_fold))
    model.load_state_dict(torch.load('resnet50_fold_{}_best_model.pt'.format(num_fold)))

    model.eval()
    # for _ in range(tta):
        # print("tta {} predict".format(_+1))
    predictions = np.zeros((len(test_loader.dataset), 6))

    with torch.no_grad():
        for i, image in enumerate(test_loader):
            image = image.to(device)
            output = model(image) # output shape (batch_num, num_classes)

            predictions[i*batch_size: (i+1)*batch_size] = output.detach().cpu().numpy()
    print("predict values check : ",predictions[0])
    np.savetxt("../JOB_VISION/resnet50_submission/resnet50_{}_fold.csv".format(num_fold), predictions, delimiter=",")
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 SAVED {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
# Out:
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 23520326
# ['BOY', 'FA', 'GFA', 'GIRL', 'GMA', 'MA']
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7414.05it/s]
# ==== fold_df created
#                                                path  label  fold
# 0    C:/SEOYILGUK/JOB_VISION/train//BOY\face_10.png      2     1
# 1  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1007.png      2     2
# 2  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1019.png      2     3
# 3  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1024.png      2     4
# 4  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1026.png      2     0
# number of train images: 4678
# number of valid images: 1172
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 7
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.46757679180887374
# Epoch 1/200  train_loss: 1.49915  valid_loss 1.42663  valid_acc: 0.46758  lr: 0.000250  elapsed: 28
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.4880546075085324
# Epoch 2/200  train_loss: 1.39447  valid_loss 1.35116  valid_acc: 0.48805  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.5119453924914675
# Epoch 3/200  train_loss: 1.23168  valid_loss 1.22756  valid_acc: 0.51195  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.590443686006826
# Epoch 4/200  train_loss: 1.09613  valid_loss 1.01797  valid_acc: 0.59044  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.5998293515358362
# Epoch 5/200  train_loss: 0.99924  valid_loss 0.95745  valid_acc: 0.59983  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.6245733788395904
# Epoch 6/200  train_loss: 0.92019  valid_loss 0.90820  valid_acc: 0.62457  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.6322525597269625
# Epoch 7/200  train_loss: 0.87146  valid_loss 0.97212  valid_acc: 0.63225  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.6373720136518771
# Epoch 8/200  train_loss: 0.81804  valid_loss 0.88224  valid_acc: 0.63737  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 9/200  train_loss: 0.77475  valid_loss 1.12278  valid_acc: 0.57509  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.6962457337883959
# Epoch 10/200  train_loss: 0.75250  valid_loss 0.78513  valid_acc: 0.69625  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 11/200  train_loss: 0.71467  valid_loss 0.81552  valid_acc: 0.69113  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 12/200  train_loss: 0.70194  valid_loss 0.86153  valid_acc: 0.67662  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.7167235494880546
# Epoch 13/200  train_loss: 0.67344  valid_loss 0.73655  valid_acc: 0.71672  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 14/200  train_loss: 0.60679  valid_loss 0.81117  valid_acc: 0.69966  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 15/200  train_loss: 0.60873  valid_loss 0.79197  valid_acc: 0.71075  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 16, Accuracy : 0.7192832764505119
# Epoch 16/200  train_loss: 0.61877  valid_loss 0.77178  valid_acc: 0.71928  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.7610921501706485
# Epoch 17/200  train_loss: 0.54854  valid_loss 0.75503  valid_acc: 0.76109  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 18/200  train_loss: 0.55825  valid_loss 0.72710  valid_acc: 0.74488  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 19/200  train_loss: 0.52657  valid_loss 0.73745  valid_acc: 0.75512  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 20/200  train_loss: 0.49464  valid_loss 0.77189  valid_acc: 0.70648  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 21/200  train_loss: 0.50118  valid_loss 0.75671  valid_acc: 0.74061  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 22, Accuracy : 0.773037542662116
# Epoch 22/200  train_loss: 0.46088  valid_loss 0.65089  valid_acc: 0.77304  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 23, Accuracy : 0.7841296928327645
# Epoch 23/200  train_loss: 0.45607  valid_loss 0.62152  valid_acc: 0.78413  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 24/200  train_loss: 0.43481  valid_loss 0.82186  valid_acc: 0.74744  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 25/200  train_loss: 0.43018  valid_loss 0.63271  valid_acc: 0.78413  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 26/200  train_loss: 0.43610  valid_loss 0.66961  valid_acc: 0.78242  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 27, Accuracy : 0.7858361774744027
# Epoch 27/200  train_loss: 0.40600  valid_loss 0.72629  valid_acc: 0.78584  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 28, Accuracy : 0.8003412969283277
# Epoch 28/200  train_loss: 0.41541  valid_loss 0.59828  valid_acc: 0.80034  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 29/200  train_loss: 0.39909  valid_loss 0.66404  valid_acc: 0.79181  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 30, Accuracy : 0.8011945392491467
# Epoch 30/200  train_loss: 0.37996  valid_loss 0.61572  valid_acc: 0.80119  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 31/200  train_loss: 0.37757  valid_loss 0.60881  valid_acc: 0.79693  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 32/200  train_loss: 0.39523  valid_loss 0.68553  valid_acc: 0.76365  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 33, Accuracy : 0.8071672354948806
# Epoch 33/200  train_loss: 0.37019  valid_loss 0.60285  valid_acc: 0.80717  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 34/200  train_loss: 0.38022  valid_loss 0.62641  valid_acc: 0.79437  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 35, Accuracy : 0.8088737201365188
# Epoch 35/200  train_loss: 0.34242  valid_loss 0.62826  valid_acc: 0.80887  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 36/200  train_loss: 0.36987  valid_loss 0.63399  valid_acc: 0.79693  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 37/200  train_loss: 0.33560  valid_loss 0.66412  valid_acc: 0.76877  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 38/200  train_loss: 0.36098  valid_loss 0.66157  valid_acc: 0.80802  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 39/200  train_loss: 0.30412  valid_loss 0.74111  valid_acc: 0.78669  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 40/200  train_loss: 0.33679  valid_loss 0.57461  valid_acc: 0.79949  lr: 0.000250  elapsed: 30
# val acc has not improved
# Epoch 41/200  train_loss: 0.32615  valid_loss 0.69593  valid_acc: 0.79778  lr: 0.000250  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 42, Accuracy : 0.8387372013651877
# Epoch 42/200  train_loss: 0.27313  valid_loss 0.52059  valid_acc: 0.83874  lr: 0.000125  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 43, Accuracy : 0.8455631399317406
# Epoch 43/200  train_loss: 0.25252  valid_loss 0.51292  valid_acc: 0.84556  lr: 0.000125  elapsed: 30
# val acc has not improved
# Epoch 44/200  train_loss: 0.22170  valid_loss 0.53042  valid_acc: 0.84386  lr: 0.000125  elapsed: 30
# val acc has not improved
# Epoch 45/200  train_loss: 0.21824  valid_loss 0.54599  valid_acc: 0.83276  lr: 0.000125  elapsed: 31
# val acc has not improved
# Epoch 46/200  train_loss: 0.22330  valid_loss 0.52311  valid_acc: 0.83959  lr: 0.000125  elapsed: 30
# val acc has not improved
# Epoch 47/200  train_loss: 0.23372  valid_loss 0.53751  valid_acc: 0.83703  lr: 0.000125  elapsed: 30
# val acc has not improved
# Epoch 48/200  train_loss: 0.22561  valid_loss 0.57884  valid_acc: 0.83106  lr: 0.000125  elapsed: 30
# val acc has not improved
# Epoch 49/200  train_loss: 0.23965  valid_loss 0.60467  valid_acc: 0.83020  lr: 0.000125  elapsed: 30
# val acc has not improved
# Epoch 50/200  train_loss: 0.20547  valid_loss 0.52234  valid_acc: 0.84471  lr: 0.000063  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 51, Accuracy : 0.8481228668941979
# Epoch 51/200  train_loss: 0.19010  valid_loss 0.51058  valid_acc: 0.84812  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 52/200  train_loss: 0.18346  valid_loss 0.54493  valid_acc: 0.84642  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 53/200  train_loss: 0.18066  valid_loss 0.53913  valid_acc: 0.84300  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 54/200  train_loss: 0.17980  valid_loss 0.54622  valid_acc: 0.83959  lr: 0.000063  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 55, Accuracy : 0.8498293515358362
# Epoch 55/200  train_loss: 0.20013  valid_loss 0.51216  valid_acc: 0.84983  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 56/200  train_loss: 0.17729  valid_loss 0.53038  valid_acc: 0.84983  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 57/200  train_loss: 0.17584  valid_loss 0.54698  valid_acc: 0.83362  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 58/200  train_loss: 0.18290  valid_loss 0.58055  valid_acc: 0.83788  lr: 0.000063  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 59, Accuracy : 0.8549488054607508
# Epoch 59/200  train_loss: 0.17489  valid_loss 0.53697  valid_acc: 0.85495  lr: 0.000063  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 60, Accuracy : 0.8600682593856656
# Epoch 60/200  train_loss: 0.18520  valid_loss 0.53195  valid_acc: 0.86007  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 61/200  train_loss: 0.18209  valid_loss 0.54060  valid_acc: 0.85068  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 62/200  train_loss: 0.18756  valid_loss 0.54848  valid_acc: 0.84556  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 63/200  train_loss: 0.18358  valid_loss 0.57430  valid_acc: 0.83959  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 64/200  train_loss: 0.16362  valid_loss 0.53531  valid_acc: 0.85324  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 65/200  train_loss: 0.17790  valid_loss 0.54657  valid_acc: 0.85666  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 66/200  train_loss: 0.17033  valid_loss 0.54453  valid_acc: 0.85580  lr: 0.000063  elapsed: 30
# val acc has not improved
# Epoch 67/200  train_loss: 0.16169  valid_loss 0.52307  valid_acc: 0.85495  lr: 0.000031  elapsed: 30
# val acc has not improved
# Epoch 68/200  train_loss: 0.16239  valid_loss 0.53999  valid_acc: 0.85666  lr: 0.000031  elapsed: 30
# val acc has not improved
# Epoch 69/200  train_loss: 0.15296  valid_loss 0.55545  valid_acc: 0.85324  lr: 0.000031  elapsed: 30
# val acc has not improved
# Epoch 70/200  train_loss: 0.15169  valid_loss 0.53814  valid_acc: 0.84727  lr: 0.000031  elapsed: 30
# val acc has not improved
# Epoch 71/200  train_loss: 0.15676  valid_loss 0.48534  valid_acc: 0.85922  lr: 0.000031  elapsed: 30
# val acc has not improved
# Epoch 72/200  train_loss: 0.15452  valid_loss 0.56982  valid_acc: 0.85324  lr: 0.000031  elapsed: 30
# val acc has not improved
# Epoch 73/200  train_loss: 0.14960  valid_loss 0.52187  valid_acc: 0.85666  lr: 0.000016  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 74, Accuracy : 0.8609215017064846
# Epoch 74/200  train_loss: 0.13266  valid_loss 0.50725  valid_acc: 0.86092  lr: 0.000016  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 75, Accuracy : 0.8703071672354948
# Epoch 75/200  train_loss: 0.14466  valid_loss 0.46859  valid_acc: 0.87031  lr: 0.000016  elapsed: 30
# val acc has not improved
# Epoch 76/200  train_loss: 0.13192  valid_loss 0.51193  valid_acc: 0.86007  lr: 0.000016  elapsed: 30
# val acc has not improved
# Epoch 77/200  train_loss: 0.12248  valid_loss 0.53013  valid_acc: 0.85324  lr: 0.000016  elapsed: 30
# val acc has not improved
# Epoch 78/200  train_loss: 0.13827  valid_loss 0.52695  valid_acc: 0.85922  lr: 0.000016  elapsed: 30
# val acc has not improved
# Epoch 79/200  train_loss: 0.12812  valid_loss 0.49337  valid_acc: 0.86860  lr: 0.000016  elapsed: 30
# val acc has not improved
# Epoch 80/200  train_loss: 0.13011  valid_loss 0.51442  valid_acc: 0.85751  lr: 0.000016  elapsed: 30
# val acc has not improved
# Epoch 81/200  train_loss: 0.14645  valid_loss 0.50504  valid_acc: 0.85922  lr: 0.000016  elapsed: 30
# val acc has not improved
# Epoch 82/200  train_loss: 0.12592  valid_loss 0.51708  valid_acc: 0.86092  lr: 0.000008  elapsed: 30
# val acc has not improved
# Epoch 83/200  train_loss: 0.12322  valid_loss 0.50838  valid_acc: 0.85495  lr: 0.000008  elapsed: 30
# val acc has not improved
# Epoch 84/200  train_loss: 0.12392  valid_loss 0.50699  valid_acc: 0.86007  lr: 0.000008  elapsed: 30
# val acc has not improved
# Epoch 85/200  train_loss: 0.12452  valid_loss 0.49768  valid_acc: 0.85580  lr: 0.000008  elapsed: 31
# val acc has not improved
# Epoch 86/200  train_loss: 0.12075  valid_loss 0.52824  valid_acc: 0.85324  lr: 0.000008  elapsed: 30
# val acc has not improved
# Epoch 87/200  train_loss: 0.12926  valid_loss 0.51538  valid_acc: 0.84898  lr: 0.000008  elapsed: 30
# val acc has not improved
# Epoch 88/200  train_loss: 0.13195  valid_loss 0.53010  valid_acc: 0.85751  lr: 0.000004  elapsed: 30
# val acc has not improved
# Epoch 89/200  train_loss: 0.12395  valid_loss 0.52262  valid_acc: 0.86348  lr: 0.000004  elapsed: 30
# val acc has not improved
# Epoch 90/200  train_loss: 0.13473  valid_loss 0.51549  valid_acc: 0.85751  lr: 0.000004  elapsed: 30
# val acc has not improved
# Epoch 91/200  train_loss: 0.12538  valid_loss 0.50503  valid_acc: 0.86348  lr: 0.000004  elapsed: 30
# val acc has not improved
# Epoch 92/200  train_loss: 0.12448  valid_loss 0.49759  valid_acc: 0.85580  lr: 0.000004  elapsed: 30
# val acc has not improved
# Epoch 93/200  train_loss: 0.12144  valid_loss 0.51127  valid_acc: 0.86519  lr: 0.000004  elapsed: 30
# val acc has not improved
# Epoch 94/200  train_loss: 0.12582  valid_loss 0.48415  valid_acc: 0.86604  lr: 0.000002  elapsed: 30
# val acc has not improved
# Epoch 95/200  train_loss: 0.12457  valid_loss 0.50959  valid_acc: 0.85239  lr: 0.000002  elapsed: 30
# val acc has not improved
# Epoch 96/200  train_loss: 0.12391  valid_loss 0.48055  valid_acc: 0.86604  lr: 0.000002  elapsed: 30
# val acc has not improved
# Epoch 97/200  train_loss: 0.12171  valid_loss 0.48469  valid_acc: 0.86177  lr: 0.000002  elapsed: 30
# val acc has not improved
# Epoch 98/200  train_loss: 0.11946  valid_loss 0.49254  valid_acc: 0.85666  lr: 0.000002  elapsed: 30
# val acc has not improved
# Epoch 99/200  train_loss: 0.12819  valid_loss 0.45298  valid_acc: 0.85324  lr: 0.000002  elapsed: 30
# val acc has not improved
# Epoch 100/200  train_loss: 0.11910  valid_loss 0.48444  valid_acc: 0.86092  lr: 0.000001  elapsed: 30
# val acc has not improved
# Epoch 101/200  train_loss: 0.12303  valid_loss 0.50768  valid_acc: 0.85580  lr: 0.000001  elapsed: 30
# val acc has not improved
# Epoch 102/200  train_loss: 0.12236  valid_loss 0.47411  valid_acc: 0.86092  lr: 0.000001  elapsed: 30
# val acc has not improved
# Epoch 103/200  train_loss: 0.12885  valid_loss 0.46513  valid_acc: 0.86177  lr: 0.000001  elapsed: 30
# val acc has not improved
# Epoch 104/200  train_loss: 0.12324  valid_loss 0.47454  valid_acc: 0.86092  lr: 0.000001  elapsed: 30
# val acc has not improved
# Epoch 105/200  train_loss: 0.12138  valid_loss 0.44994  valid_acc: 0.85836  lr: 0.000001  elapsed: 30
# val acc has not improved
# Epoch 106/200  train_loss: 0.12604  valid_loss 0.48064  valid_acc: 0.85922  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 107/200  train_loss: 0.11353  valid_loss 0.45491  valid_acc: 0.85836  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 108/200  train_loss: 0.13054  valid_loss 0.46447  valid_acc: 0.85324  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 109/200  train_loss: 0.12585  valid_loss 0.46045  valid_acc: 0.85495  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 110/200  train_loss: 0.12359  valid_loss 0.46235  valid_acc: 0.86092  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 111/200  train_loss: 0.12332  valid_loss 0.47801  valid_acc: 0.85324  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 112/200  train_loss: 0.11973  valid_loss 0.46710  valid_acc: 0.86433  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 113/200  train_loss: 0.11487  valid_loss 0.46089  valid_acc: 0.85580  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 114/200  train_loss: 0.12314  valid_loss 0.43398  valid_acc: 0.86177  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 115/200  train_loss: 0.12686  valid_loss 0.43473  valid_acc: 0.85410  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 116/200  train_loss: 0.11730  valid_loss 0.45732  valid_acc: 0.86177  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 117/200  train_loss: 0.12476  valid_loss 0.44352  valid_acc: 0.85751  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 118/200  train_loss: 0.12831  valid_loss 0.42289  valid_acc: 0.86348  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 119/200  train_loss: 0.11931  valid_loss 0.46142  valid_acc: 0.85239  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 120/200  train_loss: 0.12688  valid_loss 0.43646  valid_acc: 0.85495  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 121/200  train_loss: 0.11998  valid_loss 0.42842  valid_acc: 0.86348  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 122/200  train_loss: 0.12925  valid_loss 0.43500  valid_acc: 0.85836  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 123/200  train_loss: 0.13070  valid_loss 0.43493  valid_acc: 0.85836  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 124/200  train_loss: 0.13130  valid_loss 0.45539  valid_acc: 0.85922  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 125/200  train_loss: 0.12909  valid_loss 0.41075  valid_acc: 0.86519  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 126/200  train_loss: 0.13345  valid_loss 0.42700  valid_acc: 0.86007  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 127/200  train_loss: 0.12147  valid_loss 0.44322  valid_acc: 0.86519  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 128/200  train_loss: 0.12993  valid_loss 0.43936  valid_acc: 0.85751  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 129/200  train_loss: 0.13100  valid_loss 0.42479  valid_acc: 0.86519  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 130/200  train_loss: 0.13353  valid_loss 0.43200  valid_acc: 0.85922  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 131/200  train_loss: 0.12699  valid_loss 0.41373  valid_acc: 0.86348  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 132/200  train_loss: 0.12935  valid_loss 0.42461  valid_acc: 0.86945  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 133/200  train_loss: 0.13020  valid_loss 0.43310  valid_acc: 0.85751  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 134/200  train_loss: 0.13415  valid_loss 0.41634  valid_acc: 0.85239  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 135/200  train_loss: 0.13107  valid_loss 0.43617  valid_acc: 0.86092  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 136/200  train_loss: 0.13985  valid_loss 0.42656  valid_acc: 0.86519  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 137/200  train_loss: 0.13851  valid_loss 0.42587  valid_acc: 0.85836  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 138/200  train_loss: 0.13036  valid_loss 0.42809  valid_acc: 0.85666  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 139/200  train_loss: 0.13151  valid_loss 0.41974  valid_acc: 0.86433  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 140/200  train_loss: 0.13898  valid_loss 0.41978  valid_acc: 0.85410  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 141/200  train_loss: 0.13453  valid_loss 0.42755  valid_acc: 0.84812  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 142/200  train_loss: 0.13723  valid_loss 0.40096  valid_acc: 0.85666  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 143/200  train_loss: 0.13384  valid_loss 0.43944  valid_acc: 0.84983  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 144/200  train_loss: 0.13586  valid_loss 0.39342  valid_acc: 0.86263  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 145/200  train_loss: 0.13747  valid_loss 0.41930  valid_acc: 0.85922  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 146/200  train_loss: 0.14987  valid_loss 0.41743  valid_acc: 0.86092  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 147/200  train_loss: 0.13314  valid_loss 0.39845  valid_acc: 0.86007  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 148/200  train_loss: 0.14613  valid_loss 0.39955  valid_acc: 0.86177  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 149/200  train_loss: 0.14399  valid_loss 0.41610  valid_acc: 0.86092  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 150/200  train_loss: 0.14432  valid_loss 0.40273  valid_acc: 0.86263  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 151/200  train_loss: 0.14648  valid_loss 0.41925  valid_acc: 0.85580  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 152/200  train_loss: 0.14733  valid_loss 0.39566  valid_acc: 0.86775  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 153/200  train_loss: 0.14945  valid_loss 0.41014  valid_acc: 0.85751  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 154/200  train_loss: 0.15096  valid_loss 0.40357  valid_acc: 0.85751  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 155/200  train_loss: 0.14758  valid_loss 0.39284  valid_acc: 0.85580  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 156/200  train_loss: 0.15823  valid_loss 0.40694  valid_acc: 0.86604  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 157/200  train_loss: 0.15684  valid_loss 0.40917  valid_acc: 0.85154  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 158/200  train_loss: 0.14998  valid_loss 0.39886  valid_acc: 0.86604  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 159/200  train_loss: 0.15471  valid_loss 0.40941  valid_acc: 0.85410  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 160/200  train_loss: 0.15739  valid_loss 0.40556  valid_acc: 0.86007  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 161/200  train_loss: 0.15504  valid_loss 0.40586  valid_acc: 0.86519  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 162/200  train_loss: 0.15568  valid_loss 0.38842  valid_acc: 0.86007  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 163/200  train_loss: 0.15493  valid_loss 0.39729  valid_acc: 0.86348  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 164/200  train_loss: 0.15918  valid_loss 0.40883  valid_acc: 0.86007  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 165/200  train_loss: 0.15597  valid_loss 0.39868  valid_acc: 0.85836  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 166/200  train_loss: 0.15746  valid_loss 0.41030  valid_acc: 0.85666  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 167/200  train_loss: 0.16464  valid_loss 0.39112  valid_acc: 0.86092  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 168/200  train_loss: 0.15616  valid_loss 0.39385  valid_acc: 0.86177  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 169/200  train_loss: 0.16063  valid_loss 0.40105  valid_acc: 0.85836  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 170/200  train_loss: 0.16980  valid_loss 0.38631  valid_acc: 0.86775  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 171/200  train_loss: 0.16999  valid_loss 0.38380  valid_acc: 0.86519  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 172/200  train_loss: 0.16432  valid_loss 0.39061  valid_acc: 0.86092  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 173/200  train_loss: 0.17678  valid_loss 0.39270  valid_acc: 0.86604  lr: 0.000000  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 174, Accuracy : 0.8720136518771331
# Epoch 174/200  train_loss: 0.17935  valid_loss 0.38481  valid_acc: 0.87201  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 175/200  train_loss: 0.17579  valid_loss 0.38093  valid_acc: 0.86860  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 176/200  train_loss: 0.17494  valid_loss 0.38602  valid_acc: 0.85410  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 177/200  train_loss: 0.18106  valid_loss 0.39529  valid_acc: 0.85751  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 178/200  train_loss: 0.17788  valid_loss 0.38386  valid_acc: 0.86092  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 179/200  train_loss: 0.18329  valid_loss 0.39399  valid_acc: 0.85836  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 180/200  train_loss: 0.17632  valid_loss 0.39290  valid_acc: 0.86007  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 181/200  train_loss: 0.18160  valid_loss 0.39018  valid_acc: 0.86348  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 182/200  train_loss: 0.18013  valid_loss 0.40232  valid_acc: 0.85666  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 183/200  train_loss: 0.18922  valid_loss 0.40052  valid_acc: 0.85751  lr: 0.000000  elapsed: 33
# val acc has not improved
# Epoch 184/200  train_loss: 0.18997  valid_loss 0.39472  valid_acc: 0.86177  lr: 0.000000  elapsed: 33
# val acc has not improved
# Epoch 185/200  train_loss: 0.19164  valid_loss 0.39406  valid_acc: 0.86433  lr: 0.000000  elapsed: 34
# val acc has not improved
# Epoch 186/200  train_loss: 0.19162  valid_loss 0.39584  valid_acc: 0.85751  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 187/200  train_loss: 0.18942  valid_loss 0.39193  valid_acc: 0.86092  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 188/200  train_loss: 0.20029  valid_loss 0.39004  valid_acc: 0.86433  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 189/200  train_loss: 0.19620  valid_loss 0.40244  valid_acc: 0.85836  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 190/200  train_loss: 0.19431  valid_loss 0.41846  valid_acc: 0.84898  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 191/200  train_loss: 0.20009  valid_loss 0.39184  valid_acc: 0.85580  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 192/200  train_loss: 0.20675  valid_loss 0.39524  valid_acc: 0.86689  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 193/200  train_loss: 0.20437  valid_loss 0.40343  valid_acc: 0.86348  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 194/200  train_loss: 0.21098  valid_loss 0.39901  valid_acc: 0.86433  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 195/200  train_loss: 0.20433  valid_loss 0.38576  valid_acc: 0.86519  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 196/200  train_loss: 0.21051  valid_loss 0.38965  valid_acc: 0.86177  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 197/200  train_loss: 0.21015  valid_loss 0.38209  valid_acc: 0.87116  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 198/200  train_loss: 0.21329  valid_loss 0.41516  valid_acc: 0.85410  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 199/200  train_loss: 0.21435  valid_loss 0.39506  valid_acc: 0.86263  lr: 0.000000  elapsed: 33
# val acc has not improved
# Epoch 200/200  train_loss: 0.21599  valid_loss 0.41092  valid_acc: 0.85751  lr: 0.000000  elapsed: 31
# ================ ༼ つ ◕_◕ ༽つ Model Load 0_th FOLD ===============
# predict values check :  [ 3.47783947  0.64769703 -4.2690897   0.69395387 -3.88245201 -5.19768047]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 23520326
# ['BOY', 'FA', 'GFA', 'GIRL', 'GMA', 'MA']
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 6857.77it/s]
# ==== fold_df created
#                                                path  label  fold
# 0    C:/SEOYILGUK/JOB_VISION/train//BOY\face_10.png      2     1
# 1  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1007.png      2     2
# 2  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1019.png      2     3
# 3  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1024.png      2     4
# 4  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1026.png      2     0
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 7
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.3193851409052092
# Epoch 1/200  train_loss: 1.51177  valid_loss 1.50723  valid_acc: 0.31939  lr: 0.000250  elapsed: 28
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.4824935952177626
# Epoch 2/200  train_loss: 1.39461  valid_loss 1.32586  valid_acc: 0.48249  lr: 0.000250  elapsed: 31
# val acc has not improved
# Epoch 3/200  train_loss: 1.23955  valid_loss 1.22552  valid_acc: 0.46285  lr: 0.000250  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.5798462852263023
# Epoch 4/200  train_loss: 1.07480  valid_loss 1.02951  valid_acc: 0.57985  lr: 0.000250  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.6003415883859948
# Epoch 5/200  train_loss: 0.96082  valid_loss 1.01539  valid_acc: 0.60034  lr: 0.000250  elapsed: 34
# val acc has not improved
# Epoch 6/200  train_loss: 0.90933  valid_loss 0.99666  valid_acc: 0.59607  lr: 0.000250  elapsed: 34
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.6114432109308283
# Epoch 7/200  train_loss: 0.85958  valid_loss 0.95890  valid_acc: 0.61144  lr: 0.000250  elapsed: 33
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.6293766011955594
# Epoch 8/200  train_loss: 0.80035  valid_loss 0.93755  valid_acc: 0.62938  lr: 0.000250  elapsed: 33
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.6720751494449189
# Epoch 9/200  train_loss: 0.78001  valid_loss 0.80663  valid_acc: 0.67208  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 10/200  train_loss: 0.74695  valid_loss 0.87571  valid_acc: 0.65670  lr: 0.000250  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 11, Accuracy : 0.7070879590093937
# Epoch 11/200  train_loss: 0.69822  valid_loss 0.74481  valid_acc: 0.70709  lr: 0.000250  elapsed: 33
# val acc has not improved
# Epoch 12/200  train_loss: 0.67445  valid_loss 0.93644  valid_acc: 0.64560  lr: 0.000250  elapsed: 33
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.7241673783091375
# Epoch 13/200  train_loss: 0.64875  valid_loss 0.75243  valid_acc: 0.72417  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 14/200  train_loss: 0.61971  valid_loss 0.89931  valid_acc: 0.66183  lr: 0.000250  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 15, Accuracy : 0.7378309137489325
# Epoch 15/200  train_loss: 0.59425  valid_loss 0.73438  valid_acc: 0.73783  lr: 0.000250  elapsed: 33
# val acc has not improved
# Epoch 16/200  train_loss: 0.58225  valid_loss 0.83962  valid_acc: 0.69001  lr: 0.000250  elapsed: 33
# val acc has not improved
# Epoch 17/200  train_loss: 0.54561  valid_loss 0.74550  valid_acc: 0.72758  lr: 0.000250  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 18, Accuracy : 0.7429547395388557
# Epoch 18/200  train_loss: 0.53525  valid_loss 0.71369  valid_acc: 0.74295  lr: 0.000250  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 19, Accuracy : 0.7600341588385995
# Epoch 19/200  train_loss: 0.51736  valid_loss 0.66720  valid_acc: 0.76003  lr: 0.000250  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 20, Accuracy : 0.7702818104184458
# Epoch 20/200  train_loss: 0.51740  valid_loss 0.61906  valid_acc: 0.77028  lr: 0.000250  elapsed: 31
# val acc has not improved
# Epoch 21/200  train_loss: 0.46258  valid_loss 0.68608  valid_acc: 0.75576  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 22/200  train_loss: 0.47441  valid_loss 0.65006  valid_acc: 0.75491  lr: 0.000250  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 23, Accuracy : 0.7796754910333049
# Epoch 23/200  train_loss: 0.47499  valid_loss 0.66904  valid_acc: 0.77968  lr: 0.000250  elapsed: 31
# val acc has not improved
# Epoch 24/200  train_loss: 0.44509  valid_loss 0.77802  valid_acc: 0.76943  lr: 0.000250  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 25, Accuracy : 0.798462852263023
# Epoch 25/200  train_loss: 0.43116  valid_loss 0.62161  valid_acc: 0.79846  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 26/200  train_loss: 0.42791  valid_loss 0.66543  valid_acc: 0.77028  lr: 0.000250  elapsed: 33
# val acc has not improved
# Epoch 27/200  train_loss: 0.41847  valid_loss 0.65723  valid_acc: 0.78138  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 28/200  train_loss: 0.38703  valid_loss 0.57715  valid_acc: 0.79846  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 29/200  train_loss: 0.41074  valid_loss 0.80947  valid_acc: 0.76089  lr: 0.000250  elapsed: 33
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 30, Accuracy : 0.8010247651579846
# Epoch 30/200  train_loss: 0.37162  valid_loss 0.60712  valid_acc: 0.80102  lr: 0.000250  elapsed: 31
# val acc has not improved
# Epoch 31/200  train_loss: 0.40853  valid_loss 0.63988  valid_acc: 0.78907  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 32/200  train_loss: 0.38412  valid_loss 0.59372  valid_acc: 0.79249  lr: 0.000250  elapsed: 31
# val acc has not improved
# Epoch 33/200  train_loss: 0.36419  valid_loss 0.65270  valid_acc: 0.77797  lr: 0.000250  elapsed: 31
# val acc has not improved
# Epoch 34/200  train_loss: 0.37702  valid_loss 0.65605  valid_acc: 0.78053  lr: 0.000250  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 35, Accuracy : 0.8035866780529461
# Epoch 35/200  train_loss: 0.37571  valid_loss 0.59856  valid_acc: 0.80359  lr: 0.000250  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 36, Accuracy : 0.8087105038428694
# Epoch 36/200  train_loss: 0.35990  valid_loss 0.60024  valid_acc: 0.80871  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 37/200  train_loss: 0.36716  valid_loss 0.66278  valid_acc: 0.78309  lr: 0.000250  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 38, Accuracy : 0.8283518360375747
# Epoch 38/200  train_loss: 0.35934  valid_loss 0.57327  valid_acc: 0.82835  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 39/200  train_loss: 0.34383  valid_loss 0.57343  valid_acc: 0.81554  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 40/200  train_loss: 0.32763  valid_loss 0.64248  valid_acc: 0.81298  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 41/200  train_loss: 0.30829  valid_loss 0.70883  valid_acc: 0.78053  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 42/200  train_loss: 0.32358  valid_loss 0.53407  valid_acc: 0.82664  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 43/200  train_loss: 0.30623  valid_loss 0.57818  valid_acc: 0.82323  lr: 0.000250  elapsed: 32
# val acc has not improved
# Epoch 44/200  train_loss: 0.29338  valid_loss 0.58602  valid_acc: 0.82835  lr: 0.000250  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 45, Accuracy : 0.8479931682322801
# Epoch 45/200  train_loss: 0.24356  valid_loss 0.55146  valid_acc: 0.84799  lr: 0.000125  elapsed: 35
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 46, Accuracy : 0.8514090520922288
# Epoch 46/200  train_loss: 0.25821  valid_loss 0.48712  valid_acc: 0.85141  lr: 0.000125  elapsed: 33
# val acc has not improved
# Epoch 47/200  train_loss: 0.23934  valid_loss 0.51430  valid_acc: 0.84543  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 48/200  train_loss: 0.22499  valid_loss 0.52592  valid_acc: 0.84116  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 49/200  train_loss: 0.23029  valid_loss 0.51515  valid_acc: 0.84543  lr: 0.000125  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 50, Accuracy : 0.856532877882152
# Epoch 50/200  train_loss: 0.23644  valid_loss 0.54934  valid_acc: 0.85653  lr: 0.000125  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 51, Accuracy : 0.8590947907771136
# Epoch 51/200  train_loss: 0.22878  valid_loss 0.53718  valid_acc: 0.85909  lr: 0.000125  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 52, Accuracy : 0.8659265584970111
# Epoch 52/200  train_loss: 0.22631  valid_loss 0.49710  valid_acc: 0.86593  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 53/200  train_loss: 0.20959  valid_loss 0.56303  valid_acc: 0.84629  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 54/200  train_loss: 0.22545  valid_loss 0.59653  valid_acc: 0.84629  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 55/200  train_loss: 0.23433  valid_loss 0.48920  valid_acc: 0.85568  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 56/200  train_loss: 0.20852  valid_loss 0.54306  valid_acc: 0.85141  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 57/200  train_loss: 0.23033  valid_loss 0.51746  valid_acc: 0.84287  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 58/200  train_loss: 0.21493  valid_loss 0.57297  valid_acc: 0.84031  lr: 0.000125  elapsed: 32
# val acc has not improved
# Epoch 59/200  train_loss: 0.19334  valid_loss 0.49684  valid_acc: 0.84714  lr: 0.000063  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 60, Accuracy : 0.8676345004269855
# Epoch 60/200  train_loss: 0.18506  valid_loss 0.48454  valid_acc: 0.86763  lr: 0.000063  elapsed: 32
# val acc has not improved
# Epoch 61/200  train_loss: 0.17050  valid_loss 0.53346  valid_acc: 0.85824  lr: 0.000063  elapsed: 32
# val acc has not improved
# Epoch 62/200  train_loss: 0.17166  valid_loss 0.52705  valid_acc: 0.86763  lr: 0.000063  elapsed: 32
# val acc has not improved
# Epoch 63/200  train_loss: 0.17122  valid_loss 0.51446  valid_acc: 0.86507  lr: 0.000063  elapsed: 32
# val acc has not improved
# Epoch 64/200  train_loss: 0.16510  valid_loss 0.54031  valid_acc: 0.85397  lr: 0.000063  elapsed: 32
# val acc has not improved
# Epoch 65/200  train_loss: 0.16096  valid_loss 0.52144  valid_acc: 0.85141  lr: 0.000063  elapsed: 32
# val acc has not improved
# Epoch 66/200  train_loss: 0.17001  valid_loss 0.48582  valid_acc: 0.86763  lr: 0.000063  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 67, Accuracy : 0.8684884713919727
# Epoch 67/200  train_loss: 0.14869  valid_loss 0.50304  valid_acc: 0.86849  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 68/200  train_loss: 0.15395  valid_loss 0.50378  valid_acc: 0.86849  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 69/200  train_loss: 0.16287  valid_loss 0.48890  valid_acc: 0.85995  lr: 0.000031  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 70, Accuracy : 0.8753202391118702
# Epoch 70/200  train_loss: 0.14800  valid_loss 0.48774  valid_acc: 0.87532  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 71/200  train_loss: 0.14209  valid_loss 0.47484  valid_acc: 0.87447  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 72/200  train_loss: 0.15488  valid_loss 0.47897  valid_acc: 0.87190  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 73/200  train_loss: 0.15792  valid_loss 0.52084  valid_acc: 0.86593  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 74/200  train_loss: 0.14967  valid_loss 0.49752  valid_acc: 0.86080  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 75/200  train_loss: 0.14012  valid_loss 0.53010  valid_acc: 0.85995  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 76/200  train_loss: 0.15246  valid_loss 0.45271  valid_acc: 0.87190  lr: 0.000031  elapsed: 32
# val acc has not improved
# Epoch 77/200  train_loss: 0.13180  valid_loss 0.49248  valid_acc: 0.87447  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 78/200  train_loss: 0.13374  valid_loss 0.52516  valid_acc: 0.85568  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 79/200  train_loss: 0.12683  valid_loss 0.47946  valid_acc: 0.86336  lr: 0.000016  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 80, Accuracy : 0.8787361229718189
# Epoch 80/200  train_loss: 0.13292  valid_loss 0.49356  valid_acc: 0.87874  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 81/200  train_loss: 0.12366  valid_loss 0.50839  valid_acc: 0.86422  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 82/200  train_loss: 0.13912  valid_loss 0.49398  valid_acc: 0.86849  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 83/200  train_loss: 0.12113  valid_loss 0.49181  valid_acc: 0.86507  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 84/200  train_loss: 0.12816  valid_loss 0.49142  valid_acc: 0.86763  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 85/200  train_loss: 0.13524  valid_loss 0.52352  valid_acc: 0.86422  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 86/200  train_loss: 0.12813  valid_loss 0.50254  valid_acc: 0.86422  lr: 0.000016  elapsed: 32
# val acc has not improved
# Epoch 87/200  train_loss: 0.11670  valid_loss 0.48599  valid_acc: 0.86934  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 88/200  train_loss: 0.13188  valid_loss 0.47658  valid_acc: 0.86593  lr: 0.000008  elapsed: 31
# val acc has not improved
# Epoch 89/200  train_loss: 0.12774  valid_loss 0.50105  valid_acc: 0.86934  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 90/200  train_loss: 0.12710  valid_loss 0.48733  valid_acc: 0.86934  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 91/200  train_loss: 0.12213  valid_loss 0.48939  valid_acc: 0.87361  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 92/200  train_loss: 0.13015  valid_loss 0.50090  valid_acc: 0.86763  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 93/200  train_loss: 0.11765  valid_loss 0.49434  valid_acc: 0.86849  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 94/200  train_loss: 0.12380  valid_loss 0.48946  valid_acc: 0.86422  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 95/200  train_loss: 0.10731  valid_loss 0.51090  valid_acc: 0.86166  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 96/200  train_loss: 0.11881  valid_loss 0.48112  valid_acc: 0.86763  lr: 0.000004  elapsed: 31
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 97, Accuracy : 0.8812980358667806
# Epoch 97/200  train_loss: 0.11573  valid_loss 0.47148  valid_acc: 0.88130  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 98/200  train_loss: 0.11790  valid_loss 0.48638  valid_acc: 0.86678  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 99/200  train_loss: 0.12745  valid_loss 0.46894  valid_acc: 0.86593  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 100/200  train_loss: 0.10560  valid_loss 0.45722  valid_acc: 0.87020  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 101/200  train_loss: 0.11565  valid_loss 0.48389  valid_acc: 0.86934  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 102/200  train_loss: 0.12402  valid_loss 0.51766  valid_acc: 0.86080  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 103/200  train_loss: 0.11636  valid_loss 0.48054  valid_acc: 0.87276  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 104/200  train_loss: 0.13093  valid_loss 0.46612  valid_acc: 0.87361  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 105/200  train_loss: 0.11994  valid_loss 0.46271  valid_acc: 0.87190  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 106/200  train_loss: 0.11782  valid_loss 0.46537  valid_acc: 0.87361  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 107/200  train_loss: 0.11775  valid_loss 0.45435  valid_acc: 0.86507  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 108/200  train_loss: 0.12788  valid_loss 0.43455  valid_acc: 0.87703  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 109/200  train_loss: 0.11907  valid_loss 0.45758  valid_acc: 0.86849  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 110/200  train_loss: 0.12494  valid_loss 0.46712  valid_acc: 0.86251  lr: 0.000001  elapsed: 31
# val acc has not improved
# Epoch 111/200  train_loss: 0.11827  valid_loss 0.44373  valid_acc: 0.87105  lr: 0.000001  elapsed: 32
# val acc has not improved
# Epoch 112/200  train_loss: 0.12161  valid_loss 0.46663  valid_acc: 0.86763  lr: 0.000001  elapsed: 32
# val acc has not improved
# Epoch 113/200  train_loss: 0.12617  valid_loss 0.47964  valid_acc: 0.86507  lr: 0.000001  elapsed: 31
# val acc has not improved
# Epoch 114/200  train_loss: 0.12257  valid_loss 0.43491  valid_acc: 0.86507  lr: 0.000001  elapsed: 32
# val acc has not improved
# Epoch 115/200  train_loss: 0.11973  valid_loss 0.43794  valid_acc: 0.87447  lr: 0.000001  elapsed: 32
# val acc has not improved
# Epoch 116/200  train_loss: 0.10816  valid_loss 0.45770  valid_acc: 0.86593  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 117/200  train_loss: 0.11363  valid_loss 0.47201  valid_acc: 0.86080  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 118/200  train_loss: 0.11177  valid_loss 0.44544  valid_acc: 0.86251  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 119/200  train_loss: 0.11636  valid_loss 0.43620  valid_acc: 0.86763  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 120/200  train_loss: 0.11865  valid_loss 0.45116  valid_acc: 0.86336  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 121/200  train_loss: 0.11898  valid_loss 0.45832  valid_acc: 0.86336  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 122/200  train_loss: 0.12263  valid_loss 0.43749  valid_acc: 0.86507  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 123/200  train_loss: 0.12058  valid_loss 0.42281  valid_acc: 0.87105  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 124/200  train_loss: 0.10747  valid_loss 0.44214  valid_acc: 0.86507  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 125/200  train_loss: 0.12245  valid_loss 0.42660  valid_acc: 0.86678  lr: 0.000000  elapsed: 32
# ...
# Epoch 80/200  train_loss: 0.13741  valid_loss 0.47651  valid_acc: 0.84919  lr: 0.000008  elapsed: 33
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 81, Accuracy : 0.869751499571551
# Epoch 81/200  train_loss: 0.13078  valid_loss 0.45899  valid_acc: 0.86975  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 82/200  train_loss: 0.14419  valid_loss 0.47742  valid_acc: 0.85176  lr: 0.000008  elapsed: 33
# val acc has not improved
# Epoch 83/200  train_loss: 0.13023  valid_loss 0.48995  valid_acc: 0.86118  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 84/200  train_loss: 0.11564  valid_loss 0.45771  valid_acc: 0.86461  lr: 0.000008  elapsed: 33
# val acc has not improved
# Epoch 85/200  train_loss: 0.12621  valid_loss 0.47384  valid_acc: 0.86118  lr: 0.000008  elapsed: 33
# val acc has not improved
# Epoch 86/200  train_loss: 0.12096  valid_loss 0.48890  valid_acc: 0.86033  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 87/200  train_loss: 0.13349  valid_loss 0.47141  valid_acc: 0.86375  lr: 0.000008  elapsed: 32
# val acc has not improved
# Epoch 88/200  train_loss: 0.13639  valid_loss 0.44614  valid_acc: 0.86461  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 89/200  train_loss: 0.11996  valid_loss 0.46144  valid_acc: 0.86975  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 90/200  train_loss: 0.12541  valid_loss 0.46556  valid_acc: 0.86547  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 91/200  train_loss: 0.14172  valid_loss 0.42700  valid_acc: 0.86975  lr: 0.000004  elapsed: 33
# val acc has not improved
# Epoch 92/200  train_loss: 0.12842  valid_loss 0.47055  valid_acc: 0.86290  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 93/200  train_loss: 0.13343  valid_loss 0.46088  valid_acc: 0.86118  lr: 0.000004  elapsed: 32
# val acc has not improved
# Epoch 94/200  train_loss: 0.13294  valid_loss 0.45347  valid_acc: 0.86290  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 95/200  train_loss: 0.12290  valid_loss 0.48694  valid_acc: 0.86718  lr: 0.000002  elapsed: 33
# val acc has not improved
# Epoch 96/200  train_loss: 0.12587  valid_loss 0.43334  valid_acc: 0.86461  lr: 0.000002  elapsed: 32
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 97, Accuracy : 0.8723221936589546
# Epoch 97/200  train_loss: 0.12273  valid_loss 0.44726  valid_acc: 0.87232  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 98/200  train_loss: 0.13066  valid_loss 0.46912  valid_acc: 0.85261  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 99/200  train_loss: 0.13824  valid_loss 0.45035  valid_acc: 0.86718  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 100/200  train_loss: 0.11877  valid_loss 0.46291  valid_acc: 0.86375  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 101/200  train_loss: 0.12424  valid_loss 0.41940  valid_acc: 0.86375  lr: 0.000002  elapsed: 33
# val acc has not improved
# Epoch 102/200  train_loss: 0.13059  valid_loss 0.44328  valid_acc: 0.86804  lr: 0.000002  elapsed: 32
# val acc has not improved
# Epoch 103/200  train_loss: 0.13700  valid_loss 0.44558  valid_acc: 0.86889  lr: 0.000002  elapsed: 33
# val acc has not improved
# Epoch 104/200  train_loss: 0.13613  valid_loss 0.47306  valid_acc: 0.85690  lr: 0.000001  elapsed: 32
# val acc has not improved
# Epoch 105/200  train_loss: 0.12323  valid_loss 0.41288  valid_acc: 0.87232  lr: 0.000001  elapsed: 33
# val acc has not improved
# Epoch 106/200  train_loss: 0.12404  valid_loss 0.43661  valid_acc: 0.86118  lr: 0.000001  elapsed: 32
# val acc has not improved
# Epoch 107/200  train_loss: 0.12057  valid_loss 0.41901  valid_acc: 0.86889  lr: 0.000001  elapsed: 33
# val acc has not improved
# Epoch 108/200  train_loss: 0.12449  valid_loss 0.43440  valid_acc: 0.86632  lr: 0.000001  elapsed: 32
# val acc has not improved
# Epoch 109/200  train_loss: 0.12179  valid_loss 0.42599  valid_acc: 0.86632  lr: 0.000001  elapsed: 33
# val acc has not improved
# Epoch 110/200  train_loss: 0.13464  valid_loss 0.43353  valid_acc: 0.86632  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 111/200  train_loss: 0.13116  valid_loss 0.43552  valid_acc: 0.85947  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 112/200  train_loss: 0.12679  valid_loss 0.40147  valid_acc: 0.87232  lr: 0.000000  elapsed: 32
# val acc has not improved
# Epoch 113/200  train_loss: 0.12086  valid_loss 0.43803  valid_acc: 0.85861  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 114/200  train_loss: 0.13061  valid_loss 0.40759  valid_acc: 0.86804  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 115/200  train_loss: 0.13052  valid_loss 0.41242  valid_acc: 0.86461  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 116/200  train_loss: 0.13482  valid_loss 0.39556  valid_acc: 0.86718  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 117/200  train_loss: 0.12950  valid_loss 0.41850  valid_acc: 0.86461  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 118/200  train_loss: 0.12771  valid_loss 0.40204  valid_acc: 0.86547  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 119/200  train_loss: 0.11947  valid_loss 0.43150  valid_acc: 0.85775  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 120/200  train_loss: 0.12342  valid_loss 0.41622  valid_acc: 0.86461  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 121/200  train_loss: 0.12769  valid_loss 0.40812  valid_acc: 0.86375  lr: 0.000000  elapsed: 31
# val acc has not improved
# Epoch 122/200  train_loss: 0.12460  valid_loss 0.42374  valid_acc: 0.85861  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 123/200  train_loss: 0.13695  valid_loss 0.41952  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 124/200  train_loss: 0.12722  valid_loss 0.40680  valid_acc: 0.85690  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 125/200  train_loss: 0.12757  valid_loss 0.39855  valid_acc: 0.87232  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 126/200  train_loss: 0.14016  valid_loss 0.41358  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 127/200  train_loss: 0.12638  valid_loss 0.39473  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 128/200  train_loss: 0.13740  valid_loss 0.39884  valid_acc: 0.86632  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 129/200  train_loss: 0.13110  valid_loss 0.39156  valid_acc: 0.86632  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 130/200  train_loss: 0.13661  valid_loss 0.39561  valid_acc: 0.86375  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 131/200  train_loss: 0.12673  valid_loss 0.41770  valid_acc: 0.85690  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 132/200  train_loss: 0.13305  valid_loss 0.41205  valid_acc: 0.86632  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 133/200  train_loss: 0.13242  valid_loss 0.39982  valid_acc: 0.86461  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 134/200  train_loss: 0.13910  valid_loss 0.38687  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 135/200  train_loss: 0.13501  valid_loss 0.38873  valid_acc: 0.86375  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 136/200  train_loss: 0.13475  valid_loss 0.39059  valid_acc: 0.86461  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 137/200  train_loss: 0.13910  valid_loss 0.39039  valid_acc: 0.86632  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 138/200  train_loss: 0.13604  valid_loss 0.39345  valid_acc: 0.86375  lr: 0.000000  elapsed: 30
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 139, Accuracy : 0.8731790916880892
# Epoch 139/200  train_loss: 0.13537  valid_loss 0.39155  valid_acc: 0.87318  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 140/200  train_loss: 0.14126  valid_loss 0.39609  valid_acc: 0.86118  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 141/200  train_loss: 0.14081  valid_loss 0.40619  valid_acc: 0.86118  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 142/200  train_loss: 0.13833  valid_loss 0.37868  valid_acc: 0.86632  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 143/200  train_loss: 0.14128  valid_loss 0.38386  valid_acc: 0.86290  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 144/200  train_loss: 0.13613  valid_loss 0.37657  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 145/200  train_loss: 0.14515  valid_loss 0.37957  valid_acc: 0.86547  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 146/200  train_loss: 0.14656  valid_loss 0.37617  valid_acc: 0.87061  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 147/200  train_loss: 0.15413  valid_loss 0.38935  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 148/200  train_loss: 0.14459  valid_loss 0.39295  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 149/200  train_loss: 0.14328  valid_loss 0.35878  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 150/200  train_loss: 0.15331  valid_loss 0.37918  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 151/200  train_loss: 0.14434  valid_loss 0.37861  valid_acc: 0.86204  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 152/200  train_loss: 0.15058  valid_loss 0.39385  valid_acc: 0.86804  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 153/200  train_loss: 0.15486  valid_loss 0.38395  valid_acc: 0.85947  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 154/200  train_loss: 0.15431  valid_loss 0.37706  valid_acc: 0.86804  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 155/200  train_loss: 0.15135  valid_loss 0.39461  valid_acc: 0.86804  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 156/200  train_loss: 0.15527  valid_loss 0.38288  valid_acc: 0.87147  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 157/200  train_loss: 0.15725  valid_loss 0.37251  valid_acc: 0.86204  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 158/200  train_loss: 0.15080  valid_loss 0.36773  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 159/200  train_loss: 0.14756  valid_loss 0.37600  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 160/200  train_loss: 0.15642  valid_loss 0.37367  valid_acc: 0.87318  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 161/200  train_loss: 0.15687  valid_loss 0.37257  valid_acc: 0.86804  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 162/200  train_loss: 0.14935  valid_loss 0.37407  valid_acc: 0.86461  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 163/200  train_loss: 0.15347  valid_loss 0.37271  valid_acc: 0.86204  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 164/200  train_loss: 0.16134  valid_loss 0.38121  valid_acc: 0.86804  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 165/200  train_loss: 0.16365  valid_loss 0.37956  valid_acc: 0.86118  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 166/200  train_loss: 0.15526  valid_loss 0.37280  valid_acc: 0.86204  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 167/200  train_loss: 0.16200  valid_loss 0.36221  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 168/200  train_loss: 0.16588  valid_loss 0.36878  valid_acc: 0.86632  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 169/200  train_loss: 0.15651  valid_loss 0.36502  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 170/200  train_loss: 0.16248  valid_loss 0.38253  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 171/200  train_loss: 0.16447  valid_loss 0.37433  valid_acc: 0.87061  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 172/200  train_loss: 0.16232  valid_loss 0.36959  valid_acc: 0.86804  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 173/200  train_loss: 0.17552  valid_loss 0.37365  valid_acc: 0.86718  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 174/200  train_loss: 0.17448  valid_loss 0.37697  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 175/200  train_loss: 0.17580  valid_loss 0.37883  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 176/200  train_loss: 0.18174  valid_loss 0.38200  valid_acc: 0.86461  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 177/200  train_loss: 0.17995  valid_loss 0.38068  valid_acc: 0.85347  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 178/200  train_loss: 0.17341  valid_loss 0.36942  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 179/200  train_loss: 0.18462  valid_loss 0.37816  valid_acc: 0.86204  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 180/200  train_loss: 0.17823  valid_loss 0.38352  valid_acc: 0.86547  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 181/200  train_loss: 0.17931  valid_loss 0.37271  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 182/200  train_loss: 0.18627  valid_loss 0.36835  valid_acc: 0.86889  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 183/200  train_loss: 0.19297  valid_loss 0.37211  valid_acc: 0.86547  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 184/200  train_loss: 0.18432  valid_loss 0.37369  valid_acc: 0.85861  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 185/200  train_loss: 0.18359  valid_loss 0.37919  valid_acc: 0.86889  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 186/200  train_loss: 0.19138  valid_loss 0.37742  valid_acc: 0.86375  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 187/200  train_loss: 0.19480  valid_loss 0.36726  valid_acc: 0.86632  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 188/200  train_loss: 0.19304  valid_loss 0.36820  valid_acc: 0.86204  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 189/200  train_loss: 0.19201  valid_loss 0.37984  valid_acc: 0.86118  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 190/200  train_loss: 0.19781  valid_loss 0.37552  valid_acc: 0.86547  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 191/200  train_loss: 0.20202  valid_loss 0.38362  valid_acc: 0.86118  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 192/200  train_loss: 0.20001  valid_loss 0.37331  valid_acc: 0.87318  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 193/200  train_loss: 0.20262  valid_loss 0.37775  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 194/200  train_loss: 0.20867  valid_loss 0.37952  valid_acc: 0.87061  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 195/200  train_loss: 0.20706  valid_loss 0.37117  valid_acc: 0.87061  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 196/200  train_loss: 0.20718  valid_loss 0.38127  valid_acc: 0.86804  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 197/200  train_loss: 0.20808  valid_loss 0.38454  valid_acc: 0.86632  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 198/200  train_loss: 0.21435  valid_loss 0.37954  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 199/200  train_loss: 0.21298  valid_loss 0.38817  valid_acc: 0.86375  lr: 0.000000  elapsed: 30
# val acc has not improved
# Epoch 200/200  train_loss: 0.21305  valid_loss 0.37857  valid_acc: 0.86975  lr: 0.000000  elapsed: 30
# ================ ༼ つ ◕_◕ ༽つ Model Load 4_th FOLD ===============
# predict values check :  [ 5.22818375  1.11873901 -3.86643362  0.85682261 -7.18434525 -8.15405846]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 4_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
