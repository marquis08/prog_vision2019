# %%
import gc
import os
import time
import numpy as np
import pandas as pd
from glob import glob
import tqdm
import argparse
import tqdm
from collections import defaultdict, Counter
from PIL import Image
import cv2

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch import nn, cuda
from torch.autograd import Variable 
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import CenterCrop

from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR
from utils import count_parameters, seed_everything, AdamW, CosineAnnealingWithRestartsLR

from efficientnet_pytorch import EfficientNet
import torchvision.models as models

from model import Baseline, Resnet18, Resnet50, Resnext50, Resnext101
from customs import mixup_data, mixup_criterion
from transforms import get_transform
from dataloader import make_loader, TestDataset

#num_fold = 0 #select fold number for training
for num_fold in range(5):
    
    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 STARTS {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
    train_csv = pd.read_csv("../JOB_VISION/train.csv")

    def to_numpy(t):
        return t.cpu().detach().numpy()

    def make_folds(df, n_folds: int) -> pd.DataFrame:

        cls_counts = Counter([classes for classes in df['label']])
        fold_cls_counts = defaultdict()
        for class_index in cls_counts.keys():
            fold_cls_counts[class_index] = np.zeros(n_folds, dtype=np.int)

        df['fold'] = -1
        pbar = tqdm.tqdm(total=len(df))

        def get_fold(row):
            class_index = row['label']
            counts = fold_cls_counts[class_index]
            fold = np.argmin(counts)
            counts[fold] += 1
            fold_cls_counts[class_index] = counts
            row['fold']=fold
            pbar.update()
            return row

        df = df.apply(get_fold, axis=1)
        return df

    def make_label(label):
        if label == 'MA':
            return 1
        elif label == 'GMA':
            return 2
        elif label == 'BOY':
            return 3
        elif label == 'FA':
            return 4
        elif label == 'GFA':
            return 5
        #elif label == 'GIRL':
        else:
            return 6

    def make_csv(folder_path):
        folder_list = os.listdir(folder_path)
        print(folder_list)

        result_df = pd.DataFrame(columns=['path', 'label'])
        #print('current path: ', folder_path)
        #print('current file list', os.listdir(folder_path))
        for folder in folder_list:
            file_list = glob(folder_path + '/' + folder + '/*png')

            for file in file_list:
                # print('folder: ', folder)
                # print('file: ', file)
                result_df = result_df.append(pd.DataFrame([(file, folder)], columns=['path', 'label']), ignore_index=True)
        # print(result_df.head())

        result_df['label'] = result_df['label'].apply(lambda x: make_label(x))
        result_df['label'] = result_df['label']-1
        #print(result_df.head())
        return result_df

    SEED = 42
    seed_everything(SEED)

    device = 'cuda'
    use_gpu = cuda.is_available()

    if use_gpu:
        print("enable gpu use")
    else:
        print("enable cpu for debugging")


    target_size = (128, 128)

    num_classes = 6
    model = models.densenet201(pretrained=False)
    model = models.vgg16(pretrained=False) 
    num_features = model.classifier[6].in_features # last layer's in_features
    features = list(model.classifier.children())[:-1] # Remove last layer
    features.extend([nn.Linear(num_features, 6)]) # Add our layer with 4 outputs
    model.classifier = nn.Sequential(*features) # Replace the model classifier

    #model = models.resnet50() 
    #model.fc = nn.Linear(2048, args.num_classes)

    # elif args.model == 'resnet18': 
    #     model = Resnet18(args.num_classes, dropout=False)
    # elif args.model == 'resnet50':
    #     model = Resnet50(args.num_classes, dropout=False)
    # elif args.model == 'efficient':
    #     model = EfficientNet.from_pretrained('efficientnet-b0')
    #     in_features = model._fc.in_features
    #     model._fc = nn.Linear(in_features, args.num_classes)
    # elif args.model == 'densenet201':
    #     model = models.densenet201(pretrained=True)
    #     model.classifier = nn.Linear(1920, args.num_classes)
    # elif args.model == 'resnext50':
    #     model = Resnext50(args.num_classes, dropout=False)
    # elif args.model == 'resnext101':
    #     model = Resnext101(args.num_classes, dropout=False)
    # elif args.model == 'mobilenet':
    #     assert args.input_size == 158
    #     model = torch.hub.load('pytorch/vision', 'mobilenet_v2', pretrained=True)
    #     model.classifier = nn.Sequential(nn.Dropout(0.2),
    #                         nn.Linear(1280, args.num_classes))
    # else:
    #     raise NotImplementedError

    if use_gpu:
        model = model.to(device)

    # optimizer = optim.Adam(model.parameters(), args.lr, weight_decay=0.00025)
    optimizer = AdamW(model.parameters(), 2.5e-4, weight_decay=0.000025)
    #optimizer = optim.SGD(model.parameters(), args.lr, momentum=0.9, weight_decay=0.025)

    ###### SCHEDULER #######
    scheduler = ReduceLROnPlateau(optimizer, 'max', patience=5, factor=0.5)

    #eta_min = 0.00001
    #T_max = 10
    #T_mult = 1
    #restart_decay = 0.97
    #scheduler = CosineAnnealingWithRestartsLR(optimizer, T_max=T_max, eta_min=eta_min, T_mult=T_mult, restart_decay=restart_decay)

    #scheduler = StepLR(optimizer, step_size=5, gamma=0.5)

    criterion = nn.CrossEntropyLoss() 

    num_parameters = count_parameters(model)
    print("==== number of parameters that can be trained: {}".format(num_parameters))

    folder_path = 'C:/SEOYILGUK/JOB_VISION/train/'
    IMAGE_PATH = folder_path + 'train_images/'
    df = make_csv(folder_path)
    print(df['label'].value_counts())

    # 5 stratifiedKFold
    folds = make_folds(df, 5)
    print("==== fold_df created")
    print(folds.head())

    train_df = folds[folds['fold'] != num_fold]
    valid_df = folds[folds['fold'] == num_fold]

    train_df = train_df[['path', 'label']].reset_index(drop=True)
    valid_df = valid_df[['path', 'label']].reset_index(drop=True)
    print("number of train images: {}".format(len(train_df)))
    print("number of valid images: {}".format(len(valid_df)))

    start_time = time.time()
    

    print("shape of the df: {}".format(df.shape))

    class Glass_Dataset(Dataset):
        def __init__(self, df, transform1=None, transform2=None):
            self.df = df
            self.transform1 = transform1
            self.transform2 = transform2

            self.image_list = []

            for path in self.df['path']:
                #print(path)
                image = cv2.imread(path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = Image.fromarray(image)
                image = self.transform1(image)
                self.image_list.append(image)

        def __len__(self):
            return len(self.df)

        def __getitem__(self, idx):

            # img_path = self.df.iloc[idx, 0]
            # print(img_path)
            # image = cv2.imread(img_path)
            # image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            # image = Image.fromarray(image)

            # if self.transform:
            #     image = self.transform(image)
            image = self.image_list[idx]

            if self.transform2:
                image = self.transform2(image)

            label = self.df['label'][idx]

            return image, label

    def make_loader(df, transforms1, transforms2, batch_size=256, num_workers=0):

        dataset = Glass_Dataset(df, transforms1, transforms2)
        # dataset = image, label from Glass_Dataset

        loader = DataLoader(dataset, # image, label
                            batch_size=batch_size,
                            shuffle=True, 
                            num_workers=num_workers, 
                            pin_memory=True)

        return loader

    train_augments = 'horizontal_flip, vertical_flip, Affine'
    augment_ratio = 0.5
    valid_augments = 'horizontal_flip, vertical_flip'
    transform1 = transforms.Compose([transforms.RandomRotation(180), transforms.ColorJitter()])
    #transforms2
    train_transforms = get_transform(target_size, 'horizontal_flip, vertical_flip, Affine', augment_ratio)
    valid_transforms = get_transform(target_size, 'horizontal_flip, vertical_flip', augment_ratio)


    train_loader = make_loader(train_df, transform1, train_transforms, batch_size=32 ,num_workers=0)
    valid_loader = make_loader(valid_df, transform1, valid_transforms, batch_size=32 ,num_workers=0)
    print("number train batches: {}".format(len(train_loader)))
    print("number valid batches: {}".format(len(valid_loader)))
    elapsed = time.time() - start_time
    print("elapsed: {:.0f}".format(elapsed))

    best_val_acc = 0
    grad_clip_step = 100
    grad_clip = 100
    step = 0
    # accumulation_step = 2

    print("start training")

    for epoch_idx in range(1, 100 + 1):

        start_time = time.time()

        train_loss = 0
        train_total_correct = 0
        model.train()
        optimizer.zero_grad()

        for batch_idx, (image, labels) in enumerate(train_loader):
            if use_gpu:
                image = image.to(device)
                labels = labels.to(device)

            # print("shape of the image: {}".format(image.shape))
            # print("shape of the labels: {}".format(labels.shape))
            # print(image)
            # print(labels)

            #if args.mixup_loss:
            #    inputs, targets_a, targets_b, lam = mixup_data(image, labels, alpha=0.4, device=device)
            #    inputs, targets_a, targets_b = map(Variable, (inputs, targets_a, targets_b))
            #    output = model(inputs)
            #    loss = mixup_criterion(criterion, output.to(device), targets_a.to(device), targets_b.to(device), lam)
            #else:
            output = model(image)
            loss = criterion(output, labels)

            # gradient explosion prevention
            if step > grad_clip_step:
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

            step += 1

            loss.backward()

            optimizer.step()
            optimizer.zero_grad()

            # output_prob = F.softmax(output, dim=1)

            train_loss += loss.item() / len(train_loader)


        model.eval()
        valid_loss = 0
        valid_total_correct = 0

        with torch.no_grad():
            for batch_idx, (image, labels) in enumerate(valid_loader):
                if use_gpu:
                    image = image.to(device)
                    labels = labels.to(device)


                output = model(image)
                loss = criterion(output, labels)

                output_prob = F.softmax(output, dim=1)

                predict_vector = np.argmax(to_numpy(output_prob), axis=1)
                label_vector = to_numpy(labels)
                bool_vector = predict_vector == label_vector
                #print('val_pred', predict_vector[:5])
                #print('val_label', label_vector[:5])
                #print("shape of prediction vector: {}".format(predict_vector.shape))
                #print(predict_vector.head())
                #print("shape of label vector: {}".format(label_vector.shape))

                valid_loss += loss.item() / len(valid_loader)
                valid_total_correct += bool_vector.sum()


        elapsed = time.time() - start_time

        val_acc = valid_total_correct / len(valid_loader.dataset)

        # best val_acc checkpoint
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            print("val_acc has improved !! ")
            torch.save(model.state_dict(), 'densenet201_fold_{}_best_model.pt'.format(num_fold))
            print("================ ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ".format(epoch_idx, best_val_acc))
            #file_save_name = 'best_acc' + '_' + str(num_fold)
            #print(file_save_name)
        else:
            print("val acc has not improved")

        lr = [_['lr'] for _ in optimizer.param_groups]

        #if args.scheduler == 'plateau':
        scheduler.step(val_acc)
        #else:
        #    scheduler.step()

        # nsml.save(epoch_idx)

        print("Epoch {}/{}  train_loss: {:.5f}  valid_loss {:.5f}  valid_acc: {:.5f}  lr: {:.6f}  elapsed: {:.0f}".format(
               epoch_idx, 100, train_loss, valid_loss, val_acc, lr[0], elapsed))
                #epoch_idx, args.epochs, train_loss, valid_loss, val_acc, lr[0], elapsed

    IMAGES_PATH = 'C:/SEOYILGUK/JOB_VISION/faces_images'
    test_df = pd.read_csv('C:/SEOYILGUK/JOB_VISION/test.csv')

    class TestDataset(Dataset):
        def __init__(self, df, transform=None):
            self.df = df
            self.transform = transform

        def __len__(self):
            return len(self.df)

        def __getitem__(self, idx):

            image = Image.open(IMAGES_PATH+'/'+self.df['filename'][idx]).convert('RGB')

            if self.transform:
                image = self.transform(image)

            return image

    batch_size = 1
    num_workers = 0

    # model = models.resnet18(pretrained=False) 
    # model.fc = nn.Linear(512, args.num_classes)

    # checkpoint = 'team012/KHD2019_FUNDUS/93'
    # nsml.load(checkpoint, load_fn=load)


    test_transforms = transforms.Compose([transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    test_dataset = TestDataset(test_df, test_transforms)
    test_loader = DataLoader(test_dataset,
                             batch_size=batch_size,
                             shuffle=False, 
                             num_workers=num_workers, 
                             pin_memory=True)
    print("============== ༼ つ ◕_◕ ༽つ BEST epoch : {}, Accuracy : {} ====================================".format(epoch_idx, best_val_acc))
    print("========================== ༼ つ ◕_◕ ༽つ Model Load {}_th FOLD =================================".format(num_fold))
    
    model.load_state_dict(torch.load('densenet201_fold_{}_best_model.pt'.format(num_fold)))

    model.eval()
    # for _ in range(tta):
        # print("tta {} predict".format(_+1))
    predictions = np.zeros((len(test_loader.dataset), 6))

    with torch.no_grad():
        for i, image in enumerate(test_loader):
            image = image.to(device)
            output = model(image) # output shape (batch_num, num_classes)

            predictions[i*batch_size: (i+1)*batch_size] = output.detach().cpu().numpy()
    print("predict values check : ",predictions[0])

    np.savetxt("../JOB_VISION/densenet201_submission/densenet201_{}_fold.csv".format(num_fold), predictions, delimiter=",")

    print("===============================================================================================")
    print("=================================༼ つ ◕_◕ ༽つ　 SAVED {}_th FOLD ༼ つ ◕_◕ ༽つ ==================".format(num_fold))
    print("===============================================================================================")
# Out:
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 134285126
# ['BOY', 'FA', 'GFA', 'GIRL', 'GMA', 'MA']
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7509.21it/s]
# ==== fold_df created
#                                                path  label  fold
# 0    C:/SEOYILGUK/JOB_VISION/train//BOY\face_10.png      2     1
# 1  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1007.png      2     2
# 2  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1019.png      2     3
# 3  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1024.png      2     4
# 4  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1026.png      2     0
# number of train images: 4678
# number of valid images: 1172
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 12
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43856655290102387
# Epoch 1/100  train_loss: 1.48065  valid_loss 1.42797  valid_acc: 0.43857  lr: 0.000250  elapsed: 39
# val acc has not improved
# Epoch 2/100  train_loss: 1.43076  valid_loss 1.41908  valid_acc: 0.43857  lr: 0.000250  elapsed: 37
# val acc has not improved
# Epoch 3/100  train_loss: 1.42715  valid_loss 1.40611  valid_acc: 0.43857  lr: 0.000250  elapsed: 37
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 4, Accuracy : 0.46245733788395904
# Epoch 4/100  train_loss: 1.41797  valid_loss 1.38185  valid_acc: 0.46246  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.4880546075085324
# Epoch 5/100  train_loss: 1.40356  valid_loss 1.34263  valid_acc: 0.48805  lr: 0.000250  elapsed: 37
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.5247440273037542
# Epoch 6/100  train_loss: 1.37221  valid_loss 1.26973  valid_acc: 0.52474  lr: 0.000250  elapsed: 37
# val acc has not improved
# Epoch 7/100  train_loss: 1.31317  valid_loss 1.27846  valid_acc: 0.41980  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 8/100  train_loss: 1.13401  valid_loss 1.12736  valid_acc: 0.52048  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.6194539249146758
# Epoch 9/100  train_loss: 1.01769  valid_loss 0.94802  valid_acc: 0.61945  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.6416382252559727
# Epoch 10/100  train_loss: 0.95502  valid_loss 0.94552  valid_acc: 0.64164  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 11, Accuracy : 0.658703071672355
# Epoch 11/100  train_loss: 0.92433  valid_loss 0.86705  valid_acc: 0.65870  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 12, Accuracy : 0.712457337883959
# Epoch 12/100  train_loss: 0.84881  valid_loss 0.80208  valid_acc: 0.71246  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 13/100  train_loss: 0.80176  valid_loss 0.81803  valid_acc: 0.70819  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 14, Accuracy : 0.7218430034129693
# Epoch 14/100  train_loss: 0.75819  valid_loss 0.71613  valid_acc: 0.72184  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 15, Accuracy : 0.7440273037542662
# Epoch 15/100  train_loss: 0.66475  valid_loss 0.76519  valid_acc: 0.74403  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 16, Accuracy : 0.757679180887372
# Epoch 16/100  train_loss: 0.65964  valid_loss 0.62547  valid_acc: 0.75768  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 17/100  train_loss: 0.56940  valid_loss 0.86872  valid_acc: 0.75256  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 18, Accuracy : 0.7841296928327645
# Epoch 18/100  train_loss: 0.55865  valid_loss 0.60285  valid_acc: 0.78413  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 19, Accuracy : 0.7952218430034129
# Epoch 19/100  train_loss: 0.52632  valid_loss 0.54989  valid_acc: 0.79522  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 20, Accuracy : 0.802901023890785
# Epoch 20/100  train_loss: 0.50220  valid_loss 0.54712  valid_acc: 0.80290  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 21/100  train_loss: 0.49331  valid_loss 0.55651  valid_acc: 0.78498  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 22, Accuracy : 0.8037542662116041
# Epoch 22/100  train_loss: 0.48355  valid_loss 0.54189  valid_acc: 0.80375  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 23, Accuracy : 0.8054607508532423
# Epoch 23/100  train_loss: 0.45195  valid_loss 0.50713  valid_acc: 0.80546  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 24/100  train_loss: 0.44440  valid_loss 0.56616  valid_acc: 0.80205  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 25, Accuracy : 0.818259385665529
# Epoch 25/100  train_loss: 0.42058  valid_loss 0.55877  valid_acc: 0.81826  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 26/100  train_loss: 0.41791  valid_loss 0.57590  valid_acc: 0.79608  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 27, Accuracy : 0.8250853242320819
# Epoch 27/100  train_loss: 0.40200  valid_loss 0.46421  valid_acc: 0.82509  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 28/100  train_loss: 0.39980  valid_loss 0.52792  valid_acc: 0.82253  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 29/100  train_loss: 0.38339  valid_loss 0.55554  valid_acc: 0.81741  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 30/100  train_loss: 0.39270  valid_loss 0.52554  valid_acc: 0.80973  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 31/100  train_loss: 0.36253  valid_loss 0.55891  valid_acc: 0.81826  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 32, Accuracy : 0.8284982935153583
# Epoch 32/100  train_loss: 0.35754  valid_loss 0.51402  valid_acc: 0.82850  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 33/100  train_loss: 0.36735  valid_loss 0.51399  valid_acc: 0.82167  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 34, Accuracy : 0.8310580204778157
# Epoch 34/100  train_loss: 0.32230  valid_loss 0.48763  valid_acc: 0.83106  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 35, Accuracy : 0.8361774744027304
# Epoch 35/100  train_loss: 0.33499  valid_loss 0.49503  valid_acc: 0.83618  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 36, Accuracy : 0.8430034129692833
# Epoch 36/100  train_loss: 0.33884  valid_loss 0.45245  valid_acc: 0.84300  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 37/100  train_loss: 0.33097  valid_loss 0.52227  valid_acc: 0.83618  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 38, Accuracy : 0.8464163822525598
# Epoch 38/100  train_loss: 0.34977  valid_loss 0.44194  valid_acc: 0.84642  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 39, Accuracy : 0.8472696245733788
# Epoch 39/100  train_loss: 0.30160  valid_loss 0.47366  valid_acc: 0.84727  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 40/100  train_loss: 0.29999  valid_loss 0.48126  valid_acc: 0.84215  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 41/100  train_loss: 0.30361  valid_loss 0.48112  valid_acc: 0.84215  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 42/100  train_loss: 0.28080  valid_loss 0.42817  valid_acc: 0.84642  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 43, Accuracy : 0.8506825938566553
# Epoch 43/100  train_loss: 0.28887  valid_loss 0.51746  valid_acc: 0.85068  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 44/100  train_loss: 0.28538  valid_loss 0.42006  valid_acc: 0.84812  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 45/100  train_loss: 0.29828  valid_loss 0.53154  valid_acc: 0.82765  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 46/100  train_loss: 0.31328  valid_loss 0.49070  valid_acc: 0.83362  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 47/100  train_loss: 0.28744  valid_loss 0.48418  valid_acc: 0.82935  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 48, Accuracy : 0.8668941979522184
# Epoch 48/100  train_loss: 0.28762  valid_loss 0.44507  valid_acc: 0.86689  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 49/100  train_loss: 0.28937  valid_loss 0.45120  valid_acc: 0.84898  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 50/100  train_loss: 0.27358  valid_loss 0.51022  valid_acc: 0.84642  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 51/100  train_loss: 0.27082  valid_loss 0.55326  valid_acc: 0.82935  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 52/100  train_loss: 0.25439  valid_loss 0.50912  valid_acc: 0.84044  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 53/100  train_loss: 0.23882  valid_loss 0.46656  valid_acc: 0.84556  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 54/100  train_loss: 0.26644  valid_loss 0.45923  valid_acc: 0.85239  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 55/100  train_loss: 0.22173  valid_loss 0.47704  valid_acc: 0.85922  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 56/100  train_loss: 0.21229  valid_loss 0.49261  valid_acc: 0.85495  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 57/100  train_loss: 0.21102  valid_loss 0.41712  valid_acc: 0.86348  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 58/100  train_loss: 0.19043  valid_loss 0.44377  valid_acc: 0.86519  lr: 0.000125  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 59, Accuracy : 0.8703071672354948
# Epoch 59/100  train_loss: 0.20450  valid_loss 0.45221  valid_acc: 0.87031  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 60/100  train_loss: 0.19612  valid_loss 0.46863  valid_acc: 0.85580  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 61/100  train_loss: 0.18410  valid_loss 0.47934  valid_acc: 0.86092  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 62/100  train_loss: 0.20558  valid_loss 0.41451  valid_acc: 0.86775  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 63/100  train_loss: 0.17034  valid_loss 0.46302  valid_acc: 0.86519  lr: 0.000125  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 64, Accuracy : 0.8762798634812287
# Epoch 64/100  train_loss: 0.19360  valid_loss 0.44564  valid_acc: 0.87628  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 65/100  train_loss: 0.19349  valid_loss 0.40352  valid_acc: 0.87372  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 66/100  train_loss: 0.19860  valid_loss 0.44739  valid_acc: 0.85580  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 67/100  train_loss: 0.18802  valid_loss 0.43722  valid_acc: 0.86092  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 68/100  train_loss: 0.18335  valid_loss 0.50689  valid_acc: 0.85410  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 69/100  train_loss: 0.19581  valid_loss 0.49607  valid_acc: 0.84471  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 70/100  train_loss: 0.18781  valid_loss 0.43831  valid_acc: 0.86689  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 71/100  train_loss: 0.17448  valid_loss 0.40795  valid_acc: 0.86945  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 72/100  train_loss: 0.15619  valid_loss 0.46039  valid_acc: 0.86945  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 73/100  train_loss: 0.14969  valid_loss 0.41308  valid_acc: 0.87287  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 74/100  train_loss: 0.17211  valid_loss 0.44559  valid_acc: 0.87201  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 75/100  train_loss: 0.16447  valid_loss 0.42167  valid_acc: 0.87628  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 76/100  train_loss: 0.16556  valid_loss 0.42336  valid_acc: 0.87457  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 77/100  train_loss: 0.14663  valid_loss 0.41518  valid_acc: 0.87201  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 78, Accuracy : 0.8831058020477816
# Epoch 78/100  train_loss: 0.15737  valid_loss 0.38795  valid_acc: 0.88311  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 79/100  train_loss: 0.14663  valid_loss 0.40853  valid_acc: 0.87713  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 80/100  train_loss: 0.14070  valid_loss 0.43995  valid_acc: 0.86263  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 81/100  train_loss: 0.15498  valid_loss 0.41826  valid_acc: 0.87116  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 82/100  train_loss: 0.15992  valid_loss 0.43837  valid_acc: 0.86604  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 83/100  train_loss: 0.13534  valid_loss 0.42748  valid_acc: 0.87969  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 84, Accuracy : 0.8873720136518771
# Epoch 84/100  train_loss: 0.14082  valid_loss 0.40290  valid_acc: 0.88737  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 85/100  train_loss: 0.14399  valid_loss 0.43755  valid_acc: 0.87713  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 86/100  train_loss: 0.12999  valid_loss 0.44217  valid_acc: 0.87543  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 87, Accuracy : 0.8924914675767918
# Epoch 87/100  train_loss: 0.13408  valid_loss 0.40872  valid_acc: 0.89249  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 88/100  train_loss: 0.13537  valid_loss 0.38550  valid_acc: 0.88055  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 89/100  train_loss: 0.12693  valid_loss 0.43368  valid_acc: 0.87201  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 90/100  train_loss: 0.14374  valid_loss 0.42640  valid_acc: 0.87969  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 91/100  train_loss: 0.14099  valid_loss 0.44984  valid_acc: 0.86519  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 92/100  train_loss: 0.14006  valid_loss 0.39032  valid_acc: 0.88652  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 93/100  train_loss: 0.13448  valid_loss 0.40876  valid_acc: 0.88737  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 94/100  train_loss: 0.11769  valid_loss 0.45719  valid_acc: 0.86945  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 95/100  train_loss: 0.12486  valid_loss 0.42096  valid_acc: 0.87799  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 96/100  train_loss: 0.12853  valid_loss 0.42121  valid_acc: 0.88567  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 97/100  train_loss: 0.13946  valid_loss 0.40492  valid_acc: 0.87713  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 98/100  train_loss: 0.13027  valid_loss 0.41313  valid_acc: 0.87713  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 99/100  train_loss: 0.13357  valid_loss 0.41256  valid_acc: 0.88225  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 100/100  train_loss: 0.13410  valid_loss 0.40187  valid_acc: 0.88567  lr: 0.000008  elapsed: 38
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8924914675767918 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 0_th FOLD =================================
# predict values check :  [  6.56731081  -3.60816407  -5.76295662  -3.33221412 -11.59692478
#  -12.93335438]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 0_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 134285126
# ['BOY', 'FA', 'GFA', 'GIRL', 'GMA', 'MA']
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7480.41it/s]
# ==== fold_df created
#                                                path  label  fold
# 0    C:/SEOYILGUK/JOB_VISION/train//BOY\face_10.png      2     1
# 1  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1007.png      2     2
# 2  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1019.png      2     3
# 3  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1024.png      2     4
# 4  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1026.png      2     0
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 7
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43894107600341586
# Epoch 1/100  train_loss: 1.47965  valid_loss 1.43397  valid_acc: 0.43894  lr: 0.000250  elapsed: 37
# val acc has not improved
# Epoch 2/100  train_loss: 1.42437  valid_loss 1.41743  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 3/100  train_loss: 1.42030  valid_loss 1.46870  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 4/100  train_loss: 1.44748  valid_loss 1.43910  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 5/100  train_loss: 1.43872  valid_loss 1.43503  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 6/100  train_loss: 1.43693  valid_loss 1.42859  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 7/100  train_loss: 1.43638  valid_loss 1.42088  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 8/100  train_loss: 1.43441  valid_loss 1.45575  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 9/100  train_loss: 1.43047  valid_loss 1.43243  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 10/100  train_loss: 1.43692  valid_loss 1.43031  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 11/100  train_loss: 1.43211  valid_loss 1.42889  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 12/100  train_loss: 1.43398  valid_loss 1.42594  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 13/100  train_loss: 1.43468  valid_loss 1.43574  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 14/100  train_loss: 1.43187  valid_loss 1.42641  valid_acc: 0.43894  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 15, Accuracy : 0.43979504696840305
# Epoch 15/100  train_loss: 1.42803  valid_loss 1.40204  valid_acc: 0.43980  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 16/100  train_loss: 1.40430  valid_loss 1.39340  valid_acc: 0.43980  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.46797608881298036
# Epoch 17/100  train_loss: 1.35554  valid_loss 1.31466  valid_acc: 0.46798  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 18, Accuracy : 0.4935952177625961
# Epoch 18/100  train_loss: 1.26072  valid_loss 1.18913  valid_acc: 0.49360  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 19, Accuracy : 0.5431255337318531
# Epoch 19/100  train_loss: 1.14898  valid_loss 1.08060  valid_acc: 0.54313  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 20/100  train_loss: 1.08588  valid_loss 1.08367  valid_acc: 0.53715  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 21, Accuracy : 0.5935098206660974
# Epoch 21/100  train_loss: 1.02241  valid_loss 0.99698  valid_acc: 0.59351  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 22/100  train_loss: 0.98134  valid_loss 0.96147  valid_acc: 0.56106  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 23, Accuracy : 0.6404782237403929
# Epoch 23/100  train_loss: 0.88485  valid_loss 0.82578  valid_acc: 0.64048  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 24, Accuracy : 0.6746370623398804
# Epoch 24/100  train_loss: 0.80960  valid_loss 0.81410  valid_acc: 0.67464  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 25/100  train_loss: 0.74750  valid_loss 0.83260  valid_acc: 0.66524  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 26, Accuracy : 0.7275832621690862
# Epoch 26/100  train_loss: 0.71350  valid_loss 0.68624  valid_acc: 0.72758  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 27, Accuracy : 0.7472245943637916
# Epoch 27/100  train_loss: 0.66211  valid_loss 0.65003  valid_acc: 0.74722  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 28, Accuracy : 0.7514944491887275
# Epoch 28/100  train_loss: 0.61221  valid_loss 0.62108  valid_acc: 0.75149  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 29/100  train_loss: 0.60334  valid_loss 0.64881  valid_acc: 0.74381  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 30/100  train_loss: 0.57680  valid_loss 0.65530  valid_acc: 0.73954  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 31, Accuracy : 0.7941929974380871
# Epoch 31/100  train_loss: 0.53814  valid_loss 0.56790  valid_acc: 0.79419  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 32/100  train_loss: 0.51756  valid_loss 0.53912  valid_acc: 0.78992  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 33/100  train_loss: 0.50214  valid_loss 0.57720  valid_acc: 0.77882  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 34, Accuracy : 0.798462852263023
# Epoch 34/100  train_loss: 0.50315  valid_loss 0.56043  valid_acc: 0.79846  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 35, Accuracy : 0.8010247651579846
# Epoch 35/100  train_loss: 0.47539  valid_loss 0.53956  valid_acc: 0.80102  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 36, Accuracy : 0.8129803586678053
# Epoch 36/100  train_loss: 0.45576  valid_loss 0.53084  valid_acc: 0.81298  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 37, Accuracy : 0.8189581554227157
# Epoch 37/100  train_loss: 0.44040  valid_loss 0.50973  valid_acc: 0.81896  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 38, Accuracy : 0.8215200683176772
# Epoch 38/100  train_loss: 0.42664  valid_loss 0.53179  valid_acc: 0.82152  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 39/100  train_loss: 0.43670  valid_loss 0.51126  valid_acc: 0.81127  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 40, Accuracy : 0.8232280102476516
# Epoch 40/100  train_loss: 0.39456  valid_loss 0.50495  valid_acc: 0.82323  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 41/100  train_loss: 0.38263  valid_loss 0.55185  valid_acc: 0.80102  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 42/100  train_loss: 0.41191  valid_loss 0.64764  valid_acc: 0.78651  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 43, Accuracy : 0.8351836037574722
# Epoch 43/100  train_loss: 0.39533  valid_loss 0.46868  valid_acc: 0.83518  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 44/100  train_loss: 0.38106  valid_loss 0.49903  valid_acc: 0.82664  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 45/100  train_loss: 0.39556  valid_loss 0.51271  valid_acc: 0.81896  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 46, Accuracy : 0.842869342442357
# Epoch 46/100  train_loss: 0.38451  valid_loss 0.45535  valid_acc: 0.84287  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 47/100  train_loss: 0.35197  valid_loss 0.61147  valid_acc: 0.80188  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 48/100  train_loss: 0.36003  valid_loss 0.50208  valid_acc: 0.82237  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 49/100  train_loss: 0.34955  valid_loss 0.50982  valid_acc: 0.82664  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 50/100  train_loss: 0.33938  valid_loss 0.52645  valid_acc: 0.82067  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 51/100  train_loss: 0.34266  valid_loss 0.47876  valid_acc: 0.83775  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 52/100  train_loss: 0.33120  valid_loss 0.57802  valid_acc: 0.83091  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 53/100  train_loss: 0.28459  valid_loss 0.58479  valid_acc: 0.81213  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 54, Accuracy : 0.8539709649871904
# Epoch 54/100  train_loss: 0.27585  valid_loss 0.45511  valid_acc: 0.85397  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 55/100  train_loss: 0.27989  valid_loss 0.49018  valid_acc: 0.84458  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 56/100  train_loss: 0.26303  valid_loss 0.44699  valid_acc: 0.84799  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 57/100  train_loss: 0.26908  valid_loss 0.46372  valid_acc: 0.85226  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 58/100  train_loss: 0.27126  valid_loss 0.48544  valid_acc: 0.83689  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 59/100  train_loss: 0.27389  valid_loss 0.50800  valid_acc: 0.84458  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 60/100  train_loss: 0.26391  valid_loss 0.49791  valid_acc: 0.84287  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 61/100  train_loss: 0.23269  valid_loss 0.48234  valid_acc: 0.84970  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 62/100  train_loss: 0.22449  valid_loss 0.47325  valid_acc: 0.84885  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 63/100  train_loss: 0.21865  valid_loss 0.48201  valid_acc: 0.84799  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 64/100  train_loss: 0.21121  valid_loss 0.52236  valid_acc: 0.84372  lr: 0.000016  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 65, Accuracy : 0.8599487617421008
# Epoch 65/100  train_loss: 0.21811  valid_loss 0.44886  valid_acc: 0.85995  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 66/100  train_loss: 0.21998  valid_loss 0.52988  valid_acc: 0.84885  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 67/100  train_loss: 0.20812  valid_loss 0.47389  valid_acc: 0.85141  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 68/100  train_loss: 0.22893  valid_loss 0.48651  valid_acc: 0.84799  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 69/100  train_loss: 0.22684  valid_loss 0.50710  valid_acc: 0.85482  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 70/100  train_loss: 0.20802  valid_loss 0.50634  valid_acc: 0.84714  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 71/100  train_loss: 0.22158  valid_loss 0.43136  valid_acc: 0.85653  lr: 0.000016  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 72, Accuracy : 0.8633646456020495
# Epoch 72/100  train_loss: 0.20869  valid_loss 0.43808  valid_acc: 0.86336  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 73/100  train_loss: 0.21127  valid_loss 0.46736  valid_acc: 0.86251  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 74/100  train_loss: 0.18834  valid_loss 0.46854  valid_acc: 0.86166  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 75/100  train_loss: 0.19927  valid_loss 0.49685  valid_acc: 0.84970  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 76/100  train_loss: 0.20465  valid_loss 0.46931  valid_acc: 0.86166  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 77/100  train_loss: 0.20882  valid_loss 0.46081  valid_acc: 0.85995  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 78/100  train_loss: 0.20735  valid_loss 0.48222  valid_acc: 0.84372  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 79/100  train_loss: 0.19633  valid_loss 0.46011  valid_acc: 0.85312  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 80/100  train_loss: 0.18901  valid_loss 0.48049  valid_acc: 0.85568  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 81/100  train_loss: 0.19053  valid_loss 0.48265  valid_acc: 0.85568  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 82/100  train_loss: 0.19628  valid_loss 0.47153  valid_acc: 0.85739  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 83/100  train_loss: 0.18164  valid_loss 0.48747  valid_acc: 0.85056  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 84/100  train_loss: 0.19426  valid_loss 0.45622  valid_acc: 0.85995  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 85/100  train_loss: 0.19367  valid_loss 0.45828  valid_acc: 0.85909  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 86/100  train_loss: 0.19347  valid_loss 0.45110  valid_acc: 0.85653  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 87/100  train_loss: 0.18987  valid_loss 0.47048  valid_acc: 0.85312  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 88/100  train_loss: 0.18182  valid_loss 0.46992  valid_acc: 0.85909  lr: 0.000002  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 89, Accuracy : 0.8642186165670367
# Epoch 89/100  train_loss: 0.19441  valid_loss 0.45802  valid_acc: 0.86422  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 90/100  train_loss: 0.18609  valid_loss 0.46868  valid_acc: 0.86166  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 91/100  train_loss: 0.19602  valid_loss 0.46844  valid_acc: 0.85568  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 92/100  train_loss: 0.19491  valid_loss 0.46203  valid_acc: 0.85653  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 93/100  train_loss: 0.19383  valid_loss 0.46323  valid_acc: 0.85482  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 94/100  train_loss: 0.18264  valid_loss 0.48103  valid_acc: 0.85995  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 95/100  train_loss: 0.20003  valid_loss 0.46448  valid_acc: 0.86251  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 96/100  train_loss: 0.19357  valid_loss 0.45752  valid_acc: 0.85995  lr: 0.000001  elapsed: 38
# val acc has not improved
# Epoch 97/100  train_loss: 0.19728  valid_loss 0.45297  valid_acc: 0.85568  lr: 0.000001  elapsed: 38
# val acc has not improved
# Epoch 98/100  train_loss: 0.19500  valid_loss 0.43868  valid_acc: 0.86251  lr: 0.000001  elapsed: 38
# val acc has not improved
# Epoch 99/100  train_loss: 0.19969  valid_loss 0.43574  valid_acc: 0.85909  lr: 0.000001  elapsed: 38
# val acc has not improved
# Epoch 100/100  train_loss: 0.19585  valid_loss 0.43250  valid_acc: 0.86251  lr: 0.000001  elapsed: 38
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8642186165670367 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 1_th FOLD =================================
# predict values check :  [ 5.50798321 -1.26643598 -2.41059995 -0.48439038 -7.5970006  -6.90695429]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 1_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 STARTS 2_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
# enable gpu use
# ==== number of parameters that can be trained: 134285126
# ['BOY', 'FA', 'GFA', 'GIRL', 'GMA', 'MA']
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7489.97it/s]
# ==== fold_df created
#                                                path  label  fold
# 0    C:/SEOYILGUK/JOB_VISION/train//BOY\face_10.png      2     1
# 1  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1007.png      2     2
# 2  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1019.png      2     3
# 3  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1024.png      2     4
# 4  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1026.png      2     0
# number of train images: 4679
# number of valid images: 1171
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 7
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43894107600341586
# Epoch 1/100  train_loss: 1.48214  valid_loss 1.43456  valid_acc: 0.43894  lr: 0.000250  elapsed: 37
# val acc has not improved
# Epoch 2/100  train_loss: 1.43678  valid_loss 1.42956  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 3/100  train_loss: 1.44114  valid_loss 1.43316  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 4/100  train_loss: 1.43464  valid_loss 1.43290  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 5/100  train_loss: 1.43816  valid_loss 1.43483  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 6/100  train_loss: 1.43791  valid_loss 1.42851  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 7/100  train_loss: 1.43689  valid_loss 1.43085  valid_acc: 0.43894  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 8/100  train_loss: 1.43059  valid_loss 1.43118  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 9/100  train_loss: 1.42846  valid_loss 1.43261  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 10/100  train_loss: 1.43616  valid_loss 1.43010  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 11/100  train_loss: 1.43174  valid_loss 1.42899  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 12/100  train_loss: 1.43369  valid_loss 1.42567  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 13/100  train_loss: 1.43503  valid_loss 1.43560  valid_acc: 0.43894  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 14/100  train_loss: 1.43273  valid_loss 1.42638  valid_acc: 0.43894  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 15/100  train_loss: 1.43229  valid_loss 1.42454  valid_acc: 0.43894  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 16/100  train_loss: 1.43037  valid_loss 1.42099  valid_acc: 0.43894  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 17/100  train_loss: 1.41752  valid_loss 1.41347  valid_acc: 0.43894  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 18, Accuracy : 0.4568744662681469
# Epoch 18/100  train_loss: 1.38875  valid_loss 1.39702  valid_acc: 0.45687  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 19, Accuracy : 0.4850555081127242
# Epoch 19/100  train_loss: 1.37545  valid_loss 1.37026  valid_acc: 0.48506  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 20/100  train_loss: 1.35781  valid_loss 1.35271  valid_acc: 0.46114  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 21, Accuracy : 0.5234842015371477
# Epoch 21/100  train_loss: 1.31763  valid_loss 1.28439  valid_acc: 0.52348  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 22, Accuracy : 0.547395388556789
# Epoch 22/100  train_loss: 1.26664  valid_loss 1.25182  valid_acc: 0.54740  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 23/100  train_loss: 1.22692  valid_loss 1.18886  valid_acc: 0.54398  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 24, Accuracy : 0.5883859948761742
# Epoch 24/100  train_loss: 1.19542  valid_loss 1.13930  valid_acc: 0.58839  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 25, Accuracy : 0.6157130657557643
# Epoch 25/100  train_loss: 1.07296  valid_loss 1.00642  valid_acc: 0.61571  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 26, Accuracy : 0.6404782237403929
# Epoch 26/100  train_loss: 0.98747  valid_loss 0.95040  valid_acc: 0.64048  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 27, Accuracy : 0.6754910333048676
# Epoch 27/100  train_loss: 0.91419  valid_loss 0.85673  valid_acc: 0.67549  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 28/100  train_loss: 0.84444  valid_loss 0.89670  valid_acc: 0.65329  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 29, Accuracy : 0.7233134073441503
# Epoch 29/100  train_loss: 0.79200  valid_loss 0.74621  valid_acc: 0.72331  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 30, Accuracy : 0.7438087105038429
# Epoch 30/100  train_loss: 0.70741  valid_loss 0.68845  valid_acc: 0.74381  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 31, Accuracy : 0.7583262169086251
# Epoch 31/100  train_loss: 0.65858  valid_loss 0.61769  valid_acc: 0.75833  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 32, Accuracy : 0.7677198975234842
# Epoch 32/100  train_loss: 0.60193  valid_loss 0.64137  valid_acc: 0.76772  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 33/100  train_loss: 0.56548  valid_loss 0.68179  valid_acc: 0.74039  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 34, Accuracy : 0.7873612297181896
# Epoch 34/100  train_loss: 0.56434  valid_loss 0.57900  valid_acc: 0.78736  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 35, Accuracy : 0.7924850555081128
# Epoch 35/100  train_loss: 0.52170  valid_loss 0.58135  valid_acc: 0.79249  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 36, Accuracy : 0.7950469684030743
# Epoch 36/100  train_loss: 0.49762  valid_loss 0.58732  valid_acc: 0.79505  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 37/100  train_loss: 0.47230  valid_loss 0.57239  valid_acc: 0.79163  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 38, Accuracy : 0.8146883005977796
# Epoch 38/100  train_loss: 0.45663  valid_loss 0.55151  valid_acc: 0.81469  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 39, Accuracy : 0.829205807002562
# Epoch 39/100  train_loss: 0.41869  valid_loss 0.48868  valid_acc: 0.82921  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 40/100  train_loss: 0.41004  valid_loss 0.57885  valid_acc: 0.78822  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 41/100  train_loss: 0.41117  valid_loss 0.50401  valid_acc: 0.81640  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 42/100  train_loss: 0.39281  valid_loss 0.61638  valid_acc: 0.78309  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 43/100  train_loss: 0.37667  valid_loss 0.52572  valid_acc: 0.81469  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 44/100  train_loss: 0.37768  valid_loss 0.52116  valid_acc: 0.80700  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 45/100  train_loss: 0.34467  valid_loss 0.54762  valid_acc: 0.81554  lr: 0.000063  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 46, Accuracy : 0.8309137489325363
# Epoch 46/100  train_loss: 0.31722  valid_loss 0.45803  valid_acc: 0.83091  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 47, Accuracy : 0.838599487617421
# Epoch 47/100  train_loss: 0.30348  valid_loss 0.45709  valid_acc: 0.83860  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 48/100  train_loss: 0.28655  valid_loss 0.46553  valid_acc: 0.82067  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 49, Accuracy : 0.8479931682322801
# Epoch 49/100  train_loss: 0.29295  valid_loss 0.46346  valid_acc: 0.84799  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 50/100  train_loss: 0.28169  valid_loss 0.48276  valid_acc: 0.84287  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 51/100  train_loss: 0.27317  valid_loss 0.46028  valid_acc: 0.83091  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 52, Accuracy : 0.8497011101622545
# Epoch 52/100  train_loss: 0.27200  valid_loss 0.43645  valid_acc: 0.84970  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 53/100  train_loss: 0.26217  valid_loss 0.52055  valid_acc: 0.83945  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 54/100  train_loss: 0.25863  valid_loss 0.46078  valid_acc: 0.84458  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 55/100  train_loss: 0.26199  valid_loss 0.46882  valid_acc: 0.84202  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 56/100  train_loss: 0.24412  valid_loss 0.46874  valid_acc: 0.84629  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 57/100  train_loss: 0.25212  valid_loss 0.46824  valid_acc: 0.84970  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 58/100  train_loss: 0.25059  valid_loss 0.45527  valid_acc: 0.83604  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 59, Accuracy : 0.8548249359521777
# Epoch 59/100  train_loss: 0.23950  valid_loss 0.45624  valid_acc: 0.85482  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 60/100  train_loss: 0.21652  valid_loss 0.45967  valid_acc: 0.84799  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 61/100  train_loss: 0.21580  valid_loss 0.47223  valid_acc: 0.85056  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 62/100  train_loss: 0.20022  valid_loss 0.47979  valid_acc: 0.84799  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 63/100  train_loss: 0.21343  valid_loss 0.47963  valid_acc: 0.84372  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 64/100  train_loss: 0.21789  valid_loss 0.45714  valid_acc: 0.85482  lr: 0.000016  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 65, Accuracy : 0.8599487617421008
# Epoch 65/100  train_loss: 0.20728  valid_loss 0.46207  valid_acc: 0.85995  lr: 0.000016  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 66, Accuracy : 0.8676345004269855
# Epoch 66/100  train_loss: 0.21189  valid_loss 0.45010  valid_acc: 0.86763  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 67/100  train_loss: 0.20391  valid_loss 0.44294  valid_acc: 0.85909  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 68/100  train_loss: 0.20721  valid_loss 0.47486  valid_acc: 0.86251  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 69/100  train_loss: 0.19788  valid_loss 0.50853  valid_acc: 0.85568  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 70/100  train_loss: 0.19056  valid_loss 0.48280  valid_acc: 0.85226  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 71/100  train_loss: 0.20594  valid_loss 0.45088  valid_acc: 0.85312  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 72/100  train_loss: 0.18796  valid_loss 0.47736  valid_acc: 0.85653  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 73/100  train_loss: 0.19410  valid_loss 0.43398  valid_acc: 0.86251  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 74/100  train_loss: 0.19657  valid_loss 0.45035  valid_acc: 0.85653  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 75/100  train_loss: 0.19178  valid_loss 0.47353  valid_acc: 0.85568  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 76/100  train_loss: 0.18408  valid_loss 0.46005  valid_acc: 0.85909  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 77/100  train_loss: 0.19191  valid_loss 0.43056  valid_acc: 0.86422  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 78/100  train_loss: 0.17963  valid_loss 0.43842  valid_acc: 0.86593  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 79/100  train_loss: 0.16789  valid_loss 0.43886  valid_acc: 0.86593  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 80/100  train_loss: 0.17371  valid_loss 0.46164  valid_acc: 0.85995  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 81/100  train_loss: 0.17780  valid_loss 0.44474  valid_acc: 0.84543  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 82/100  train_loss: 0.19297  valid_loss 0.43324  valid_acc: 0.86422  lr: 0.000004  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 83, Accuracy : 0.8710503842869343
# Epoch 83/100  train_loss: 0.18214  valid_loss 0.41644  valid_acc: 0.87105  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 84/100  train_loss: 0.18569  valid_loss 0.44089  valid_acc: 0.86336  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 85/100  train_loss: 0.17881  valid_loss 0.41613  valid_acc: 0.86934  lr: 0.000004  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 86, Accuracy : 0.874466268146883
# Epoch 86/100  train_loss: 0.17316  valid_loss 0.42775  valid_acc: 0.87447  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 87/100  train_loss: 0.18104  valid_loss 0.39959  valid_acc: 0.86678  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 88/100  train_loss: 0.17288  valid_loss 0.45156  valid_acc: 0.86934  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 89/100  train_loss: 0.17419  valid_loss 0.43256  valid_acc: 0.86422  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 90/100  train_loss: 0.18190  valid_loss 0.44816  valid_acc: 0.86763  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 91/100  train_loss: 0.18697  valid_loss 0.44637  valid_acc: 0.86251  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 92/100  train_loss: 0.17758  valid_loss 0.42042  valid_acc: 0.86849  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 93/100  train_loss: 0.17782  valid_loss 0.42702  valid_acc: 0.86763  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 94/100  train_loss: 0.18115  valid_loss 0.41808  valid_acc: 0.86507  lr: 0.000002  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 95, Accuracy : 0.8812980358667806
# Epoch 95/100  train_loss: 0.18278  valid_loss 0.40290  valid_acc: 0.88130  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 96/100  train_loss: 0.16963  valid_loss 0.42253  valid_acc: 0.86678  lr: 0.000002  elapsed: 38
# ...
# ['BOY', 'FA', 'GFA', 'GIRL', 'GMA', 'MA']
# 3    2568
# 0    1723
# 1     601
# 4     374
# 5     354
# 2     230
# Name: label, dtype: int64
# 5851it [00:00, 7470.85it/s]
# ==== fold_df created
#                                                path  label  fold
# 0    C:/SEOYILGUK/JOB_VISION/train//BOY\face_10.png      2     1
# 1  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1007.png      2     2
# 2  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1019.png      2     3
# 3  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1024.png      2     4
# 4  C:/SEOYILGUK/JOB_VISION/train//BOY\face_1026.png      2     0
# number of train images: 4683
# number of valid images: 1167
# shape of the df: (5850, 3)
# number train batches: 147
# number valid batches: 37
# elapsed: 7
# start training
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 1, Accuracy : 0.43958868894601544
# Epoch 1/100  train_loss: 1.45814  valid_loss 1.62656  valid_acc: 0.43959  lr: 0.000250  elapsed: 37
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 2, Accuracy : 0.44044558697514996
# Epoch 2/100  train_loss: 1.43475  valid_loss 1.39540  valid_acc: 0.44045  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 3, Accuracy : 0.47386461011139674
# Epoch 3/100  train_loss: 1.39840  valid_loss 1.38639  valid_acc: 0.47386  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 4/100  train_loss: 1.37957  valid_loss 1.37937  valid_acc: 0.46958  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 5, Accuracy : 0.4772922022279349
# Epoch 5/100  train_loss: 1.35675  valid_loss 1.35564  valid_acc: 0.47729  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 6, Accuracy : 0.5132819194515853
# Epoch 6/100  train_loss: 1.33820  valid_loss 1.25010  valid_acc: 0.51328  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 7, Accuracy : 0.5604113110539846
# Epoch 7/100  train_loss: 1.19245  valid_loss 1.08397  valid_acc: 0.56041  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 8, Accuracy : 0.5886889460154242
# Epoch 8/100  train_loss: 1.09337  valid_loss 1.00720  valid_acc: 0.58869  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 9, Accuracy : 0.6135389888603257
# Epoch 9/100  train_loss: 0.99329  valid_loss 0.98826  valid_acc: 0.61354  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 10, Accuracy : 0.6709511568123393
# Epoch 10/100  train_loss: 0.92986  valid_loss 0.84649  valid_acc: 0.67095  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 11, Accuracy : 0.7052270779777207
# Epoch 11/100  train_loss: 0.89230  valid_loss 0.77512  valid_acc: 0.70523  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 12/100  train_loss: 0.81271  valid_loss 0.84642  valid_acc: 0.69237  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 13, Accuracy : 0.7446443873179092
# Epoch 13/100  train_loss: 0.78914  valid_loss 0.69111  valid_acc: 0.74464  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 14, Accuracy : 0.7643530419880035
# Epoch 14/100  train_loss: 0.72296  valid_loss 0.63855  valid_acc: 0.76435  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 15, Accuracy : 0.7720651242502142
# Epoch 15/100  train_loss: 0.67087  valid_loss 0.58033  valid_acc: 0.77207  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 16, Accuracy : 0.7849185946872322
# Epoch 16/100  train_loss: 0.60400  valid_loss 0.55617  valid_acc: 0.78492  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 17, Accuracy : 0.7952013710368466
# Epoch 17/100  train_loss: 0.58631  valid_loss 0.55453  valid_acc: 0.79520  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 18/100  train_loss: 0.54026  valid_loss 0.62911  valid_acc: 0.76521  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 19/100  train_loss: 0.52104  valid_loss 0.58453  valid_acc: 0.78920  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 20, Accuracy : 0.8029134532990574
# Epoch 20/100  train_loss: 0.48960  valid_loss 0.49389  valid_acc: 0.80291  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 21/100  train_loss: 0.47649  valid_loss 0.67352  valid_acc: 0.78663  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 22/100  train_loss: 0.49264  valid_loss 0.54305  valid_acc: 0.79606  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 23, Accuracy : 0.8277634961439588
# Epoch 23/100  train_loss: 0.44578  valid_loss 0.48218  valid_acc: 0.82776  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 24/100  train_loss: 0.43374  valid_loss 0.47717  valid_acc: 0.82091  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 25/100  train_loss: 0.42793  valid_loss 0.49262  valid_acc: 0.80977  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 26/100  train_loss: 0.41094  valid_loss 0.54921  valid_acc: 0.81491  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 27/100  train_loss: 0.39593  valid_loss 0.46674  valid_acc: 0.82519  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 28, Accuracy : 0.8320479862896315
# Epoch 28/100  train_loss: 0.37087  valid_loss 0.48941  valid_acc: 0.83205  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 29, Accuracy : 0.8457583547557841
# Epoch 29/100  train_loss: 0.38690  valid_loss 0.45558  valid_acc: 0.84576  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 30/100  train_loss: 0.35750  valid_loss 0.48086  valid_acc: 0.82262  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 31/100  train_loss: 0.38262  valid_loss 0.43970  valid_acc: 0.84404  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 32/100  train_loss: 0.33858  valid_loss 0.50536  valid_acc: 0.83033  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 33/100  train_loss: 0.35725  valid_loss 0.44888  valid_acc: 0.83976  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 34/100  train_loss: 0.33526  valid_loss 0.46586  valid_acc: 0.83548  lr: 0.000250  elapsed: 38
# val acc has not improved
# Epoch 35/100  train_loss: 0.32398  valid_loss 0.43754  valid_acc: 0.83976  lr: 0.000250  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 36, Accuracy : 0.8534704370179949
# Epoch 36/100  train_loss: 0.28869  valid_loss 0.43650  valid_acc: 0.85347  lr: 0.000125  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 37, Accuracy : 0.856898029134533
# Epoch 37/100  train_loss: 0.27001  valid_loss 0.46623  valid_acc: 0.85690  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 38/100  train_loss: 0.25637  valid_loss 0.49389  valid_acc: 0.83033  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 39/100  train_loss: 0.25162  valid_loss 0.44452  valid_acc: 0.84404  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 40/100  train_loss: 0.24831  valid_loss 0.43495  valid_acc: 0.85518  lr: 0.000125  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 41, Accuracy : 0.8688946015424165
# Epoch 41/100  train_loss: 0.25561  valid_loss 0.41658  valid_acc: 0.86889  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 42/100  train_loss: 0.24853  valid_loss 0.40127  valid_acc: 0.85690  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 43/100  train_loss: 0.23176  valid_loss 0.46057  valid_acc: 0.85090  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 44/100  train_loss: 0.22850  valid_loss 0.46230  valid_acc: 0.85861  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 45/100  train_loss: 0.24458  valid_loss 0.45875  valid_acc: 0.85090  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 46/100  train_loss: 0.24476  valid_loss 0.41975  valid_acc: 0.85261  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 47/100  train_loss: 0.22857  valid_loss 0.42397  valid_acc: 0.85090  lr: 0.000125  elapsed: 38
# val acc has not improved
# Epoch 48/100  train_loss: 0.21619  valid_loss 0.40422  valid_acc: 0.85947  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 49/100  train_loss: 0.19425  valid_loss 0.40361  valid_acc: 0.86118  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 50/100  train_loss: 0.20262  valid_loss 0.38094  valid_acc: 0.86461  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 51/100  train_loss: 0.19474  valid_loss 0.40345  valid_acc: 0.86290  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 52/100  train_loss: 0.17965  valid_loss 0.46641  valid_acc: 0.86290  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 53/100  train_loss: 0.17359  valid_loss 0.43980  valid_acc: 0.86632  lr: 0.000063  elapsed: 38
# val acc has not improved
# Epoch 54/100  train_loss: 0.18258  valid_loss 0.41592  valid_acc: 0.86204  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 55/100  train_loss: 0.17467  valid_loss 0.42234  valid_acc: 0.86033  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 56, Accuracy : 0.8757497857754927
# Epoch 56/100  train_loss: 0.17383  valid_loss 0.38727  valid_acc: 0.87575  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 57/100  train_loss: 0.18492  valid_loss 0.40518  valid_acc: 0.87232  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 58/100  train_loss: 0.17729  valid_loss 0.41094  valid_acc: 0.86889  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 59/100  train_loss: 0.18057  valid_loss 0.39093  valid_acc: 0.87147  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 60, Accuracy : 0.8783204798628963
# Epoch 60/100  train_loss: 0.16117  valid_loss 0.41318  valid_acc: 0.87832  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 61/100  train_loss: 0.15752  valid_loss 0.42668  valid_acc: 0.86804  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 62, Accuracy : 0.8800342759211653
# Epoch 62/100  train_loss: 0.16468  valid_loss 0.41460  valid_acc: 0.88003  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 63/100  train_loss: 0.17863  valid_loss 0.38905  valid_acc: 0.87489  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 64/100  train_loss: 0.17125  valid_loss 0.39859  valid_acc: 0.87404  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 65/100  train_loss: 0.15953  valid_loss 0.40925  valid_acc: 0.87575  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 66/100  train_loss: 0.18186  valid_loss 0.37987  valid_acc: 0.87746  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 67/100  train_loss: 0.17280  valid_loss 0.39494  valid_acc: 0.86975  lr: 0.000031  elapsed: 38
# val acc has not improved
# Epoch 68/100  train_loss: 0.16652  valid_loss 0.40344  valid_acc: 0.87318  lr: 0.000031  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 69, Accuracy : 0.882604970008569
# Epoch 69/100  train_loss: 0.16732  valid_loss 0.37233  valid_acc: 0.88260  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 70/100  train_loss: 0.16352  valid_loss 0.37675  valid_acc: 0.87746  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 71/100  train_loss: 0.14869  valid_loss 0.39792  valid_acc: 0.86975  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 72/100  train_loss: 0.16132  valid_loss 0.40010  valid_acc: 0.86718  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 73/100  train_loss: 0.15872  valid_loss 0.38341  valid_acc: 0.87832  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 74/100  train_loss: 0.14928  valid_loss 0.38554  valid_acc: 0.86975  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 75/100  train_loss: 0.15510  valid_loss 0.40288  valid_acc: 0.87232  lr: 0.000016  elapsed: 38
# val acc has not improved
# Epoch 76/100  train_loss: 0.16034  valid_loss 0.38350  valid_acc: 0.87661  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 77/100  train_loss: 0.15321  valid_loss 0.37048  valid_acc: 0.87489  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 78/100  train_loss: 0.15617  valid_loss 0.38797  valid_acc: 0.87746  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 79/100  train_loss: 0.13806  valid_loss 0.36290  valid_acc: 0.88089  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 80/100  train_loss: 0.14298  valid_loss 0.39496  valid_acc: 0.87918  lr: 0.000008  elapsed: 38
# val_acc has improved !!
# ================ ༼ つ ◕_◕ ༽つ BEST epoch : 81, Accuracy : 0.8903170522707797
# Epoch 81/100  train_loss: 0.15947  valid_loss 0.35362  valid_acc: 0.89032  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 82/100  train_loss: 0.16168  valid_loss 0.39840  valid_acc: 0.87489  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 83/100  train_loss: 0.15796  valid_loss 0.38826  valid_acc: 0.87147  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 84/100  train_loss: 0.14247  valid_loss 0.38203  valid_acc: 0.88603  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 85/100  train_loss: 0.15597  valid_loss 0.38079  valid_acc: 0.86889  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 86/100  train_loss: 0.13940  valid_loss 0.36091  valid_acc: 0.87404  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 87/100  train_loss: 0.15219  valid_loss 0.37551  valid_acc: 0.87147  lr: 0.000008  elapsed: 38
# val acc has not improved
# Epoch 88/100  train_loss: 0.16411  valid_loss 0.34622  valid_acc: 0.88775  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 89/100  train_loss: 0.14698  valid_loss 0.34934  valid_acc: 0.88175  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 90/100  train_loss: 0.14994  valid_loss 0.38456  valid_acc: 0.86975  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 91/100  train_loss: 0.16615  valid_loss 0.36891  valid_acc: 0.87575  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 92/100  train_loss: 0.14731  valid_loss 0.35523  valid_acc: 0.88089  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 93/100  train_loss: 0.14912  valid_loss 0.36826  valid_acc: 0.87318  lr: 0.000004  elapsed: 38
# val acc has not improved
# Epoch 94/100  train_loss: 0.14972  valid_loss 0.36043  valid_acc: 0.87061  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 95/100  train_loss: 0.14354  valid_loss 0.35970  valid_acc: 0.86461  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 96/100  train_loss: 0.16427  valid_loss 0.34723  valid_acc: 0.87404  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 97/100  train_loss: 0.14539  valid_loss 0.36231  valid_acc: 0.87232  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 98/100  train_loss: 0.14814  valid_loss 0.35715  valid_acc: 0.87575  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 99/100  train_loss: 0.14635  valid_loss 0.35766  valid_acc: 0.87147  lr: 0.000002  elapsed: 38
# val acc has not improved
# Epoch 100/100  train_loss: 0.15983  valid_loss 0.35976  valid_acc: 0.86889  lr: 0.000001  elapsed: 38
# ============== ༼ つ ◕_◕ ༽つ BEST epoch : 100, Accuracy : 0.8903170522707797 ====================================
# ========================== ༼ つ ◕_◕ ༽つ Model Load 4_th FOLD =================================
# predict values check :  [  5.58504057  -1.4156692   -4.53080559  -3.5002172   -8.55613232
#  -12.72949886]
# ===============================================================================================
# =================================༼ つ ◕_◕ ༽つ　 SAVED 4_th FOLD ༼ つ ◕_◕ ༽つ ==================
# ===============================================================================================
